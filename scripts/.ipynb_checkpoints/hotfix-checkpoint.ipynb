# %%
#########################################################################
#Data Collection 
#
# Functions for handling subwatershed characteristics data collection
#
# Authors: Shannon McAvoy (smcavoy@dewberry.com)
#
# Editor: Evan Barnes (ebarnes@dewberry.com)
#
# Copyright: Dewberry Engineers Inc.
#########################################################################

# %%
import pandas as pd
import arcpy
import numpy as np
from numpy import mean
from numpy import std
import os
from arcpy import management
# from arcgis.gis import GIS
from time import time
arcpy.CheckOutExtension('Spatial')
# import rasterio
# Out:
# 'CheckedOut'

# %%
arcpy.env.overwriteOutput = True

# %%
path = "P:\Temp\jMatney\Indiana_ML_2"

# %%
st = time()
# Set Local Variables
output_workspace = os.path.join(path, "working_dsn")

arcpy.env.workspace = output_workspace

##### change these based on what subwatersheds you want #####

#set source for shapefile with all 11 subwatersheds in the county

# all_subwatersheds = r"P:\Temp\McAvoy\ML_DataCollection\Indiana_ML\Indiana_HUC12_groups\1.shp"
all_subwatersheds = os.path.join(path, "50sws_10groups\\hotfix_last25.shp")

#set source for streams data
streams = os.path.join(path, "Indiana_50c_streams_edited\Indiana_50c_streams_edited.shp")

#####these are the same for all subwatersheds in Indiana#####

#set source for dem
dem_Indiana = os.path.join(path, "Indiana_3dep\Indiana_dem2")

#set source for slope dem
dem_slope = os.path.join(path, "Indiana_SlopeRaster\IN_slope2")

#set source for NHFL Data
nfhl_sfha = os.path.join(path, "NFHL_18_20200310.gdb\S_FLD_HAZ_AR")

#set source for water bodies data 
water_bodies = os.path.join(path, "IndianaMAP_WaterBodies\Water_Bodies_Lakes_LocalRes\Hydrography_LocalRes_WaterbodyDiscrete_NHD_IN.shp")

#set source for dams data 
dams = os.path.join(path, "IndianaMAP_Dams\Dams_IDNR\Dams_IDNR_IN.shp")

#set source for bridges data
bridges = os.path.join(path, "IndianaMAP_Bridges\Bridges_County_INDOT\Bridges_County_INDOT_IN.shp")

#set source for streets data
streets = os.path.join(path, "IndianaMAP_Streets\Streets_Centerlines_IGIO\County_Street_Centerlines_IGIO_IN.gdb\County_Street_Centerlines_IGIO_IN_Dec2019")

#set source for railraods data
railroads = os.path.join(path, "IndianaMAP_Railroads\Railroads_Active_Abandoned_INDOT\Rail_System_Active_Abandoned_INDOT_IN.shp")

#set source for ACS population data
population = os.path.join(path, "Indiana_PopulationData\Indiana_PopulationData.shp")

#set source for ACS median income data 
median_income = os.path.join(path, "Indiana_IncomeData\Indiana_IncomeData.shp")

#set source for county boundary data
county_boundary = os.path.join(path, "MarionCounty_Boundary\Marion_County_Boundary.shp")

#source for Bing building footprints for Indiana (attrubuted with open street maps data)
building_footprints = os.path.join(path, "BuildingFootprints_Indiana\Building_Footprints_Attributed_IN.shp")

#folder with partial duration files, set as workspace temporarily, then reset when done
directory_rainfall = os.path.join(path, "MarionCounty_Rainfall\All_Rainfall_Clipped_IN")

#set source for nlcd land use data
lu_usa = os.path.join(path, r"NLCD_Impervious\NLCD_indiana_polygon.shp")

#set source for impervious indicator data
impervious_usa = os.path.join(path, "NLCD_Impervious\\NLCD_2016_Impervious_L48_20190405_PERCENT\\NLCD_2016_Impervious_L48_20190405.img")


#########################################################################################################
print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
# 0.15 minutes to process.

# %%
subwatershed_list = []
area_list = []
perimeter_list = []
watershed_length_list = []
elongation_ratio_list = []
shape_factor_list = []
circulatory_ratio_list = []
relief_list = []
relief_ratio_list = []
avg_slope_list = []
drainage_density_list = []
ruggedness_list = []
aae_list = []
buildings_aae_list = []
x_list = []
buildings_x_list = []
water_bodies_list = []
dams_list = []
bridges_list = []
streets_list = []
railroads_list = []
population_list = []
dependent_population_list = []
population_density_list = []
avg_median_income_list = []
housing_density_list = []
population_change_list = []
dist_to_stream_avg_list = []
dist_to_stream_stdev_list = []

lu_21_list = []
lu_22_list = []
lu_23_list = []
lu_24_list = []
lu_41_list = []
lu_82_list = []
impervious_percent_list = []

orb100yr06h_list = []
orb100yr12h_list = []
orb100yr24h_list = []
orb25yr06h_list = []
orb25yr12h_list = []
orb25yr24h_list = []
orb2yr06h_list = []
orb2yr12h_list = []
orb2yr24h_list = []
orb50yr06h_list = []
orb50yr12h_list = []
orb50yr24h_list = []
orb100yr06ha_am_list = []
orb100yr12ha_am_list = []
orb100yr24ha_am_list = []
orb25yr06ha_am_list = []
orb25yr12ha_am_list = []
orb25yr24ha_am_list = []
orb2yr06ha_am_list = []
orb2yr12ha_am_list = []
orb2yr24ha_am_list = []
orb50yr06ha_am_list = []
orb50yr12ha_am_list = []
orb50yr24ha_am_list = []

# %%
print(all_subwatersheds)
# Out:
# P:\Temp\jMatney\Indiana_ML_2\50sws_10groups\hotfix_all.shp

# %%
#add AREA and PERIMETER fields for the whole subwatersheds file
#calculate area of subwatersheds
arcpy.AddField_management(all_subwatersheds, "AREA", "DOUBLE")

arcpy.CalculateGeometryAttributes_management(all_subwatersheds, "AREA AREA_GEODESIC", '', 
                                                    "SQUARE_KILOMETERS",
                                                    None)
#calculate perimeter of subwatershed
arcpy.AddField_management(all_subwatersheds, "PERIMETER", "DOUBLE")
perimeter = arcpy.CalculateGeometryAttributes_management(all_subwatersheds, "PERIMETER PERIMETER_LENGTH_GEODESIC",
                                                         "KILOMETERS")

print("perimeter calculated")
# Out:
# perimeter calculated

# %%
st = time()
# perform all need intersections here:

#put all intersections in this projection so area and length will be in meters
arcpy.env.outputCoordinateSystem = arcpy.SpatialReference(102008)

# nfhl_sfha_intersect = "nfhl_sfha.shp"
# nfhl_sfha_intersect = arcpy.Intersect_analysis([nfhl_sfha, all_subwatersheds], nfhl_sfha_intersect)

water_bodies_intersect = "water_bodies.shp"
water_bodies_intersect = arcpy.Intersect_analysis([water_bodies, all_subwatersheds], water_bodies_intersect)

# dams_intersect = "dams.shp"
# arcpy.Intersect_analysis([dams, all_subwatersheds], dams_intersect)

# bridges_intersect = "bridges.shp"
# arcpy.Intersect_analysis([bridges, all_subwatersheds], bridges_intersect)

# streets_intersect = "streets.shp"
# arcpy.Intersect_analysis([streets, all_subwatersheds], streets_intersect)

# railroads_intersect = "railroads.shp"
# arcpy.Intersect_analysis([railroads, all_subwatersheds], railroads_intersect)

population_intersect = "population.shp"
arcpy.Intersect_analysis([population, all_subwatersheds], population_intersect)

median_income_intersect= "median_income.shp"
arcpy.Intersect_analysis([median_income, all_subwatersheds], median_income_intersect)

building_footprints_intersect = "building_footprints.shp"
arcpy.Intersect_analysis([building_footprints, all_subwatersheds], building_footprints_intersect)

streams_intersect = "streams.shp"
arcpy.Intersect_analysis([streams, all_subwatersheds], streams_intersect)

# lu_subwatershed = "lu_subwatershed.shp"
# arcpy.Intersect_analysis([lu_usa, all_subwatersheds], lu_subwatershed)

print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
# 32.21 minutes to process.

# %%
def get_length_area(layer, length_area):
    #length_Area = 'LENGTH' or 'AREA'
    search_field = "SHAPE@{}".format(length_area)
    values = []
    with arcpy.da.SearchCursor(layer, [search_field]) as sCursor: 
        for s in sCursor:
            # convert meters to kilometers
            if length_area == 'AREA':
                value = s[0]/ (1000 * 1000)
            else: # assumed length
                value = s[0] / 1000
                    
            values.append(value)
    return values

# %%
st = time()
# make all layers for selections
#subwatershed_selection = "subwatershed_lyr"
#arcpy.MakeFeatureLayer_management (all_subwatersheds, subwatershed_selection)

# nfhl_sfha_selection = "nfhl_sfha_lyr"
# arcpy.MakeFeatureLayer_management(nfhl_sfha_intersect, nfhl_sfha_selection)

water_bodies_selection = "water_bodies_lyr"
arcpy.MakeFeatureLayer_management(water_bodies_intersect, water_bodies_selection)

# dams_selection = "dams_lyr"
# arcpy.MakeFeatureLayer_management(dams_intersect, dams_selection)

# bridges_selection = "bridges_lyr"
# arcpy.MakeFeatureLayer_management(bridges_intersect, bridges_selection)

# streets_selection = "streets_lyr"
# arcpy.MakeFeatureLayer_management(streets_intersect, streets_selection)

# railroads_selection = "railroads_lyr"
# arcpy.MakeFeatureLayer_management(railroads_intersect, railroads_selection)

population_selection = "population_lyr"
arcpy.MakeFeatureLayer_management(population_intersect, population_selection)

median_income_selection = "median_income_lyr"
arcpy.MakeFeatureLayer_management(median_income_intersect, median_income_selection)

building_footprints_selection= "building_footprints_lyr"
arcpy.MakeFeatureLayer_management(building_footprints_intersect, building_footprints_selection)

streams_selection = "streams_lyr"
arcpy.MakeFeatureLayer_management(streams_intersect, streams_selection)

# lu_selection = "lu_lyr"
# arcpy.MakeFeatureLayer_management(lu_subwatershed, lu_selection)

print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
# 5.18 minutes to process.

# %%
st = time()


#search cursor through each row of county subwatersheds file
with arcpy.da.SearchCursor(all_subwatersheds, ['HUC12','AREA', 'PERIMETER']) as cursor:

    for row in cursor:
        subwatershed_number = row[0]
        
        subwatershed_list.append(subwatershed_number)

        print("--------------------", subwatershed_number, " is the subwatershed to be worked on ------------------------")
        # Make a layer from the feature class
        arcpy.MakeFeatureLayer_management(all_subwatersheds,"subwatersheds_lyr")
        
        #select subwatershed from shapefile with all of them
        s = arcpy.SelectLayerByAttribute_management(all_subwatersheds, "NEW_SELECTION", 
                                                "HUC12 = '{}'".format(subwatershed_number))
        arcpy.CopyFeatures_management(s, "s_lyr.shp")
        subwatershed_selection1 = os.path.join(path, "working_dsn\s_lyr.shp")
        #arcpy.MakeFeatureLayer_management(s, subwatershed_selection1)
        
        # use mask in lieu of clipping rasters
        arcpy.env.cellSize = dem_slope
        arcpy.env.snapRaster = dem_slope
        #arcpy.env.outputCoordinateSystem = 
        arcpy.env.mask = subwatershed_selection1

        area = row[1]
        area_list.append(area)
        print(area, " square kilometers")

        perimeter = row[2]
        perimeter_list.append(perimeter)
        print(perimeter, " kilometers")


        #calculate area covered by lakes/reserviors 
        arcpy.management.SelectLayerByAttribute(water_bodies_selection, "NEW_SELECTION", 
                                                            "HUC12 = '{}'".format(subwatershed_number))
        water_bodies_area_sum = sum(get_length_area(water_bodies_selection, "AREA"))
        water_bodies_list.append(water_bodies_area_sum)
        print(water_bodies_area_sum, " = area of all water bodies in the subwatershed (square km)")


        #all streams in subwatershed
        arcpy.management.SelectLayerByAttribute(streams_selection, "NEW_SELECTION", 
                                                            "HUC12 = '{}'".format(subwatershed_number))
        print("streams clipped")
        print("length calculated")
        #get the sum of all of the areas
        stream_length_list = get_length_area(streams_selection, "LENGTH")  
        stream_length_sum = sum(stream_length_list)
        print(stream_length_sum, " = length of all streams in subwatershed")
        print(area, " = subwatershed area")
        drainage_density = stream_length_sum / area
        drainage_density_list.append(drainage_density)
        print(drainage_density, "is the drainage density (streams/km)")
        #find watershed length
        #watershed length = distance from outlet to watershed boundary along the main channel
        #we are assuming that the longest stream above is the main channel
        watershed_length = max(stream_length_list)
        watershed_length_list.append(watershed_length)
        print(watershed_length, " = watershed length (longest stream in subwatershed)")
        #calculate shape factor 
        #watershed length squared divided by watershed area
        shape_factor = (watershed_length**2) / area
        shape_factor_list.append(shape_factor)
        print(shape_factor, " is the shape factor.")

        
        #use Raster Domain tool to get z-enabled polyline of perimeter
        dem_clip = os.path.join(path, "working_dsn\dem_clip.tif")
        arcpy.Clip_management(dem_Indiana, "#", dem_clip, subwatershed_selection1, "#", "ClippingGeometry", "NO_MAINTAIN_EXTENT")
        perimeter_polyline = "perimeter_polyline.shp"
        arcpy.RasterDomain_3d(dem_clip, perimeter_polyline, "LINE")
        print("created 3d polyline of subwatershed perimeter")

        #Convert each vertices of the polyline into points
        perimeter_points = "perimeter_points.shp"
        arcpy.FeatureVerticesToPoints_management(perimeter_polyline, perimeter_points)
        print("created perimeter points")

        #get Z values into the attribute table for the points
        arcpy.AddZInformation_3d(perimeter_points, "Z")
        print("added z information")

        #get the max value from all of the points
        perimeter_stats = "perimeter_stats"
        arcpy.Statistics_analysis(perimeter_points, "perimeter_stats", [["Z", "MAX"], ["Z", "MIN"]])

        #get the values for max Z and min Z into a format to use them
        with arcpy.da.SearchCursor(perimeter_stats, ['MAX_Z', 'MIN_Z']) as statsCursor:
            for stat in statsCursor:
                max_z = stat[0]
                min_z = stat[1]


        print(max_z)
        print(min_z)

        relief = max_z - min_z
        
        #calculate relief ratio
        #relief divided by watershed length
        #length is is kilometers, convert to meters
        watershed_length_meters = watershed_length * 1000
        relief_ratio = relief / watershed_length_meters
        relief_ratio_list.append(relief_ratio)
        print(relief_ratio, " = relief ratio")


        #calculate ruggedness number
        #product of relief and drainage density
        #relief is in meters, convert first to km
        relief_km = relief / 1000
        print(relief_km, " is the relief in km")
        ruggedness = relief_km * drainage_density
        ruggedness_list.append(ruggedness)
        print(ruggedness, " is the ruggedness number")
        
        
                #ACS population data - 5 year estimates (2014-2018) gotten from ESRI Living Atlas Data
        #data is chosen to be on census tract level
        arcpy.management.SelectLayerByAttribute(population_selection, "NEW_SELECTION", 
                                                            "HUC12 = '{}'".format(subwatershed_number))
        #get total population
        #field = B01001_001E = Total Population (alias)
        #when clipped, field name changes to B01001_001

        #get the sum of all of the populations in each tract
        total_pop_list = []  
        with arcpy.da.SearchCursor(population_selection, ['B01001_001']) as popCursor:  
            for pop in popCursor:  
                total_pop_value = pop[0] 
                total_pop_list.append(total_pop_value)  
        total_pop_sum = sum(total_pop_list)
        population_list.append(total_pop_sum)
        print(total_pop_sum, " = total population in the subwatershed") 

        #get the average of percentages of dependent age groups in each tract
        #field = B01001_calc_pctDependE = Percent of Population in Dependent Age Groups (under 18 and 65+) (alias)
        #when clipped field changes to B01001_61
        dependent_pop_list = []  
        with arcpy.da.SearchCursor(population_selection, ["B01001__61"]) as dpopCursor: 
            for dpop in dpopCursor:  
                dependent_pop_value = dpop[0] 
                dependent_pop_list.append(dependent_pop_value)  
        dependent_pop_avg_pct = mean(dependent_pop_list)
        dependent_population_list.append(dependent_pop_avg_pct)

        print(dependent_pop_avg_pct, " = total percent of dependent population in the subwatershed") 

        #find population density
        population_density = total_pop_sum / area
        population_density_list.append(population_density)
        print(population_density, " = population density of subwatershed (people/square km)")
        

        #get housing density
        #select buildings that are marked residential
        arcpy.SelectLayerByAttribute_management(building_footprints_selection, "NEW_SELECTION",
                                                                             "HUC12 = '{}' And RES_NONRES = 'Res'".format(subwatershed_number))
        #get count of how many buildings there are 
        buildings_count = arcpy.GetCount_management(building_footprints_selection)
        buildings_count_number = buildings_count.getOutput(0)
        print(buildings_count_number, " = number of residential building footprints in the subwatershed")
        #divide number of buildings by subwatershed area
        housing_density = int(buildings_count_number) / area
        housing_density_list.append(housing_density)
        print(housing_density, " = housing density (buildings per square km)")

    

    #########################################################################################




print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
# -------------------- 051201111902  is the subwatershed to be worked on ------------------------
# 61.7611689348  square kilometers
# 43.8045173646  kilometers
# 0.578547275655337  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 24.39173225667595  = length of all streams in subwatershed
# 61.7611689348  = subwatershed area
# 0.39493637632451234 is the drainage density (streams/km)
# 10.968176416913414  = watershed length (longest stream in subwatershed)
# 1.9478403013960885  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 183.373977661
# 121.728050232
# 0.005620435438468992  = relief ratio
# 0.061645927429  is the relief in km
# 0.02434621919397312  is the ruggedness number
# 25923  = total population in the subwatershed
# 37.15  = total percent of dependent population in the subwatershed
# 419.7297500532475  = population density of subwatershed (people/square km)
# 1167  = number of residential building footprints in the subwatershed
# 18.89536775497203  = housing density (buildings per square km)
# -------------------- 051202081501  is the subwatershed to be worked on ------------------------
# 50.7143696924  square kilometers
# 40.8714539299  kilometers
# 0.35793134832718343  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 56.54750474949632  = length of all streams in subwatershed
# 50.7143696924  = subwatershed area
# 1.115019374044798 is the drainage density (streams/km)
# 13.401043782857164  = watershed length (longest stream in subwatershed)
# 3.541165463739708  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 201.216888427
# 130.814880373
# 0.005253471982836099  = relief ratio
# 0.07040200805399999  is the relief in km
# 0.07849960295186789  is the ruggedness number
# 18010  = total population in the subwatershed
# 40.46666666666667  = total percent of dependent population in the subwatershed
# 355.12617250765044  = population density of subwatershed (people/square km)
# 1025  = number of residential building footprints in the subwatershed
# 20.21123413772025  = housing density (buildings per square km)
# -------------------- 051202060503  is the subwatershed to be worked on ------------------------
# 89.2500095283  square kilometers
# 53.8379439667  kilometers
# 0.28371461575790774  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 42.11107324358157  = length of all streams in subwatershed
# 89.2500095283  = subwatershed area
# 0.47183270305678465 is the drainage density (streams/km)
# 19.60900974164856  = watershed length (longest stream in subwatershed)
# 4.308271394930709  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 225.983398437
# 161.961257935
# 0.0032649349123439  = relief ratio
# 0.06402214050200002  is the relief in km
# 0.03020773960853992  is the ruggedness number
# 18196  = total population in the subwatershed
# 39.2  = total percent of dependent population in the subwatershed
# 203.87672893446907  = population density of subwatershed (people/square km)
# 260  = number of residential building footprints in the subwatershed
# 2.913164955097931  = housing density (buildings per square km)
# -------------------- 051202030602  is the subwatershed to be worked on ------------------------
# 111.004173734  square kilometers
# 52.5923194855  kilometers
# 3.014052413102817  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 49.15983618053085  = length of all streams in subwatershed
# 111.004173734  = subwatershed area
# 0.4428647547824001 is the drainage density (streams/km)
# 17.970407558100142  = watershed length (longest stream in subwatershed)
# 2.909219869318384  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 217.113388061
# 160.986526489
# 0.0031232937478204758  = relief ratio
# 0.056126861571999996  is the relief in km
# 0.024856608786789493  is the ruggedness number
# 11358  = total population in the subwatershed
# 40.333333333333336  = total percent of dependent population in the subwatershed
# 102.32047695086895  = population density of subwatershed (people/square km)
# 249  = number of residential building footprints in the subwatershed
# 2.2431588977607295  = housing density (buildings per square km)
# -------------------- 051202090103  is the subwatershed to be worked on ------------------------
# 53.4823562665  square kilometers
# 42.1466947085  kilometers
# 3.070525202567721  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 21.82728850076223  = length of all streams in subwatershed
# 53.4823562665  = subwatershed area
# 0.4081212950304191 is the drainage density (streams/km)
# 6.825770412170958  = watershed length (longest stream in subwatershed)
# 0.8711497580156544  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 269.717956543
# 162.900360107
# 0.015649163389019748  = relief ratio
# 0.106817596436  is the relief in km
# 0.043594535789497  is the ruggedness number
# 7514  = total population in the subwatershed
# 42.849999999999994  = total percent of dependent population in the subwatershed
# 140.49493187170177  = population density of subwatershed (people/square km)
# 171  = number of residential building footprints in the subwatershed
# 3.1973161232447436  = housing density (buildings per square km)
# -------------------- 040400010303  is the subwatershed to be worked on ------------------------
# 106.113980123  square kilometers
# 54.5648151169  kilometers
# 2.2164100374788798  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 55.89938300495406  = length of all streams in subwatershed
# 106.113980123  = subwatershed area
# 0.5267862249645084 is the drainage density (streams/km)
# 22.378411339615468  = watershed length (longest stream in subwatershed)
# 4.719390352756019  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 264.808258057
# 179.320175171
# 0.0038201140192049465  = relief ratio
# 0.085488082886  is the relief in km
# 0.04503394446296894  is the ruggedness number
# 83885  = total population in the subwatershed
# 38.75333333333333  = total percent of dependent population in the subwatershed
# 790.5178931443934  = population density of subwatershed (people/square km)
# 6191  = number of residential building footprints in the subwatershed
# 58.34292515297061  = housing density (buildings per square km)
# -------------------- 051202011502  is the subwatershed to be worked on ------------------------
# 84.1633728056  square kilometers
# 53.9834313728  kilometers
# 1.6414627693848334  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 39.7299844470513  = length of all streams in subwatershed
# 84.1633728056  = subwatershed area
# 0.4720578931504962 is the drainage density (streams/km)
# 27.249228176723268  = watershed length (longest stream in subwatershed)
# 8.822370248186203  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 279.558441162
# 176.640792847
# 0.0037769014097402557  = relief ratio
# 0.10291764831500001  is the relief in km
# 0.04858308823158262  is the ruggedness number
# 17125  = total population in the subwatershed
# 38.96666666666667  = total percent of dependent population in the subwatershed
# 203.47330945915405  = population density of subwatershed (people/square km)
# 801  = number of residential building footprints in the subwatershed
# 9.517204138790213  = housing density (buildings per square km)
# -------------------- 051201040506  is the subwatershed to be worked on ------------------------
# 57.3070524096  square kilometers
# 41.0290726709  kilometers
# 0.18261935429188073  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 34.57769752230608  = length of all streams in subwatershed
# 57.3070524096  = subwatershed area
# 0.6033759558101731 is the drainage density (streams/km)
# 13.744429621885699  = watershed length (longest stream in subwatershed)
# 3.296441496951311  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 274.666107178
# 232.380844116
# 0.003076538221321882  = relief ratio
# 0.04228526306200001  is the relief in km
# 0.025513911016718866  is the ruggedness number
# 11644  = total population in the subwatershed
# 42.86666666666667  = total percent of dependent population in the subwatershed
# 203.18616139554604  = population density of subwatershed (people/square km)
# 199  = number of residential building footprints in the subwatershed
# 3.4725219956813516  = housing density (buildings per square km)
# -------------------- 051201060205  is the subwatershed to be worked on ------------------------
# 53.340016332  square kilometers
# 53.3728454158  kilometers
# 2.084175522481967  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 27.200287553253652  = length of all streams in subwatershed
# 53.340016332  = subwatershed area
# 0.5099414927800748 is the drainage density (streams/km)
# 17.79460440249639  = watershed length (longest stream in subwatershed)
# 5.9364051160100395  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 281.508483887
# 244.556274414
# 0.0020765962893682546  = relief ratio
# 0.036952209473000014  is the relief in km
# 0.01884346486018365  is the ruggedness number
# 31617  = total population in the subwatershed
# 41.175  = total percent of dependent population in the subwatershed
# 592.7444754273946  = population density of subwatershed (people/square km)
# 720  = number of residential building footprints in the subwatershed
# 13.498308577908217  = housing density (buildings per square km)
# -------------------- 040400010503  is the subwatershed to be worked on ------------------------
# 54.6629100542  square kilometers
# 45.8438207489  kilometers
# 1.7835673465518584  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 20.183257254332073  = length of all streams in subwatershed
# 54.6629100542  = subwatershed area
# 0.3692312984127581 is the drainage density (streams/km)
# 13.282991037431133  = watershed length (longest stream in subwatershed)
# 3.2277434685700435  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 224.527297974
# 186.345626831
# 0.0028744784239788314  = relief ratio
# 0.03818167114299999  is the relief in km
# 0.014097868011698822  is the ruggedness number
# 84380  = total population in the subwatershed
# 38.32  = total percent of dependent population in the subwatershed
# 1543.642662206139  = population density of subwatershed (people/square km)
# 4119  = number of residential building footprints in the subwatershed
# 75.3527391043741  = housing density (buildings per square km)
# -------------------- 051202040302  is the subwatershed to be worked on ------------------------
# 97.5205000551  square kilometers
# 52.160754919  kilometers
# 1.098837305086839  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 55.437162128526126  = length of all streams in subwatershed
# 97.5205000551  = subwatershed area
# 0.5684667541409612 is the drainage density (streams/km)
# 24.53059596878077  = watershed length (longest stream in subwatershed)
# 6.170498902728849  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 287.090148926
# 258.015930176
# 0.0011852226821966224  = relief ratio
# 0.02907421875  is the relief in km
# 0.01652772676199677  is the ruggedness number
# 37147  = total population in the subwatershed
# 39.46666666666667  = total percent of dependent population in the subwatershed
# 380.9147818049702  = population density of subwatershed (people/square km)
# 4814  = number of residential building footprints in the subwatershed
# 49.36397985326208  = housing density (buildings per square km)
# -------------------- 050902031007  is the subwatershed to be worked on ------------------------
# 61.2756310377  square kilometers
# 37.9334603114  kilometers
# 0.697609235091111  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 37.35622886212315  = length of all streams in subwatershed
# 61.2756310377  = subwatershed area
# 0.609642499465075 is the drainage density (streams/km)
# 15.381702771673977  = watershed length (longest stream in subwatershed)
# 3.861188798048544  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 282.488372803
# 131.082550049
# 0.009843242000022253  = relief ratio
# 0.15140582275400002  is the relief in km
# 0.0923034242173147  is the ruggedness number
# 7713  = total population in the subwatershed
# 43.0  = total percent of dependent population in the subwatershed
# 125.87385669279449  = population density of subwatershed (people/square km)
# 284  = number of residential building footprints in the subwatershed
# 4.634795190036773  = housing density (buildings per square km)
# -------------------- 051201130704  is the subwatershed to be worked on ------------------------
# 62.9557858221  square kilometers
# 46.4810657839  kilometers
# 0.4637511585136779  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 17.21937963214831  = length of all streams in subwatershed
# 62.9557858221  = subwatershed area
# 0.27351544273955547 is the drainage density (streams/km)
# 8.652663090139797  = watershed length (longest stream in subwatershed)
# 1.1892247483500669  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 178.848892212
# 113.495002844
# 0.007553037566258011  = relief ratio
# 0.06535388936800002  is the relief in km
# 0.017875297985240454  is the ruggedness number
# 8026  = total population in the subwatershed
# 39.9  = total percent of dependent population in the subwatershed
# 127.48629685410984  = population density of subwatershed (people/square km)
# 512  = number of residential building footprints in the subwatershed
# 8.13269175047399  = housing density (buildings per square km)
# -------------------- 071200021301  is the subwatershed to be worked on ------------------------
# 61.6937510077  square kilometers
# 45.0576188328  kilometers
# 0.32029247783019443  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 36.99787095599496  = length of all streams in subwatershed
# 61.6937510077  = subwatershed area
# 0.5997020824909358 is the drainage density (streams/km)
# 9.514783822277781  = watershed length (longest stream in subwatershed)
# 1.4674275709606277  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 226.871185303
# 199.275512695
# 0.0029002942287966525  = relief ratio
# 0.027595672608000003  is the relief in km
# 0.016549182330755675  is the ruggedness number
# 3025  = total population in the subwatershed
# 39.5  = total percent of dependent population in the subwatershed
# 49.032518700677635  = population density of subwatershed (people/square km)
# 52  = number of residential building footprints in the subwatershed
# 0.8428730487389213  = housing density (buildings per square km)
# -------------------- 051202010103  is the subwatershed to be worked on ------------------------
# 53.0825293382  square kilometers
# 37.2455310439  kilometers
# 0.33558029579831194  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 20.16479656888086  = length of all streams in subwatershed
# 53.0825293382  = subwatershed area
# 0.3798763325765184 is the drainage density (streams/km)
# 11.974105046240462  = watershed length (longest stream in subwatershed)
# 2.7010617889909163  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 363.707489014
# 312.301513672
# 0.004293095404081162  = relief ratio
# 0.05140597534199998  is the relief in km
# 0.019527913385437887  is the ruggedness number
# 12683  = total population in the subwatershed
# 42.050000000000004  = total percent of dependent population in the subwatershed
# 238.92983544913488  = population density of subwatershed (people/square km)
# 171  = number of residential building footprints in the subwatershed
# 3.2213988694947617  = housing density (buildings per square km)
# -------------------- 051202040603  is the subwatershed to be worked on ------------------------
# 71.9083115391  square kilometers
# 60.4100804948  kilometers
# 0.4350581947040275  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 44.654832764990985  = length of all streams in subwatershed
# 71.9083115391  = subwatershed area
# 0.6209968195499905 is the drainage density (streams/km)
# 10.928427443064788  = watershed length (longest stream in subwatershed)
# 1.6608723501092286  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 275.465667725
# 215.644943237
# 0.005473863902163015  = relief ratio
# 0.05982072448799999  is the relief in km
# 0.037148479650224234  is the ruggedness number
# 67062  = total population in the subwatershed
# 39.46666666666667  = total percent of dependent population in the subwatershed
# 932.6042923916407  = population density of subwatershed (people/square km)
# 4311  = number of residential building footprints in the subwatershed
# 59.95134509111513  = housing density (buildings per square km)
# -------------------- 051201070101  is the subwatershed to be worked on ------------------------
# 50.824330418  square kilometers
# 49.1756305567  kilometers
# 0.022572237910204403  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 23.39865400953982  = length of all streams in subwatershed
# 50.824330418  = subwatershed area
# 0.4603829271748344 is the drainage density (streams/km)
# 19.49848009277465  = watershed length (longest stream in subwatershed)
# 7.4804866645853645  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 279.948150635
# 259.937072754
# 0.001026289115140585  = relief ratio
# 0.020011077881000004  is the relief in km
# 0.009212758610778365  is the ruggedness number
# 15218  = total population in the subwatershed
# 39.525  = total percent of dependent population in the subwatershed
# 299.42352166454464  = population density of subwatershed (people/square km)
# 353  = number of residential building footprints in the subwatershed
# 6.945492387145766  = housing density (buildings per square km)
# -------------------- 051201100602  is the subwatershed to be worked on ------------------------
# 43.9293838336  square kilometers
# 40.256017686  kilometers
# 0.25855257694697464  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 6.123101898982342  = length of all streams in subwatershed
# 43.9293838336  = subwatershed area
# 0.13938510774874566 is the drainage density (streams/km)
# 6.123101898982342  = watershed length (longest stream in subwatershed)
# 0.853469217946203  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 259.578552246
# 195.160980225
# 0.010520414829566399  = relief ratio
# 0.06441757202100001  is the relief in km
# 0.00897885021705967  is the ruggedness number
# 17716  = total population in the subwatershed
# 40.625  = total percent of dependent population in the subwatershed
# 403.28359867523733  = population density of subwatershed (people/square km)
# 354  = number of residential building footprints in the subwatershed
# 8.058387555375592  = housing density (buildings per square km)
# -------------------- 051202060301  is the subwatershed to be worked on ------------------------
# 44.6778154181  square kilometers
# 34.8968277075  kilometers
# 0.08749746645162933  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 15.91201021662097  = length of all streams in subwatershed
# 44.6778154181  = subwatershed area
# 0.3561501400127691 is the drainage density (streams/km)
# 15.91201021662097  = watershed length (longest stream in subwatershed)
# 5.667064666534171  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 334.263153076
# 266.429840088
# 0.0042630259825464645  = relief ratio
# 0.067833312988  is the relief in km
# 0.024158843918206187  is the ruggedness number
# 19390  = total population in the subwatershed
# 40.2  = total percent of dependent population in the subwatershed
# 433.9961526441301  = population density of subwatershed (people/square km)
# 1965  = number of residential building footprints in the subwatershed
# 43.9815595639874  = housing density (buildings per square km)
# -------------------- 051202070303  is the subwatershed to be worked on ------------------------
# 75.0714582191  square kilometers
# 42.6353400328  kilometers
# 0.44943876273784533  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 43.04909239322451  = length of all streams in subwatershed
# 75.0714582191  = subwatershed area
# 0.5734415370963419 is the drainage density (streams/km)
# 22.252292186749244  = watershed length (longest stream in subwatershed)
# 6.595909008711378  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 262.19229126
# 185.746749878
# 0.0034354007551420543  = relief ratio
# 0.07644554138199999  is the relief in km
# 0.04383704875425609  is the ruggedness number
# 9940  = total population in the subwatershed
# 40.9  = total percent of dependent population in the subwatershed
# 132.40717891731353  = population density of subwatershed (people/square km)
# 505  = number of residential building footprints in the subwatershed
# 6.726924079803152  = housing density (buildings per square km)
# -------------------- 051201070109  is the subwatershed to be worked on ------------------------
# 67.5355872435  square kilometers
# 40.9283974281  kilometers
# 0.4465299873987175  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 24.625051812001054  = length of all streams in subwatershed
# 67.5355872435  = subwatershed area
# 0.3646233462546978 is the drainage density (streams/km)
# 11.96837611938194  = watershed length (longest stream in subwatershed)
# 2.1209858799114585  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 262.497436523
# 237.053604126
# 0.0021259218580033995  = relief ratio
# 0.025443832396999967  is the relief in km
# 0.009277415310137815  is the ruggedness number
# 55523  = total population in the subwatershed
# 40.528571428571425  = total percent of dependent population in the subwatershed
# 822.1295211339684  = population density of subwatershed (people/square km)
# 5401  = number of residential building footprints in the subwatershed
# 79.97265175953322  = housing density (buildings per square km)
# -------------------- 051401040302  is the subwatershed to be worked on ------------------------
# 67.8915832452  square kilometers
# 49.072958553  kilometers
# 0.8554266122987757  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 45.48713111768248  = length of all streams in subwatershed
# 67.8915832452  = subwatershed area
# 0.6699966173037873 is the drainage density (streams/km)
# 24.396661375872746  = watershed length (longest stream in subwatershed)
# 8.766875919498933  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 306.869598389
# 201.824157716
# 0.0043057301593276785  = relief ratio
# 0.10504544067299998  is the relief in km
# 0.07038008991409567  is the ruggedness number
# 34646  = total population in the subwatershed
# 39.699999999999996  = total percent of dependent population in the subwatershed
# 510.3136256945298  = population density of subwatershed (people/square km)
# 2066  = number of residential building footprints in the subwatershed
# 30.43087082736531  = housing density (buildings per square km)
# -------------------- 051201100402  is the subwatershed to be worked on ------------------------
# 70.340446768  square kilometers
# 57.6107793984  kilometers
# 0.3152138522901349  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 38.586501190753495  = length of all streams in subwatershed
# 70.340446768  = subwatershed area
# 0.5485677581494643 is the drainage density (streams/km)
# 24.99991526401895  = watershed length (longest stream in subwatershed)
# 8.88529703641941  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 298.297098795
# 243.630172729
# 0.002186684454274099  = relief ratio
# 0.054666926066  is the relief in km
# 0.029988513076948137  is the ruggedness number
# 26141  = total population in the subwatershed
# 38.9  = total percent of dependent population in the subwatershed
# 371.6353989934043  = population density of subwatershed (people/square km)
# 779  = number of residential building footprints in the subwatershed
# 11.074709300174513  = housing density (buildings per square km)
# -------------------- 050800030803  is the subwatershed to be worked on ------------------------
# 76.6784441331  square kilometers
# 53.6776416804  kilometers
# 0.2208882064493812  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 30.79110240402025  = length of all streams in subwatershed
# 76.6784441331  = subwatershed area
# 0.4015613873251318 is the drainage density (streams/km)
# 22.62724429686368  = watershed length (longest stream in subwatershed)
# 6.677133192494405  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 319.015838623
# 165.464248658
# 0.006786137452287263  = relief ratio
# 0.15355158996499998  is the relief in km
# 0.061660389492325184  is the ruggedness number
# 6353  = total population in the subwatershed
# 42.2  = total percent of dependent population in the subwatershed
# 82.85248966413994  = population density of subwatershed (people/square km)
# 231  = number of residential building footprints in the subwatershed
# 3.0125806882443453  = housing density (buildings per square km)
# -------------------- 071200010703  is the subwatershed to be worked on ------------------------
# 66.973365878  square kilometers
# 46.9114013514  kilometers
# 0.38961187477882775  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 54.62386615846468  = length of all streams in subwatershed
# 66.973365878  = subwatershed area
# 0.8156058075081457 is the drainage density (streams/km)
# 11.371937733969828  = watershed length (longest stream in subwatershed)
# 1.9309312908188079  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 223.164413452
# 203.675384522
# 0.0017137825923706116  = relief ratio
# 0.01948902892999999  is the relief in km
# 0.015895365178002253  is the ruggedness number
# 6372  = total population in the subwatershed
# 38.5  = total percent of dependent population in the subwatershed
# 95.14229897908014  = population density of subwatershed (people/square km)
# 242  = number of residential building footprints in the subwatershed
# 3.613376703223069  = housing density (buildings per square km)
# -------------------- 051201040304  is the subwatershed to be worked on ------------------------
# 90.2550137995  square kilometers
# 77.4226461099  kilometers
# 1.4165560863093105  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 47.48168552926156  = length of all streams in subwatershed
# 90.2550137995  = subwatershed area
# 0.5260836327025702 is the drainage density (streams/km)
# 14.715276649490583  = watershed length (longest stream in subwatershed)
# 2.3991948785480366  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 280.925842285
# 237.999267578
# 0.0029171435732732913  = relief ratio
# 0.04292657470699999  is the relief in km
# 0.02258296836133682  is the ruggedness number
# 23126  = total population in the subwatershed
# 40.620000000000005  = total percent of dependent population in the subwatershed
# 256.2295325927712  = population density of subwatershed (people/square km)
# 515  = number of residential building footprints in the subwatershed
# 5.706054193776579  = housing density (buildings per square km)
# -------------------- 051202040806  is the subwatershed to be worked on ------------------------
# 72.4820795081  square kilometers
# 53.258194061  kilometers
# 0.868906524858275  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 52.11981757599466  = length of all streams in subwatershed
# 72.4820795081  = subwatershed area
# 0.7190717751160848 is the drainage density (streams/km)
# 20.611823357333503  = watershed length (longest stream in subwatershed)
# 5.861411054941401  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 260.815582275
# 210.520858765
# 0.002440090943827421  = relief ratio
# 0.050294723509999986  is the relief in km
# 0.03616551611330837  is the ruggedness number
# 35973  = total population in the subwatershed
# 39.45  = total percent of dependent population in the subwatershed
# 496.3019858719693  = population density of subwatershed (people/square km)
# 700  = number of residential building footprints in the subwatershed
# 9.657559561626178  = housing density (buildings per square km)
# -------------------- 051402010501  is the subwatershed to be worked on ------------------------
# 81.2238478227  square kilometers
# 51.9429475201  kilometers
# 2.027214302396858  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 15.764800751742449  = length of all streams in subwatershed
# 81.2238478227  = subwatershed area
# 0.19409078951978176 is the drainage density (streams/km)
# 15.764800751742449  = watershed length (longest stream in subwatershed)
# 3.059802624527741  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 198.360351563
# 119.857933044
# 0.004979601059044358  = relief ratio
# 0.07850241851899999  is the relief in km
# 0.015236596389565043  is the ruggedness number
# 10515  = total population in the subwatershed
# 39.35  = total percent of dependent population in the subwatershed
# 129.45705333922047  = population density of subwatershed (people/square km)
# 966  = number of residential building footprints in the subwatershed
# 11.893058823175176  = housing density (buildings per square km)
# -------------------- 051202070504  is the subwatershed to be worked on ------------------------
# 65.3736363964  square kilometers
# 51.1208713249  kilometers
# 0.7935263747223088  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 81.00263718767046  = length of all streams in subwatershed
# 65.3736363964  = subwatershed area
# 1.2390719203151306 is the drainage density (streams/km)
# 21.28753778058712  = watershed length (longest stream in subwatershed)
# 6.931835059811337  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 315.464889526
# 162.822372437
# 0.007170510683870647  = relief ratio
# 0.15264251708899998  is the relief in km
# 0.18913505677120235  is the ruggedness number
# 25408  = total population in the subwatershed
# 37.64  = total percent of dependent population in the subwatershed
# 388.6582023055271  = population density of subwatershed (people/square km)
# 732  = number of residential building footprints in the subwatershed
# 11.197174279268177  = housing density (buildings per square km)
# -------------------- 071200010502  is the subwatershed to be worked on ------------------------
# 68.137755414  square kilometers
# 60.0845762426  kilometers
# 1.7141200922361723  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 17.282679534596078  = length of all streams in subwatershed
# 68.137755414  = subwatershed area
# 0.25364321776653465 is the drainage density (streams/km)
# 15.441540515531875  = watershed length (longest stream in subwatershed)
# 3.4993987113907896  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 266.78213501
# 229.685089111
# 0.0024024187134493434  = relief ratio
# 0.037097045898999995  is the relief in km
# 0.009409414091455187  is the ruggedness number
# 24505  = total population in the subwatershed
# 42.93333333333334  = total percent of dependent population in the subwatershed
# 359.6390848379055  = population density of subwatershed (people/square km)
# 2198  = number of residential building footprints in the subwatershed
# 32.2581803090682  = housing density (buildings per square km)
# -------------------- 041000050102  is the subwatershed to be worked on ------------------------
# 87.2779446207  square kilometers
# 64.12769072  kilometers
# 1.3913742251214671  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 46.666950247451986  = length of all streams in subwatershed
# 87.2779446207  = subwatershed area
# 0.5346935064781971 is the drainage density (streams/km)
# 13.241820730043171  = watershed length (longest stream in subwatershed)
# 2.0090507058642824  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 249.956451416
# 221.546020508
# 0.002145507894057358  = relief ratio
# 0.028410430907999995  is the relief in km
# 0.015190872922755068  is the ruggedness number
# 96225  = total population in the subwatershed
# 39.84814814814814  = total percent of dependent population in the subwatershed
# 1102.5122144911052  = population density of subwatershed (people/square km)
# 7865  = number of residential building footprints in the subwatershed
# 90.11440443723089  = housing density (buildings per square km)
# -------------------- 040500011506  is the subwatershed to be worked on ------------------------
# 105.455934985  square kilometers
# 79.943893316  kilometers
# 7.09048944528799  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 46.475864805469136  = length of all streams in subwatershed
# 105.455934985  = subwatershed area
# 0.440713600539219 is the drainage density (streams/km)
# 14.959056940614467  = watershed length (longest stream in subwatershed)
# 2.121961031253246  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 321.352793376
# 269.599182129
# 0.0034596840865340124  = relief ratio
# 0.051753611247000036  is the relief in km
# 0.022808520353572406  is the ruggedness number
# 28590  = total population in the subwatershed
# 43.27142857142858  = total percent of dependent population in the subwatershed
# 271.1084966822079  = population density of subwatershed (people/square km)
# 632  = number of residential building footprints in the subwatershed
# 5.993024480697984  = housing density (buildings per square km)
# -------------------- 051201020103  is the subwatershed to be worked on ------------------------
# 55.2409826877  square kilometers
# 39.3861738431  kilometers
# 0.1714901741490826  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 44.977343171398786  = length of all streams in subwatershed
# 55.2409826877  = subwatershed area
# 0.8142024450519683 is the drainage density (streams/km)
# 9.939634155232651  = watershed length (longest stream in subwatershed)
# 1.7884607103824308  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 297.299621582
# 270.663757324
# 0.0026797630417793295  = relief ratio
# 0.02663586425799997  is the relief in km
# 0.021686985804935905  is the ruggedness number
# 12849  = total population in the subwatershed
# 43.025  = total percent of dependent population in the subwatershed
# 232.5990482942833  = population density of subwatershed (people/square km)
# 384  = number of residential building footprints in the subwatershed
# 6.951360770877484  = housing density (buildings per square km)
# -------------------- 051202080806  is the subwatershed to be worked on ------------------------
# 102.175423169  square kilometers
# 78.7974286085  kilometers
# 0.47190713919203453  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 53.17850029887521  = length of all streams in subwatershed
# 102.175423169  = subwatershed area
# 0.5204627360428643 is the drainage density (streams/km)
# 18.571503677668378  = watershed length (longest stream in subwatershed)
# 3.3755744596151858  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 284.307525635
# 147.602767944
# 0.0073609956449236244  = relief ratio
# 0.136704757691  is the relief in km
# 0.07114973221793465  is the ruggedness number
# 23740  = total population in the subwatershed
# 40.260000000000005  = total percent of dependent population in the subwatershed
# 232.34550211486388  = population density of subwatershed (people/square km)
# 1275  = number of residential building footprints in the subwatershed
# 12.478538972049344  = housing density (buildings per square km)
# -------------------- 051401010404  is the subwatershed to be worked on ------------------------
# 74.4776585775  square kilometers
# 48.6724012829  kilometers
# 0.43841974627998537  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 53.36502595316356  = length of all streams in subwatershed
# 74.4776585775  = subwatershed area
# 0.71652394788476 is the drainage density (streams/km)
# 21.360537682870877  = watershed length (longest stream in subwatershed)
# 6.126301213223002  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 222.260757446
# 127.644393921
# 0.004429493532874566  = relief ratio
# 0.09461636352500001  is the relief in km
# 0.06779489032743262  is the ruggedness number
# 19716  = total population in the subwatershed
# 37.8  = total percent of dependent population in the subwatershed
# 264.723681927835  = population density of subwatershed (people/square km)
# 610  = number of residential building footprints in the subwatershed
# 8.190375632784507  = housing density (buildings per square km)
# -------------------- 050800030303  is the subwatershed to be worked on ------------------------
# 73.5638559064  square kilometers
# 46.2051839836  kilometers
# 0.34382440958737026  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 69.52165756610489  = length of all streams in subwatershed
# 73.5638559064  = subwatershed area
# 0.9450518425048539 is the drainage density (streams/km)
# 14.5427707886708  = watershed length (longest stream in subwatershed)
# 2.8749469369973184  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 351.917541504
# 291.305938721
# 0.004167816688015051  = relief ratio
# 0.060611602782999964  is the relief in km
# 0.05728110688724644  is the ruggedness number
# 21456  = total population in the subwatershed
# 42.03333333333333  = total percent of dependent population in the subwatershed
# 291.6649723649593  = population density of subwatershed (people/square km)
# 590  = number of residential building footprints in the subwatershed
# 8.0202429947486  = housing density (buildings per square km)
# -------------------- 040500011001  is the subwatershed to be worked on ------------------------
# 89.5156258895  square kilometers
# 74.9190753237  kilometers
# 3.611148403196092  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 40.565908947551115  = length of all streams in subwatershed
# 89.5156258895  = subwatershed area
# 0.4531712597041609 is the drainage density (streams/km)
# 13.570150047357997  = watershed length (longest stream in subwatershed)
# 2.057171253375669  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 357.144714355
# 302.51361084
# 0.004025828994104325  = relief ratio
# 0.05463110351500001  is the relief in km
# 0.024757245998920964  is the ruggedness number
# 18410  = total population in the subwatershed
# 38.550000000000004  = total percent of dependent population in the subwatershed
# 205.66241722674985  = population density of subwatershed (people/square km)
# 313  = number of residential building footprints in the subwatershed
# 3.4965962298735853  = housing density (buildings per square km)
# -------------------- 051201030404  is the subwatershed to be worked on ------------------------
# 52.7329083001  square kilometers
# 49.7706513403  kilometers
# 0.6058537599205088  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 42.69501723204514  = length of all streams in subwatershed
# 52.7329083001  = subwatershed area
# 0.8096465491542816 is the drainage density (streams/km)
# 14.939248871889403  = watershed length (longest stream in subwatershed)
# 4.232293724179547  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 295.004211426
# 254.56338501
# 0.002707018723819235  = relief ratio
# 0.04044082641599999  is the relief in km
# 0.0327427755526617  is the ruggedness number
# 28335  = total population in the subwatershed
# 41.166666666666664  = total percent of dependent population in the subwatershed
# 537.3305003158013  = population density of subwatershed (people/square km)
# 351  = number of residential building footprints in the subwatershed
# 6.656185128316436  = housing density (buildings per square km)
# -------------------- 051201060509  is the subwatershed to be worked on ------------------------
# 73.6909909758  square kilometers
# 73.4981101587  kilometers
# 1.5962801609292552  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 34.4032040459527  = length of all streams in subwatershed
# 73.6909909758  = subwatershed area
# 0.46685766591537153 is the drainage density (streams/km)
# 22.409874624689785  = watershed length (longest stream in subwatershed)
# 6.814977978233968  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 280.32421875
# 220.666549683
# 0.0026621152534817374  = relief ratio
# 0.059657669067  is the relief in km
# 0.02785164013457128  is the ruggedness number
# 15559  = total population in the subwatershed
# 42.275  = total percent of dependent population in the subwatershed
# 211.1384281032338  = population density of subwatershed (people/square km)
# 527  = number of residential building footprints in the subwatershed
# 7.151484774754432  = housing density (buildings per square km)
# -------------------- 050902030507  is the subwatershed to be worked on ------------------------
# 64.6085585738  square kilometers
# 41.4196077106  kilometers
# 1.4952894491722966  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 31.77738878425441  = length of all streams in subwatershed
# 64.6085585738  = subwatershed area
# 0.491844880705027 is the drainage density (streams/km)
# 16.224503798164537  = watershed length (longest stream in subwatershed)
# 4.074298038950557  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 307.250213623
# 233.029754639
# 0.004574590379300011  = relief ratio
# 0.07422045898399998  is the relief in km
# 0.03650495279485782  is the ruggedness number
# 16528  = total population in the subwatershed
# 40.075  = total percent of dependent population in the subwatershed
# 255.81750103774053  = population density of subwatershed (people/square km)
# 572  = number of residential building footprints in the subwatershed
# 8.85331622662074  = housing density (buildings per square km)
# -------------------- 051201080410  is the subwatershed to be worked on ------------------------
# 95.8676968971  square kilometers
# 50.6726654269  kilometers
# 0.265943692582386  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 35.281698446071154  = length of all streams in subwatershed
# 95.8676968971  = subwatershed area
# 0.368024888341074 is the drainage density (streams/km)
# 21.17124474223418  = watershed length (longest stream in subwatershed)
# 4.675418503238676  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 237.351089477
# 151.799835205
# 0.004040917542336807  = relief ratio
# 0.085551254272  is the relief in km
# 0.03148499080089163  is the ruggedness number
# 8247  = total population in the subwatershed
# 41.8  = total percent of dependent population in the subwatershed
# 86.02480571586018  = population density of subwatershed (people/square km)
# 120  = number of residential building footprints in the subwatershed
# 1.2517250740758121  = housing density (buildings per square km)
# -------------------- 051201040705  is the subwatershed to be worked on ------------------------
# 102.830668685  square kilometers
# 51.7628163274  kilometers
# 0.6616823413712662  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 55.744585177699136  = length of all streams in subwatershed
# 102.830668685  = subwatershed area
# 0.5421007749007339 is the drainage density (streams/km)
# 15.863286810633065  = watershed length (longest stream in subwatershed)
# 2.447167480815113  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 241.964950562
# 176.265838623
# 0.004141582556205331  = relief ratio
# 0.06569911193900001  is the relief in km
# 0.035615539492421966  is the ruggedness number
# 27808  = total population in the subwatershed
# 40.9875  = total percent of dependent population in the subwatershed
# 270.4251596883409  = population density of subwatershed (people/square km)
# 1992  = number of residential building footprints in the subwatershed
# 19.371652693439838  = housing density (buildings per square km)
# -------------------- 051201111202  is the subwatershed to be worked on ------------------------
# 84.46754768  square kilometers
# 62.0703843857  kilometers
# 0.20428664956526774  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 36.46422409361597  = length of all streams in subwatershed
# 84.46754768  = subwatershed area
# 0.43169507219220327 is the drainage density (streams/km)
# 16.314801004393203  = watershed length (longest stream in subwatershed)
# 3.151183373066875  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 184.293922424
# 138.904487611
# 0.0027821016511802776  = relief ratio
# 0.04538943481299998  is the relief in km
# 0.01959439533836133  is the ruggedness number
# 12752  = total population in the subwatershed
# 38.0  = total percent of dependent population in the subwatershed
# 150.96922250318136  = population density of subwatershed (people/square km)
# 172  = number of residential building footprints in the subwatershed
# 2.0362849961219567  = housing density (buildings per square km)
# -------------------- 051202080801  is the subwatershed to be worked on ------------------------
# 65.0754672818  square kilometers
# 38.0520765358  kilometers
# 0.3344569830446755  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 17.32759346310396  = length of all streams in subwatershed
# 65.0754672818  = subwatershed area
# 0.2662692130671808 is the drainage density (streams/km)
# 9.866218783040262  = watershed length (longest stream in subwatershed)
# 1.4958367129857044  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 288.167022705
# 189.717224121
# 0.009978473085680234  = relief ratio
# 0.09844979858400003  is the relief in km
# 0.02621415039558414  is the ruggedness number
# 112998  = total population in the subwatershed
# 25.11739130434782  = total percent of dependent population in the subwatershed
# 1736.4147307721714  = population density of subwatershed (people/square km)
# 8069  = number of residential building footprints in the subwatershed
# 123.9944995716796  = housing density (buildings per square km)
# -------------------- 051201081205  is the subwatershed to be worked on ------------------------
# 85.6550095085  square kilometers
# 46.7284699817  kilometers
# 0.2800626554229368  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 40.029472655341436  = length of all streams in subwatershed
# 85.6550095085  = subwatershed area
# 0.46733370161343685 is the drainage density (streams/km)
# 15.19175146579718  = watershed length (longest stream in subwatershed)
# 2.6944053117599425  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 293.166625977
# 207.492721558
# 0.0056395014499734854  = relief ratio
# 0.08567390441900002  is the relief in km
# 0.04003830288380707  is the ruggedness number
# 13139  = total population in the subwatershed
# 37.36666666666667  = total percent of dependent population in the subwatershed
# 153.39441412000716  = population density of subwatershed (people/square km)
# 139  = number of residential building footprints in the subwatershed
# 1.6227889156466242  = housing density (buildings per square km)
# -------------------- 051202010610  is the subwatershed to be worked on ------------------------
# 71.6819160283  square kilometers
# 60.6485559531  kilometers
# 6.702400088841462  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 46.24355297267925  = length of all streams in subwatershed
# 71.6819160283  = subwatershed area
# 0.645121608557761 is the drainage density (streams/km)
# 19.24808251020342  = watershed length (longest stream in subwatershed)
# 5.168509728078837  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 279.313049316
# 225.284225464
# 0.002806971750217679  = relief ratio
# 0.05402882385199999  is the relief in km
# 0.03485516175188616  is the ruggedness number
# 51728  = total population in the subwatershed
# 39.614285714285714  = total percent of dependent population in the subwatershed
# 721.6324962571844  = population density of subwatershed (people/square km)
# 2268  = number of residential building footprints in the subwatershed
# 31.63977925903368  = housing density (buildings per square km)
# -------------------- 051201081104  is the subwatershed to be worked on ------------------------
# 50.2126656839  square kilometers
# 38.9876171028  kilometers
# 0.08785760030976318  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 17.0334332279828  = length of all streams in subwatershed
# 50.2126656839  = subwatershed area
# 0.33922583069403417 is the drainage density (streams/km)
# 16.963529344929352  = watershed length (longest stream in subwatershed)
# 5.730851447875748  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 206.792999268
# 143.15637207
# 0.0037513789674329715  = relief ratio
# 0.06363662719799998  is the relief in km
# 0.02158718772380811  is the ruggedness number
# 2740  = total population in the subwatershed
# 43.3  = total percent of dependent population in the subwatershed
# 54.56790558081332  = population density of subwatershed (people/square km)
# 16  = number of residential building footprints in the subwatershed
# 0.3186447041215376  = housing density (buildings per square km)
# -------------------- 051202060107  is the subwatershed to be worked on ------------------------
# 103.502404427  square kilometers
# 70.3664408061  kilometers
# 0.6377145273918381  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 48.410770153582426  = length of all streams in subwatershed
# 103.502404427  = subwatershed area
# 0.4677260438691202 is the drainage density (streams/km)
# 29.41636658070887  = watershed length (longest stream in subwatershed)
# 8.360410829112242  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 233.699447632
# 180.579803467
# 0.0018057853616712683  = relief ratio
# 0.05311964416499998  is the relief in km
# 0.024845441017030834  is the ruggedness number
# 33702  = total population in the subwatershed
# 39.528571428571425  = total percent of dependent population in the subwatershed
# 325.6156239710348  = population density of subwatershed (people/square km)
# 1776  = number of residential building footprints in the subwatershed
# 17.159021665555688  = housing density (buildings per square km)
# -------------------- 051402010907  is the subwatershed to be worked on ------------------------
# 85.2424469119  square kilometers
# 65.9498442209  kilometers
# 4.91869832927951  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 31.68218338592014  = length of all streams in subwatershed
# 85.2424469119  = subwatershed area
# 0.37167144461097407 is the drainage density (streams/km)
# 21.29112310051758  = watershed length (longest stream in subwatershed)
# 5.31791307386919  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 197.29536438
# 114.280525208
# 0.0038990352354865646  = relief ratio
# 0.08301483917199999  is the relief in km
# 0.030854245199204915  is the ruggedness number
# 17536  = total population in the subwatershed
# 41.3  = total percent of dependent population in the subwatershed
# 205.71910632884405  = population density of subwatershed (people/square km)
# 138  = number of residential building footprints in the subwatershed
# 1.6189117628524452  = housing density (buildings per square km)
# -------------------- 051201111512  is the subwatershed to be worked on ------------------------
# 80.5298287048  square kilometers
# 67.6456003895  kilometers
# 0.589329434377715  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 27.40801195412724  = length of all streams in subwatershed
# 80.5298287048  = subwatershed area
# 0.34034608535673666 is the drainage density (streams/km)
# 23.494152365896422  = watershed length (longest stream in subwatershed)
# 6.854294914935736  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 171.587539673
# 127.895881653
# 0.0018596822451624952  = relief ratio
# 0.04369165802  is the relief in km
# 0.01487028476985227  is the ruggedness number
# 14733  = total population in the subwatershed
# 35.0  = total percent of dependent population in the subwatershed
# 182.95084240160364  = population density of subwatershed (people/square km)
# 118  = number of residential building footprints in the subwatershed
# 1.465295554428102  = housing density (buildings per square km)
# -------------------- 050902030505  is the subwatershed to be worked on ------------------------
# 60.6315492247  square kilometers
# 51.33679991  kilometers
# 0.5168880744216896  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 33.66443679365893  = length of all streams in subwatershed
# 60.6315492247  = subwatershed area
# 0.5552296984676874 is the drainage density (streams/km)
# 25.827738404791063  = watershed length (longest stream in subwatershed)
# 11.002062121720753  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 316.117675781
# 259.264862061
# 0.0022012308173856134  = relief ratio
# 0.05685281372000003  is the relief in km
# 0.03156637061879522  is the ruggedness number
# 14588  = total population in the subwatershed
# 41.300000000000004  = total percent of dependent population in the subwatershed
# 240.60081239120242  = population density of subwatershed (people/square km)
# 205  = number of residential building footprints in the subwatershed
# 3.381078046352927  = housing density (buildings per square km)
# -------------------- 051401041105  is the subwatershed to be worked on ------------------------
# 73.7847172189  square kilometers
# 60.7767398996  kilometers
# 0.37053182128100104  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 37.663040246973104  = length of all streams in subwatershed
# 73.7847172189  = subwatershed area
# 0.5104450036074095 is the drainage density (streams/km)
# 37.63032924528098  = watershed length (longest stream in subwatershed)
# 19.191530881757302  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 267.642395019
# 122.105308533
# 0.0038675475183159876  = relief ratio
# 0.145537086486  is the relief in km
# 0.07428867863635814  is the ruggedness number
# 6855  = total population in the subwatershed
# 44.65  = total percent of dependent population in the subwatershed
# 92.90541806459736  = population density of subwatershed (people/square km)
# 238  = number of residential building footprints in the subwatershed
# 3.225600218727086  = housing density (buildings per square km)
# -------------------- 051202020904  is the subwatershed to be worked on ------------------------
# 45.8539348671  square kilometers
# 35.6046900561  kilometers
# 0.18004218276101944  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 21.534351687754363  = length of all streams in subwatershed
# 45.8539348671  = subwatershed area
# 0.46962930771738776 is the drainage density (streams/km)
# 7.567379644636025  = watershed length (longest stream in subwatershed)
# 1.2488619537674446  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 188.664230347
# 132.399353027
# 0.007435186281407483  = relief ratio
# 0.05626487732000001  is the relief in km
# 0.026423635384595356  is the ruggedness number
# 12477  = total population in the subwatershed
# 41.16666666666667  = total percent of dependent population in the subwatershed
# 272.1031474433439  = population density of subwatershed (people/square km)
# 76  = number of residential building footprints in the subwatershed
# 1.6574368202047076  = housing density (buildings per square km)
# -------------------- 051402010908  is the subwatershed to be worked on ------------------------
# 123.7922709  square kilometers
# 68.7374772253  kilometers
# 2.609732655549812  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 38.800580714911675  = length of all streams in subwatershed
# 123.7922709  = subwatershed area
# 0.31343298279304505 is the drainage density (streams/km)
# 13.457101515398884  = watershed length (longest stream in subwatershed)
# 1.4628827783766825  is the shape factor.
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
# 170.768258412
# 114.241691589
# 0.004200500884853768  = relief ratio
# 0.056526566822999995  is the relief in km
# 0.017717290446383267  is the ruggedness number
# 9659  = total population in the subwatershed
# 42.63333333333333  = total percent of dependent population in the subwatershed
# 78.02587293840492  = population density of subwatershed (people/square km)
# 317  = number of residential building footprints in the subwatershed
# 2.56074145578987  = housing density (buildings per square km)
# -------------------- 051201130707  is the subwatershed to be worked on ------------------------
# 42.7068394581  square kilometers
# 37.3809796229  kilometers
# 0.26713413838658445  = area of all water bodies in the subwatershed (square km)
# streams clipped
# length calculated
# 7.891747789607176  = length of all streams in subwatershed
# 42.7068394581  = subwatershed area
# 0.18478885091344277 is the drainage density (streams/km)
# 7.875213753638418  = watershed length (longest stream in subwatershed)
# 1.4522027959091424  is the shape factor.
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# <ipython-input-12-be0bd5b170a4> in <module>
#      72         #use Raster Domain tool to get z-enabled polyline of perimeter
#      73         dem_clip = os.path.join(path, "working_dsn\dem_clip.tif")
# ---> 74         arcpy.Clip_management(dem_Indiana, "#", dem_clip, subwatershed_selection1, "#", "ClippingGeometry", "NO_MAINTAIN_EXTENT")
#      75         perimeter_polyline = "perimeter_polyline.shp"
#      76         arcpy.RasterDomain_3d(dem_clip, perimeter_polyline, "LINE")
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in Clip(in_raster, rectangle, out_raster, in_template_dataset, nodata_value, clipping_geometry, maintain_clipping_extent)
#   17374         return retval
#   17375     except Exception as e:
# > 17376         raise e
#   17377
#   17378 @gptooldoc('CompositeBands_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in Clip(in_raster, rectangle, out_raster, in_template_dataset, nodata_value, clipping_geometry, maintain_clipping_extent)
#   17371     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#   17372     try:
# > 17373         retval = convertArcObjectToPythonObject(gp.Clip_management(*gp_fixargs((in_raster, rectangle, out_raster, in_template_dataset, nodata_value, clipping_geometry, maintain_clipping_extent), True)))
#   17374         return retval
#   17375     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     509         val = getattr(self._gp, attr)
#     510         if callable(val):
# --> 511             return lambda *args: val(*gp_fixargs(args, True))
#     512         else:
#     513             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# Failed to execute (Clip).

# %%
st = time()
outputs = {'subwatershed': subwatershed_list[0:54],
          'area': area_list[0:54],
          'perimeter': perimeter_list[0:54],
           'watershed_length': watershed_length_list[0:54],
           'drainage_density': drainage_density_list[0:54],
           'shape_factor': shape_factor_list[0:54],
           'ruggedness': ruggedness_list[0:54],
           'population_density': population_density_list[0:54],
        'housing_density': housing_density_list[0:54]

          }

# %%
len(relief_list[0:54])
# Out:
# 0

# %%
            
outputs_df = pd.DataFrame(outputs, columns = ['subwatershed',
                                             'area',
                                             'perimeter',
                                              'watershed_length',
                                              'drainage_density',
                                              'shape_factor',

                                              'ruggedness',
  
                                              'population_density',
                                              'housing_density'
                                             ])    
    

print(outputs_df)

outputs_df.to_excel(os.path.join(path,"working_dsn\\hotfix_55_79.xlsx"))
print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
#     subwatershed        area  perimeter  watershed_length  drainage_density  \
# 0   051201111902   61.761169  43.804517         10.968176          0.394936
# 1   051202081501   50.714370  40.871454         13.401044          1.115019
# 2   051202060503   89.250010  53.837944         19.609010          0.471833
# 3   051202030602  111.004174  52.592319         17.970408          0.442865
# 4   051202090103   53.482356  42.146695          6.825770          0.408121
# 5   040400010303  106.113980  54.564815         22.378411          0.526786
# 6   051202011502   84.163373  53.983431         27.249228          0.472058
# 7   051201040506   57.307052  41.029073         13.744430          0.603376
# 8   051201060205   53.340016  53.372845         17.794604          0.509941
# 9   040400010503   54.662910  45.843821         13.282991          0.369231
# 10  051202040302   97.520500  52.160755         24.530596          0.568467
# 11  050902031007   61.275631  37.933460         15.381703          0.609642
# 12  051201130704   62.955786  46.481066          8.652663          0.273515
# 13  071200021301   61.693751  45.057619          9.514784          0.599702
# 14  051202010103   53.082529  37.245531         11.974105          0.379876
# 15  051202040603   71.908312  60.410080         10.928427          0.620997
# 16  051201070101   50.824330  49.175631         19.498480          0.460383
# 17  051201100602   43.929384  40.256018          6.123102          0.139385
# 18  051202060301   44.677815  34.896828         15.912010          0.356150
# 19  051202070303   75.071458  42.635340         22.252292          0.573442
# 20  051201070109   67.535587  40.928397         11.968376          0.364623
# 21  051401040302   67.891583  49.072959         24.396661          0.669997
# 22  051201100402   70.340447  57.610779         24.999915          0.548568
# 23  050800030803   76.678444  53.677642         22.627244          0.401561
# 24  071200010703   66.973366  46.911401         11.371938          0.815606
# 25  051201040304   90.255014  77.422646         14.715277          0.526084
# 26  051202040806   72.482080  53.258194         20.611823          0.719072
# 27  051402010501   81.223848  51.942948         15.764801          0.194091
# 28  051202070504   65.373636  51.120871         21.287538          1.239072
# 29  071200010502   68.137755  60.084576         15.441541          0.253643
# 30  041000050102   87.277945  64.127691         13.241821          0.534694
# 31  040500011506  105.455935  79.943893         14.959057          0.440714
# 32  051201020103   55.240983  39.386174          9.939634          0.814202
# 33  051202080806  102.175423  78.797429         18.571504          0.520463
# 34  051401010404   74.477659  48.672401         21.360538          0.716524
# 35  050800030303   73.563856  46.205184         14.542771          0.945052
# 36  040500011001   89.515626  74.919075         13.570150          0.453171
# 37  051201030404   52.732908  49.770651         14.939249          0.809647
# 38  051201060509   73.690991  73.498110         22.409875          0.466858
# 39  050902030507   64.608559  41.419608         16.224504          0.491845
# 40  051201080410   95.867697  50.672665         21.171245          0.368025
# 41  051201040705  102.830669  51.762816         15.863287          0.542101
# 42  051201111202   84.467548  62.070384         16.314801          0.431695
# 43  051202080801   65.075467  38.052077          9.866219          0.266269
# 44  051201081205   85.655010  46.728470         15.191751          0.467334
# 45  051202010610   71.681916  60.648556         19.248083          0.645122
# 46  051201081104   50.212666  38.987617         16.963529          0.339226
# 47  051202060107  103.502404  70.366441         29.416367          0.467726
# 48  051402010907   85.242447  65.949844         21.291123          0.371671
# 49  051201111512   80.529829  67.645600         23.494152          0.340346
# 50  050902030505   60.631549  51.336800         25.827738          0.555230
# 51  051401041105   73.784717  60.776740         37.630329          0.510445
# 52  051202020904   45.853935  35.604690          7.567380          0.469629
# 53  051402010908  123.792271  68.737477         13.457102          0.313433
#
#     shape_factor  ruggedness  population_density  housing_density
# 0       1.947840    0.024346          419.729750        18.895368
# 1       3.541165    0.078500          355.126173        20.211234
# 2       4.308271    0.030208          203.876729         2.913165
# 3       2.909220    0.024857          102.320477         2.243159
# 4       0.871150    0.043595          140.494932         3.197316
# 5       4.719390    0.045034          790.517893        58.342925
# 6       8.822370    0.048583          203.473309         9.517204
# 7       3.296441    0.025514          203.186161         3.472522
# 8       5.936405    0.018843          592.744475        13.498309
# 9       3.227743    0.014098         1543.642662        75.352739
# 10      6.170499    0.016528          380.914782        49.363980
# 11      3.861189    0.092303          125.873857         4.634795
# 12      1.189225    0.017875          127.486297         8.132692
# 13      1.467428    0.016549           49.032519         0.842873
# 14      2.701062    0.019528          238.929835         3.221399
# 15      1.660872    0.037148          932.604292        59.951345
# 16      7.480487    0.009213          299.423522         6.945492
# 17      0.853469    0.008979          403.283599         8.058388
# 18      5.667065    0.024159          433.996153        43.981560
# 19      6.595909    0.043837          132.407179         6.726924
# 20      2.120986    0.009277          822.129521        79.972652
# 21      8.766876    0.070380          510.313626        30.430871
# 22      8.885297    0.029989          371.635399        11.074709
# 23      6.677133    0.061660           82.852490         3.012581
# 24      1.930931    0.015895           95.142299         3.613377
# 25      2.399195    0.022583          256.229533         5.706054
# 26      5.861411    0.036166          496.301986         9.657560
# 27      3.059803    0.015237          129.457053        11.893059
# 28      6.931835    0.189135          388.658202        11.197174
# 29      3.499399    0.009409          359.639085        32.258180
# 30      2.009051    0.015191         1102.512214        90.114404
# 31      2.121961    0.022809          271.108497         5.993024
# 32      1.788461    0.021687          232.599048         6.951361
# 33      3.375574    0.071150          232.345502        12.478539
# 34      6.126301    0.067795          264.723682         8.190376
# 35      2.874947    0.057281          291.664972         8.020243
# 36      2.057171    0.024757          205.662417         3.496596
# 37      4.232294    0.032743          537.330500         6.656185
# 38      6.814978    0.027852          211.138428         7.151485
# 39      4.074298    0.036505          255.817501         8.853316
# 40      4.675419    0.031485           86.024806         1.251725
# 41      2.447167    0.035616          270.425160        19.371653
# 42      3.151183    0.019594          150.969223         2.036285
# 43      1.495837    0.026214         1736.414731       123.994500
# 44      2.694405    0.040038          153.394414         1.622789
# 45      5.168510    0.034855          721.632496        31.639779
# 46      5.730851    0.021587           54.567906         0.318645
# 47      8.360411    0.024845          325.615624        17.159022
# 48      5.317913    0.030854          205.719106         1.618912
# 49      6.854295    0.014870          182.950842         1.465296
# 50     11.002062    0.031566          240.600812         3.381078
# 51     19.191531    0.074289           92.905418         3.225600
# 52      1.248862    0.026424          272.103147         1.657437
# 53      1.462883    0.017717           78.025873         2.560741
# 0.79 minutes to process.

# %%
len(outputs['population_density'])
# Out:
# 54
