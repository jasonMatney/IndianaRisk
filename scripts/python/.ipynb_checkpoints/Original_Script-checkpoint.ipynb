# %%
#########################################################################
#Data Collection 
#
# Functions for handling subwatershed characteristics data collection
#
# Authors: Shannon McAvoy (smcavoy@dewberry.com)
#
# Editor: Jason Matney (jmatney@dewberry.com)
#
# Copyright: Dewberry Engineers Inc.
#########################################################################

# %%
import pandas as pd
import arcpy
import numpy as np
from numpy import mean
from numpy import std
import os
from arcpy import management
from arcgis.gis import GIS
from time import time

# %%
# Login for ArcPro, AGOL or API Server 
#gis = GIS("https://www.arcgis.com", username="dpiazza_dewberry", password="*****")

# %%
path = "C:\\Users\jmatney\Documents\GitHub\IndianaRisk\data\Indiana_ML"
hucs = "C:\\Users\jmatney\Documents\GitHub\IndianaRisk\data\shp"

# %%
arcpy.env.overwriteOutput = True

# %%
st = time()

# Set Local Variables
output_workspace = os.path.join(path, "working_dsn")

arcpy.env.workspace = output_workspace

##### change these based on what subwatersheds you want #####

# all_subwatersheds = r"P:\Temp\McAvoy\ML_DataCollection\Indiana_ML\Indiana_HUC12_groups\1.shp"
all_subwatersheds = os.path.join(hucs, "wbdhu12_a_IN_only.shp")

# All centroids of subwatersheds
all_centroids = os.path.join(hucs, "wbdhu12_a_IN_only_centroids.shp")

#set source for streams data
streams = os.path.join(path, "Indiana_50c_streams_edited\Hydrography_HighRes_FlowLine_NHD_USGS.shp")

#####these are the same for all subwatersheds in Indiana#####

#set source for dem
dem_Indiana = os.path.join(path, "IN_EXTENT_MOSAIC\IN_EXTENT_MOSAIC.tif")

#set source for slope dem
dem_slope = os.path.join(path, "Indiana_SlopeRaster\IN_ext_slope")

#set source for NHFL Data
nfhl_sfha = os.path.join(path, "NFHL_18_20200310.gdb\S_FLD_HAZ_AR")


#set source for water bodies data 
water_bodies = os.path.join(path, "IndianaMAP_WaterBodies\Water_Bodies_Lakes_LocalRes\Hydrography_LocalRes_WaterbodyDiscrete_NHD_IN.shp")

#set source for dams data 
dams = os.path.join(path, "IndianaMAP_Dams\Dams_IDNR\Dams_IDNR_IN.shp")

#set source for bridges data
bridges = os.path.join(path, "IndianaMAP_Bridges\Bridges_County_INDOT\Bridges_County_INDOT_IN.shp")

#set source for streets data
streets = os.path.join(path, "IndianaMAP_Streets\Streets_Centerlines_IGIO\County_Street_Centerlines_IGIO_IN.gdb\County_Street_Centerlines_IGIO_IN_Dec2019")


#set source for railraods data
railroads = os.path.join(path, "IndianaMAP_Railroads\Railroads_Active_Abandoned_INDOT\Rail_System_Active_Abandoned_INDOT_IN.shp")

#set source for ACS population data
population = os.path.join(path, "Indiana_PopulationData\Indiana_PopulationData.shp")

#set source for ACS median income data 
median_income = os.path.join(path, "Indiana_IncomeData\Indiana_IncomeData.shp")

#set source for county boundary data
county_boundary = os.path.join(path, "MarionCounty_Boundary\Marion_County_Boundary.shp")

#source for Bing building footprints for Indiana (attrubuted with open street maps data)
building_footprints = os.path.join(path, "BuildingFootprints_Indiana\Building_Footprints_Attributed_IN.shp")

#folder with partial duration files, set as workspace temporarily, then reset when done
directory_rainfall = os.path.join(path, "MarionCounty_Rainfall\All_Rainfall_Clipped_IN")

#set source for nlcd land use data
lu_usa = os.path.join(path, r"NLCD_Impervious\NLCD_indiana_polygon.shp")

#set source for impervious indicator data
impervious_usa = os.path.join(path, "NLCD_Impervious\\NLCD_2016_Impervious_L48_20190405_PERCENT\\NLCD_2016_Impervious_L48_20190405.img")



subwatershed_list = []
area_list = []
perimeter_list = []
watershed_length_list = []
elongation_ratio_list = []
shape_factor_list = []
circulatory_ratio_list = []
relief_list = []
relief_ratio_list = []
avg_slope_list = []
drainage_density_list = []
ruggedness_list = []
aae_list = []
buildings_aae_list = []
x_list = []
buildings_x_list = []
water_bodies_list = []
dams_list = []
bridges_list = []
streets_list = []
railroads_list = []
population_list = []
dependent_population_list = []
population_density_list = []
avg_median_income_list = []
housing_density_list = []
population_change_list = []
dist_to_stream_avg_list = []
dist_to_stream_stdev_list = []

lu_21_list = []
lu_22_list = []
lu_23_list = []
lu_24_list = []
lu_41_list = []
lu_82_list = []
impervious_percent_list = []

orb100yr06h_list = []
orb100yr12h_list = []
orb100yr24h_list = []
orb25yr06h_list = []
orb25yr12h_list = []
orb25yr24h_list = []
orb2yr06h_list = []
orb2yr12h_list = []
orb2yr24h_list = []
orb50yr06h_list = []
orb50yr12h_list = []
orb50yr24h_list = []
orb100yr06ha_am_list = []
orb100yr12ha_am_list = []
orb100yr24ha_am_list = []
orb25yr06ha_am_list = []
orb25yr12ha_am_list = []
orb25yr24ha_am_list = []
orb2yr06ha_am_list = []
orb2yr12ha_am_list = []
orb2yr24ha_am_list = []
orb50yr06ha_am_list = []
orb50yr12ha_am_list = []
orb50yr24ha_am_list = []


#########################################################################################################
print(round(((time()-st)/60), 2) , 'minutes to process.')

# %%
# GLOBAL VARIABLES
LOG_NAME = 'DataCollection_export.log'

# %%
# #search cursor through each row of county subwatersheds file
# rows = arcpy.SearchCursor(all_subwatersheds)

# row_count = 0
# for row in rows:
    
#     row_count += 1
    
#     subwatershed_number = row.getValue("HUC12")
    
#     subwatershed_list.append(subwatershed_number)
    
#     print("------ Subwatershed:", subwatershed_number, "Number", row_count, "of 1590 ------")

# %%
st = time()

row_count=366
with arcpy.da.SearchCursor(all_subwatersheds, ['HUC12']) as cursor:

    for row in cursor:
        if row[0] not in ['051202081102',	'051202080201',	'051201110302',	'051201060507',	'071200010303',	'050800030717',	'041000030604',	'051401010601',	'051401040403',	'051202050503',	'051202030203',	'040500011709',	'051201130801',	'040500010701',	'051202060310',	'051202040504',	'051201050405',	'051201040405',	'071200011009',	'051201010404',	'041000050104',	'051201111512',	'050902030505',	'051202030508',	'051202011107',	'051201100407',	'051201070103',	'050800030302',	'051201010502',	'051402010404',	'051201050504',	'051201061003',	'051201060901',	'071200010702',	'051402010801',	'040400010403',	'040500010103',	'051401041105',	'051201111902',	'051201111702',	'051202060303',	'051202011206',	'051201061208',	'051201030604',	'051201011403',	'071200010201',	'071200011403',	'041000030502',	'051202081304',	'050902030901',	'051202040401',	'051201080302',	'040500011802',	'051202070601',	'051402020105',	'051202020702',	'051201080802',	'051201020304',	'051201050104',	'071200010206',	'040500011009',	'051401010803',	'051201010401',
'071200010705',	'071200010501',	'051201030103',	'051201100302',	'051202010608',	'051201040402',	'071200010808',	'040500012104',	'051402020604',	'051202070501',	'051201030201',	'051202030303',	'051201081303',	'051201080706',	'040400010204',	'051201080506',	'071200010104',	'040500011105',	'050800030807',	'050902030601',	'051202020105',	'051202040705',	'051201110701',	'051202011002',	'051201080501',	'051201040202',	'040500011903',	'051201130704',	'050800030605',	'050800030201',	'041000040503',	'051202090406',	'051202070705',	'051201030504',	'051201020405',	'071200021301',	'051201060701',	'051402010703',	'051202010103',	'040500011003',	'051202080304',	'051201050101',	'051401010806',	'040400010103',	'051201110703',	'051202040901',	'051202010804',	'071200011305',	'071200010806',	'071200011006',	'051202021006',	'051202060601',	'051202020309',	'051201081503',	'051201060406',	'051401010605',	'051202080807',	'051202011406',	'071200011310',	'071200010312',	'051201020102',	'051202081002',	'051201070205',	'051201050501',	'071200020403',	'051401040604',	'051401040301',	'051201090704',	'050800030305',	'051201130206',	'051202020206',	'051202050301',	'051401010302',	'050800030805',	'051201040509',	'051201060303',	'051201060101',	'071200030203',	'051402010905',	'051202081509',	'051202040204',	'051201010703']:
            subwatershed_number = row[0]
#             print(subwatershed_number)
            row_count += 1

#             subwatershed_number = row.getValue("HUC12")

            subwatershed_list.append(subwatershed_number)

            print("------ Subwatershed:", subwatershed_number, "Number", row_count, "of 1590 ------")              

            #select subwatershed from shapefile with all of them
            subwatershed_selection = arcpy.SelectLayerByAttribute_management(all_subwatersheds, "NEW_SELECTION",
                                                                             "HUC12 = " + "'"+subwatershed_number+"'")

            #select centroid from shapefile with all of them
            centroid_selection = arcpy.SelectLayerByAttribute_management(all_centroids, "NEW_SELECTION",
                                                                             "HUC12 = " + "'"+subwatershed_number+"'")
            #copy selected subwatershed to it's own file
            subwatershed = arcpy.CopyFeatures_management(subwatershed_selection, "subwatershed")

            #copy selected centroid to it's own file
            centroid = arcpy.CopyFeatures_management(centroid_selection, "centroid")

            #clip dem to subwatershed area
            # dem_clip = arcpy.Clip_management(dem_Indiana, "#", "dem_clip.tif", subwatershed, "#" , "ClippingGeometry", "NO_MAINTAIN_EXTENT")
            dem_clip =  os.path.join(path, "working_dsn\dem_clip.tif")
            arcpy.Clip_management(dem_Indiana, "#", dem_clip, subwatershed_selection)
            print("clipped dem to subwatershed area")

            #calculate area of subwatershed
            arcpy.AddField_management(subwatershed, "AREA", "DOUBLE")

            area = arcpy.CalculateGeometryAttributes_management(subwatershed, "AREA AREA_GEODESIC", '', 
                                                                "SQUARE_KILOMETERS",
                                                                None)

            #print area
            rows = arcpy.SearchCursor(area)

            for row in rows:
                area = row.getValue("AREA")

            area_list.append(area)
            print(area, " square kilometers")


            #calculate perimeter of subwatershed
            arcpy.AddField_management(subwatershed, "PERIMETER", "DOUBLE")
            perimeter = arcpy.CalculateGeometryAttributes_management(subwatershed, "PERIMETER PERIMETER_LENGTH_GEODESIC",
                                                                     "KILOMETERS")

            print("perimeter calculated")

            #print perimeter
            rows = arcpy.SearchCursor(perimeter)

            for row in rows:
                perimeter = row.getValue("PERIMETER")

            perimeter_list.append(perimeter)
            print(perimeter, " kilometers")



            #get average slope using zonal statistics from slope dem
            avg_slope = arcpy.sa.ZonalStatistics(subwatershed, "FID", dem_slope, "MEAN")

            #get slope value
            avg_slope_result = arcpy.GetRasterProperties_management(avg_slope, "MAXIMUM")

            avg_slope_value = avg_slope_result.getOutput(0)

            avg_slope_list.append(avg_slope_value)

            print(avg_slope_value, " = avg slope (%)")


            #calculate circulatory ratio
            #ratio of area to the area of a circle having equal perimeter as the perimeter of drainage basin

            #area of a circle with same perimeter as above
            #C = 2(pi)r
            #r = C/(2pi)
            #A = (pi)r^2
            circle_radius = perimeter/(2*numpy.pi)
            print(circle_radius, "is the radius of a circle with the same perimeter.")
            circle_area = (numpy.pi*(circle_radius**2))
            print(circle_area, "is the area of a circle with the same perimeter.")

            #ratio of subwatershed perimeter to circle circumference
            circulatory_ratio = area / circle_area

            circulatory_ratio_list.append(circulatory_ratio)
            print(circulatory_ratio, " is the circulatory ratio")


            #calculate relief
            #elevation difference before basin outlet and highest point located in the perimeter of basin

            #find highest point on perimeter

            #use Raster Domain tool to get z-enabled polyline of perimeter
            perimeter_polyline = arcpy.RasterDomain_3d(dem_clip, "perimeter_polyline.shp", "LINE")
            print("created 3d polyline of subwatershed perimeter")

            #Convert each vertices of the polyline into points
            perimeter_points = arcpy.FeatureVerticesToPoints_management(perimeter_polyline, "perimeter_points.shp")
            print("created perimeter points")

            #get Z values into the attribute table for the points
            perimeter_points_Z = arcpy.AddZInformation_3d(perimeter_points, "Z")
            print("added z information")

            #get the max value from all of the points
            perimeter_stats = arcpy.Statistics_analysis(perimeter_points_Z, "perimeter_stats", [["Z", "MAX"], ["Z", "MIN"]])

            # Get a list of field names to display
            field_names = [i.name for i in arcpy.ListFields(perimeter_stats) if i.type != 'OID']

            # Open a cursor to extract results from stats table
            cursor = arcpy.da.SearchCursor(perimeter_stats, field_names)

            # Create a pandas dataframe to display results
            df = pd.DataFrame(data=[row for row in cursor],
                                  columns=field_names)

            print(df)

            #get the values for max Z and min Z into a format to use them

            rows = arcpy.SearchCursor(perimeter_stats)

            for row in rows:
                max_z = row.getValue("MAX_Z")
                min_z = row.getValue("MIN_Z")


            print(max_z)
            print(min_z)

            relief = max_z - min_z
            print("The relief of the subwatershed is: ", relief," meters.")

            relief_list.append(relief)



            #find area covered by A and AE zones and X NFHL Zones

            #clip to subwatershed area
            nfhl_sfha_clip = arcpy.Clip_analysis(nfhl_sfha, subwatershed, "nfhl_sfha.shp")

            #select Zone A and Zone AE
            nfhl_sfha_aae_selection = arcpy.management.SelectLayerByAttribute(nfhl_sfha_clip, "NEW_SELECTION", 
                                                               "FLD_ZONE = 'AE' Or FLD_ZONE = 'A'", None)

            #copy features to new feature class
            nfhl_sfha_aae = arcpy.CopyFeatures_management(nfhl_sfha_aae_selection, "nfhl_sfha_aae")

            #add new field for area
            nfhl_sfha_aae_addfield = arcpy.AddField_management(nfhl_sfha_aae, "AREA", "DOUBLE")

            #calculate the area for each of the features
            aae_area = arcpy.CalculateGeometryAttributes_management(nfhl_sfha_aae_addfield, "AREA AREA_GEODESIC", '', 
                                                                "SQUARE_KILOMETERS",
                                                                None)
            #get the sum of all of the areas
            aae_area_list = []  

            rows = arcpy.SearchCursor(aae_area)  
            for row in rows:  
                aae_area_feature = row.getValue("AREA")  
                aae_area_list.append(aae_area_feature)  

            aae_area_sum = sum(aae_area_list)

            aae_list.append(aae_area_sum)

            print(aae_area_sum, " = area of all AE and A zones in the subwatershed (square km)")



            #select Zone X, 0.2% chance flood area
            nfhl_sfha_x_selection = arcpy.management.SelectLayerByAttribute(nfhl_sfha_clip, "NEW_SELECTION", 
                                                               "FLD_ZONE = 'X' And ZONE_SUBTY = '0.2 PCT ANNUAL CHANCE FLOOD HAZARD'",
                                                                              None)

            #copy features to new feature class
            nfhl_sfha_x = arcpy.CopyFeatures_management(nfhl_sfha_x_selection, "nfhl_sfha_x")

            #add new field for area
            nfhl_sfha_x_addfield = arcpy.AddField_management(nfhl_sfha_x, "AREA", "DOUBLE")

            #calculate the area for each of the features
            x_area = arcpy.CalculateGeometryAttributes_management(nfhl_sfha_x_addfield, "AREA AREA_GEODESIC", '', 
                                                                "SQUARE_KILOMETERS",
                                                                None)
            #get the sum of all of the areas
            x_area_list = []  

            rows = arcpy.SearchCursor(x_area)  
            for row in rows:  
                x_area_feature = row.getValue("AREA")  
                x_area_list.append(x_area_feature)  

            x_area_sum = sum(x_area_list)

            x_list.append(x_area_sum)

            print(x_area_sum, " = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)")


            #calculate area covered by lakes/reserviors 

            #clip to subwatershed area
            water_bodies_clip = arcpy.Clip_analysis(water_bodies, subwatershed, "water_bodies.shp")

            #copy features to new feature class
            water_bodies_copy = arcpy.CopyFeatures_management(water_bodies_clip, "water_bodies_copy.shp")

            #add new field for area
            water_bodies_addfield = arcpy.AddField_management(water_bodies_copy, "AREA", "DOUBLE")

            #calculate the area for each of the features
            water_bodies_area = arcpy.CalculateGeometryAttributes_management(water_bodies_addfield, "AREA AREA_GEODESIC", '', 
                                                                "SQUARE_KILOMETERS",
                                                                None)
            #get the sum of all of the areas
            water_bodies_area_list = []  

            rows = arcpy.SearchCursor(water_bodies_area)  
            for row in rows:  
                wb_area_values = row.getValue("AREA")  
                water_bodies_area_list.append(wb_area_values)  

            water_bodies_area_sum = sum(water_bodies_area_list)

            water_bodies_list.append(water_bodies_area_sum)
            print(water_bodies_area_sum, " = area of all water bodies in the subwatershed (square km)")


            #count all of the dams in the subwatershed

            #clip dams to subwatershed
            dams_clip = arcpy.Clip_analysis(dams, subwatershed, "dams.shp")

            #count number of dam points
            dams_count = arcpy.GetCount_management(dams_clip)

            dams_list.append(dams_count)

            print(dams_count, " = number of dams in the subwatershed")



            #count all of the bridges in the subwatershed

            #clip bridges to subwatershed
            bridges_clip = arcpy.Clip_analysis(bridges, subwatershed, "bridges.shp")

            #count number of dam points
            bridges_count = arcpy.GetCount_management(bridges_clip)

            bridges_list.append(bridges_count)

            print(bridges_count, " = number of bridges in the subwatershed")



            #calculate the kilometers of streets in the subwatershed

            #clip streets to subwatershed area 
            streets_clip = arcpy.Clip_analysis(streets, subwatershed, "streets.shp")

            #add field to calculate length of each street
            streets_addfield = arcpy.AddField_management(streets_clip, "LENGTH_KM", "DOUBLE")

            #calculate the area for each of the features
            streets_length = arcpy.CalculateGeometryAttributes_management(streets_addfield, "LENGTH_KM LENGTH_GEODESIC", 
                                                                          'KILOMETERS')
            #get the sum of all of the areas
            streets_lengths_list = []  

            rows = arcpy.SearchCursor(streets_length)  
            for row in rows:  
                streets_lengths_values = row.getValue("LENGTH_KM")  
                streets_lengths_list.append(streets_lengths_values)  

            streets_length_sum = sum(streets_lengths_list)

            streets_list.append(streets_length_sum)

            print(streets_length_sum, " = sum of all streets in the subwatershed (km)")


            #calculate km of railroads in subwatershed

            #clip railroads to subwatershed area 
            railroads_clip = arcpy.Clip_analysis(railroads, subwatershed, "railroads.shp")

            #add field to calculate length of each railroad
            railroads_addfield = arcpy.AddField_management(railroads_clip, "LENGTH_KM", "DOUBLE")

            #calculate the area for each of the features
            railroads_length = arcpy.CalculateGeometryAttributes_management(railroads_addfield, "LENGTH_KM LENGTH_GEODESIC", 'KILOMETERS', 
                                                                "",
                                                                None)
            #get the sum of all of the areas
            railroads_lengths_list = []  

            rows = arcpy.SearchCursor(railroads_length)  
            for row in rows:  
                railroads_lengths_values = row.getValue("LENGTH_KM")  
                railroads_lengths_list.append(railroads_lengths_values)  

            railroads_length_sum = sum(railroads_lengths_list)

            railroads_list.append(railroads_length_sum)

            print(railroads_length_sum, " = sum of all railroads in the subwatershed (km)")   


            #ACS population data - 5 year estimates (2014-2018) gotten from ESRI Living Atlas Data
            #data is chosen to be on census tract level


            #clip to subwatershed
            population_clip = arcpy.Clip_analysis(population, subwatershed, "population.shp")

            #get total population
            #field = B01001_001E = Total Population (alias)
            #when clipped, field name changes to B01001_001

            #get the sum of all of the populations in each tract
            total_pop_list = []  

            rows = arcpy.SearchCursor(population_clip)  
            for row in rows:  
                total_pop_value = row.getValue('B01001_001') 
                total_pop_list.append(total_pop_value)  

            total_pop_sum = sum(total_pop_list)

            population_list.append(total_pop_sum)
            print(total_pop_sum, " = total population in the subwatershed") 

            #get the average of percentages of dependent age groups in each tract
            #field = B01001_calc_pctDependE = Percent of Population in Dependent Age Groups (under 18 and 65+) (alias)
            #when clipped field changes to B01001_61
            dependent_pop_list = []  

            rows = arcpy.SearchCursor(population_clip)  
            for row in rows:  
                dependent_pop_value = row.getValue('B01001__61') 
                dependent_pop_list.append(dependent_pop_value)  

            dependent_pop_avg_pct = mean(dependent_pop_list)

            dependent_population_list.append(dependent_pop_avg_pct)

            print(dependent_pop_avg_pct, " = total percent of dependent population in the subwatershed") 

            #find population density
            population_density = total_pop_sum / area

            population_density_list.append(population_density)

            print(population_density, " = population density of subwatershed (people/square km)")


            #ACS population data - 5 year estimates (2014-2018) gotten from ESRI Living Atlas Data
            #data is chosen to be on census tract level

            #clip to subwatershed
            median_income_clip = arcpy.Clip_analysis(median_income, subwatershed, "median_income.shp")

            #get average median income 
            #field = B19049_001 = Median Household Income in past 12 months 
            #^(inflation-adjusted dollars to last year of 5-year range) (alias)

            #get the sum of all of the populations in each tract
            total_median_income_list = []  

            rows = arcpy.SearchCursor(median_income_clip)  
            for row in rows:  
                median_income_value = row.getValue('B19049_001') 
                total_median_income_list.append(median_income_value)  

            median_income_average = mean(total_median_income_list)

            avg_median_income_list.append(median_income_average)

            print(median_income_average, " = average median income in the subwatershed") 


            #get housing density

            #clip building footprints to subwatershed area
            building_footprints_clip = arcpy.Clip_analysis(building_footprints, subwatershed, "building_footprints.shp")

            #select buildings that are marked residential
            building_footprints_residential = arcpy.SelectLayerByAttribute_management(building_footprints_clip, "NEW_SELECTION",
                                                                                 "RES_NONRES = 'Res'")

            #get count of how many buildings there are 
            buildings_count = arcpy.GetCount_management(building_footprints_residential)

            buildings_count_number = buildings_count.getOutput(0)
            print(buildings_count_number, " = number of residential building footprints in the subwatershed")

            #divide number of buildings by subwatershed area
            housing_density = int(buildings_count_number) / area

            housing_density_list.append(housing_density)

            print(housing_density, " = housing density (buildings per square km)")


           #find total population from the 2013 5-year ACS estimates
            #get the sum of all of the 2013 populations in each tract
            #field = DP05_0001E = TotalPopulation from the 2013 ACS 5yr estimates
            total_pop_list_2013 = []  

            rows = arcpy.SearchCursor(population_clip)  
            for row in rows:  
                total_pop_value_2013 = row.getValue('DP05_0001E')
                if total_pop_value_2013 != '0':
                    total_pop_list_2013.append(int(total_pop_value_2013))  

            total_pop_sum_2013 = sum( total_pop_list_2013)

            print(total_pop_sum_2013, " = total 2013 population in the subwatershed") 

            #find population change between 2018 and 2013
            population_change = total_pop_sum - total_pop_sum_2013

            population_change_list.append(population_change)
            print(population_change, " = population change between 2013 and 2018")




            #calculate drainage density
            #the total length of all streams and tributaries divided by basin area

            #all streams in subwatershed
            streams_clip = arcpy.Clip_analysis(streams, subwatershed, "streams")
            print("streams clipped")

            #add field for length
            streams_addfield = arcpy.AddField_management(streams_clip, "LENGTH", "DOUBLE")

            #calculate geometry 
            streams_calculate = arcpy.CalculateGeometryAttributes_management(streams_addfield, [["LENGTH", "LENGTH_GEODESIC"]], 
                                                                             "KILOMETERS")
            print("length calculated")

            #get the sum of all of the areas
            stream_length_list = []  

            rows = arcpy.SearchCursor(streams_calculate)  
            for row in rows:  
                stream_length = row.getValue("LENGTH")  
                stream_length_list.append(stream_length)  

            stream_length_sum = sum(stream_length_list)

            print(stream_length_sum, " = length of all streams in subwatershed")

            print(area, " = subwatershed area")

            drainage_density = stream_length_sum / area

            drainage_density_list.append(drainage_density)

            print(drainage_density, "is the drainage density (streams/km)")

            #find watershed length
            #watershed length = distance from outlet to watershed boundary along the main channel
            #we are assuming that the longest stream above is the main channel

            watershed_length = max(stream_length_list)

            watershed_length_list.append(watershed_length)

            print(watershed_length, " = watershed length (longest stream in subwatershed)")


            #calculate shape factor 
            #watershed length squared divided by watershed area

            shape_factor = (watershed_length**2) / area

            shape_factor_list.append(shape_factor)

            print(shape_factor, " is the shape factor.")



            #calculate relief ratio
            #relief divided by watershed length
            #length is is kilometers, convert to meters

            watershed_length_meters = watershed_length * 1000

            relief_ratio = relief / watershed_length_meters

            relief_ratio_list.append(relief_ratio)

            print(relief_ratio, " = relief ratio")


            #calculate ruggedness number
            #product of relief and drainage density

            #relief is in meters, convert first to km
            relief_km = relief / 1000
            print(relief_km, " is the relief in km")

            ruggedness = relief_km * drainage_density

            ruggedness_list.append(ruggedness)
            print(ruggedness, " is the ruggedness number")


            #calculate elongation ratio
            #ratio of diameter of a circle having the same area as the basin to the max basin length


            #diameter of circle with same area
            #A = (pi)r^2
            #r = sqrt(A/pi)
            #d = r*2

            radius = numpy.sqrt(area/numpy.pi)
            print(radius, " miles is the radius of a circle with the same area.")

            diameter = radius*2
            print(diameter, " miles is the diameter of a circle with the same area.")

            elongation_ratio = diameter / watershed_length

            elongation_ratio_list.append(elongation_ratio)


            #get number of buildings inside the aae zone

            buildings_aae_select = arcpy.SelectLayerByLocation_management(building_footprints_clip, "INTERSECT", nfhl_sfha_aae )

            buildings_aae = arcpy.CopyFeatures_management(buildings_aae_select, "buildings_aae.shp")

            buildings_aae_count = arcpy.GetCount_management(buildings_aae)

            buildings_aae_list.append(buildings_aae_count)

            #get number of buildings inside the x zone

            buildings_x_select = arcpy.SelectLayerByLocation_management(building_footprints_clip, "INTERSECT", nfhl_sfha_x )

            buildings_x = arcpy.CopyFeatures_management(buildings_x_select, "buildings_x.shp")

            buildings_x_count = arcpy.GetCount_management(buildings_x)

            buildings_x_list.append(buildings_x_count)

            #get area of various land use codes
            #clip usa land use polygon to the subwatershed
            lu_subwatershed = arcpy.Clip_analysis(lu_usa, subwatershed, "lu_subwatershed.shp")

            lu_subwatershed_area = arcpy.AddGeometryAttributes_management(lu_subwatershed, "AREA_GEODESIC", '',
                                                              "SQUARE_KILOMETERS")


            #lu 21 = developed open space
            lu_21_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
                                                                                 "gridcode = 21")

            lu_21 = arcpy.CopyFeatures_management(lu_21_select, "lu_21.shp")

            #get the sum of all of the areas
            lu_21_polygons_list = []  

            rows = arcpy.SearchCursor(lu_21)  
            for row in rows:  
                lu_21_polygon = row.getValue("AREA_GEO")  
                lu_21_polygons_list.append(lu_21_polygon)  

            lu_21_area_sum = sum(lu_21_polygons_list)

            lu_21_list.append(lu_21_area_sum)



            #lu 22 = developed low intensity
            lu_22_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
                                                                                 "gridcode = 22")

            lu_22 = arcpy.CopyFeatures_management(lu_22_select, "lu_22.shp")

            #get the sum of all of the areas
            lu_22_polygons_list = []  

            rows = arcpy.SearchCursor(lu_22)  
            for row in rows:  
                lu_22_polygon = row.getValue("AREA_GEO")  
                lu_22_polygons_list.append(lu_22_polygon)  

            lu_22_area_sum = sum(lu_22_polygons_list)

            lu_22_list.append(lu_22_area_sum)


            #lu 23 = developed medium intensity
            lu_23_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
                                                                                 "gridcode = 23")

            lu_23 = arcpy.CopyFeatures_management(lu_23_select, "lu_23.shp")

            #get the sum of all of the areas
            lu_23_polygons_list = []  

            rows = arcpy.SearchCursor(lu_23)  
            for row in rows:  
                lu_23_polygon = row.getValue("AREA_GEO")  
                lu_23_polygons_list.append(lu_23_polygon)  

            lu_23_area_sum = sum(lu_23_polygons_list)

            lu_23_list.append(lu_23_area_sum)



            #lu 24 = developed high intensity
            lu_24_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
                                                                                 "gridcode = 24")

            lu_24 = arcpy.CopyFeatures_management(lu_24_select, "lu_24.shp")

            #get the sum of all of the areas
            lu_24_polygons_list = []  

            rows = arcpy.SearchCursor(lu_24)  
            for row in rows:  
                lu_24_polygon = row.getValue("AREA_GEO")  
                lu_24_polygons_list.append(lu_24_polygon)  

            lu_24_area_sum = sum(lu_24_polygons_list)

            lu_24_list.append(lu_24_area_sum)



            #lu 41 = deciduous forest
            lu_41_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
                                                                                 "gridcode = 41")

            lu_41 = arcpy.CopyFeatures_management(lu_41_select, "lu_41.shp")

            #get the sum of all of the areas
            lu_41_polygons_list = []  

            rows = arcpy.SearchCursor(lu_41)  
            for row in rows:  
                lu_41_polygon = row.getValue("AREA_GEO")  
                lu_41_polygons_list.append(lu_41_polygon)  

            lu_41_area_sum = sum(lu_41_polygons_list)

            lu_41_list.append(lu_41_area_sum)


            #lu 82 = cultivated crops
            lu_82_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
                                                                                 "gridcode = 82")

            lu_82 = arcpy.CopyFeatures_management(lu_82_select, "lu_82.shp")

            #get the sum of all of the areas
            lu_82_polygons_list = []  

            rows = arcpy.SearchCursor(lu_82)  
            for row in rows:  
                lu_82_polygon = row.getValue("AREA_GEO")  
                lu_82_polygons_list.append(lu_82_polygon)  

            lu_82_area_sum = sum(lu_82_polygons_list)

            lu_82_list.append(lu_82_area_sum)



            #get percent impervious indicator for subwatershed area
            avg_impervious_pct = arcpy.sa.ZonalStatistics(subwatershed, "FID", impervious_usa, "MEAN" )

            #get avg value  value
            avg_impervious_result = arcpy.GetRasterProperties_management(avg_impervious_pct, "MAXIMUM")

            avg_impervious_pct_value = avg_impervious_result.getOutput(0)
            print(avg_impervious_pct_value, " = avg impervious percent ")

            impervious_percent_list.append(avg_impervious_pct_value)



            #get distance from residential buildings to streams

            building_footprints_residential_copy = arcpy.CopyFeatures_management(building_footprints_residential, "buildings_res.shp")


            #project buildings and streams so they are in the same GCS
            output_coord_system = arcpy.SpatialReference(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\Indiana_ML\working_dsn\NAD1983_ProjectionFile.prj")

            streams_project = arcpy.Project_management(streams_clip, "streams_project.shp",
                                                      output_coord_system)

            buildings_project = arcpy.Project_management(building_footprints_residential_copy, "buildings_res_project.shp",
                                                      output_coord_system)

            #use near tool to get distance to steams

            buildings_near = arcpy.Near_analysis(buildings_project, streams_project, "", "LOCATION", "", "GEODESIC")

            #get all the distances in to the streams
            dist_to_stream_list = []
            rows = arcpy.SearchCursor(buildings_near)  
            for row in rows:  
                dist_to_stream = row.getValue("NEAR_DIST")  
                dist_to_stream_list.append(dist_to_stream)  

            dist_to_stream_avg = mean(dist_to_stream_list)

            dist_to_stream_stdev = std(dist_to_stream_list)

            print("Distance to stream avg", dist_to_stream_avg)
            print("Distance to stream std", dist_to_stream_stdev)

            dist_to_stream_avg_list.append(dist_to_stream_avg)
            dist_to_stream_stdev_list.append(dist_to_stream_stdev)


         ## LOOP    

            #loop through all rainfall rasters in the same folder 


            arcpy.env.workspace = directory_rainfall

            rasters = arcpy.ListRasters("orb*")

            for raster in rasters:

                raster_name = os.path.basename(raster).rstrip(os.path.splitext(raster)[1])
                print("Raster name: ", raster_name)

                #get average rainfall for duration using zonal statistics
                #elevRaster = arcpy.sa.Raster(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\Indiana_ML\working_dsn\dem_clip.tif")

                centroid_rainfall = arcpy.sa.ExtractValuesToPoints(centroid, raster, r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\shp\Centroid_Rainfall.shp", "NONE", "VALUE_ONLY")

                # Open a cursor on some fields in a table  
                rainfall_value = arcpy.da.SearchCursor(centroid_rainfall, ("RASTERVALU",)).next()[0]


        #         avg_rainfall = arcpy.sa.ZonalStatistics(subwatershed, "FID", raster, "MEAN" )

        #         #get avg value  value
        #         avg_result = arcpy.GetRasterProperties_management(avg_rainfall, "MAXIMUM")

                #rainfall_value = avg_result.getOutput(0)
                print(rainfall_value, " = avg rainfall in inches *1000")

                if raster_name == "orb100yr06h":
                    orb100yr06h_list.append(rainfall_value)

                elif raster_name == "orb100yr12h":
                    orb100yr12h_list.append(rainfall_value)

                elif raster_name == "orb100yr24h":
                    orb100yr24h_list.append(rainfall_value)

                elif raster_name == "orb25yr06h":
                    orb25yr06h_list.append(rainfall_value)

                elif raster_name == "orb25yr12h":
                    orb25yr12h_list.append(rainfall_value)

                elif raster_name == "orb25yr24h":
                    orb25yr24h_list.append(rainfall_value)

                elif raster_name == "orb2yr06h":
                    orb2yr06h_list.append(rainfall_value)

                elif raster_name == "orb2yr12h":
                    orb2yr12h_list.append(rainfall_value)

                elif raster_name == "orb2yr24h":
                    orb2yr24h_list.append(rainfall_value)

                elif raster_name == "orb50yr06h":
                    orb50yr06h_list.append(rainfall_value)

                elif raster_name == "orb50yr12h":
                    orb50yr12h_list.append(rainfall_value)

                elif raster_name == "orb50yr24h":
                    orb50yr24h_list.append(rainfall_value)

                elif raster_name == "orb100yr06ha_am":
                    orb100yr06ha_am_list.append(rainfall_value)

                elif raster_name == "orb100yr12ha_am":
                    orb100yr12ha_am_list.append(rainfall_value)

                elif raster_name == "orb100yr24ha_am":
                    orb100yr24ha_am_list.append(rainfall_value)

                elif raster_name == "orb25yr06ha_am":
                    orb25yr06ha_am_list.append(rainfall_value)

                elif raster_name == "orb25yr12ha_am":
                    orb25yr12ha_am_list.append(rainfall_value)

                elif raster_name == "orb25yr24ha_am":
                    orb25yr24ha_am_list.append(rainfall_value)

                elif raster_name == "orb2yr06ha_am":
                    orb2yr06ha_am_list.append(rainfall_value)

                elif raster_name == "orb2yr12ha_am":
                    orb2yr12ha_am_list.append(rainfall_value)

                elif raster_name == "orb2yr24ha_am":
                    orb2yr24ha_am_list.append(rainfall_value)

                elif raster_name == "orb50yr06ha_am":
                    orb50yr06ha_am_list.append(rainfall_value)

                elif raster_name == "orb50yr12ha_am":
                    orb50yr12ha_am_list.append(rainfall_value)

                elif raster_name == "orb50yr24ha_am":
                    orb50yr24ha_am_list.append(rainfall_value)

                else:
                    continue 



            #set workspace environment back to the newly created folder
            arcpy.env.workspace = output_workspace
            print(round(((time()-st)/60), 2) , 'minutes to process.')  


    
    
#########################################################################################


    
    
print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
# ------ Subwatershed: 051402011102 Number 178 of 1590 ------
# clipped dem to subwatershed area
# 59.1980110246  square kilometers
# perimeter calculated
# 42.8279426266  kilometers
# 3.1010601520538  = avg slope (%)
# 6.816278771479482 is the radius of a circle with the same perimeter.
# 145.9635980759174 is the area of a circle with the same perimeter.
# 0.40556694823191747  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       4541  158.0  110.0
# 158.0
# 110.0
# The relief of the subwatershed is:  48.0  meters.
# 8.379877266461  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 2.981490523923921  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 7  = number of bridges in the subwatershed
# 115.25277810353805  = sum of all streets in the subwatershed (km)
# 12.006986144452998  = sum of all railroads in the subwatershed (km)
# 23050  = total population in the subwatershed
# 40.55  = total percent of dependent population in the subwatershed
# 389.3711900290277  = population density of subwatershed (people/square km)
# 70484.75  = average median income in the subwatershed
# 1120  = number of residential building footprints in the subwatershed
# 18.91955456974017  = housing density (buildings per square km)
# 22552  = total 2013 population in the subwatershed
# 498  = population change between 2013 and 2018
# streams clipped
# length calculated
# 67.46556151722791  = length of all streams in subwatershed
# 59.1980110246  = subwatershed area
# 1.1396592613422822 is the drainage density (streams/km)
# 3.85723076227  = watershed length (longest stream in subwatershed)
# 0.25132988247222177  is the shape factor.
# 0.012444160839304247  = relief ratio
# 0.048  is the relief in km
# 0.054703644544429546  is the ruggedness number
# 4.3408884057928985  miles is the radius of a circle with the same area.
# 8.681776811585797  miles is the diameter of a circle with the same area.
# 2.1671075820923  = avg impervious percent
# Distance to stream avg 272.90647560314795
# Distance to stream std 210.75871266061569
# Raster name:  orb100yr06h
# 5113  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 5092  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5969  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5945  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 7172  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 7143  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3996  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3980  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4697  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4678  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 5635  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 5612  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2303  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 2120  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2734  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2517  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 3269  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 3010  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4536  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4517  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 5315  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 5293  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 6385  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 6359  = avg rainfall in inches *1000
# 0.82 minutes to process.
# ------ Subwatershed: 041000030506 Number 179 of 1590 ------
# clipped dem to subwatershed area
# 70.572820068  square kilometers
# perimeter calculated
# 64.5927672378  kilometers
# 0.57826292514801  = avg slope (%)
# 10.280258193880101 is the radius of a circle with the same perimeter.
# 332.0151623308918 is the area of a circle with the same perimeter.
# 0.212559027643641  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       6643  255.0  240.0
# 255.0
# 240.0
# The relief of the subwatershed is:  15.0  meters.
# 4.32518784365036  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 1.2822494024208075  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 4  = number of bridges in the subwatershed
# 102.33686345022117  = sum of all streets in the subwatershed (km)
# 9.941634717227  = sum of all railroads in the subwatershed (km)
# 20475  = total population in the subwatershed
# 39.975  = total percent of dependent population in the subwatershed
# 290.1258583725497  = population density of subwatershed (people/square km)
# 59691.75  = average median income in the subwatershed
# 607  = number of residential building footprints in the subwatershed
# 8.601044983254587  = housing density (buildings per square km)
# 20566  = total 2013 population in the subwatershed
# -91  = population change between 2013 and 2018
# streams clipped
# length calculated
# 62.10646675533228  = length of all streams in subwatershed
# 70.572820068  = subwatershed area
# 0.8800337962333088 is the drainage density (streams/km)
# 4.35363774458  = watershed length (longest stream in subwatershed)
# 0.26857594174029703  is the shape factor.
# 0.0034453946056201023  = relief ratio
# 0.015  is the relief in km
# 0.013200506943499632  is the ruggedness number
# 4.739623014915239  miles is the radius of a circle with the same area.
# 9.479246029830477  miles is the diameter of a circle with the same area.
# 2.7205545902252  = avg impervious percent
# Distance to stream avg 370.4408199072865
# Distance to stream std 263.08099572571325
# Raster name:  orb100yr06h
# 4308  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 4290  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 4964  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 4944  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 5598  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 5575  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3326  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3312  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 3832  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 3816  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 4396  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 4378  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 1868  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 1720  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2170  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 1998  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2543  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2341  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 3799  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 3783  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 4376  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 4358  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 4978  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 4958  = avg rainfall in inches *1000
# 1.64 minutes to process.
# ------ Subwatershed: 051202080905 Number 180 of 1590 ------
# clipped dem to subwatershed area
# 79.529871999  square kilometers
# perimeter calculated
# 49.0623171079  kilometers
# 8.124945640564  = avg slope (%)
# 7.8085102872643475 is the radius of a circle with the same perimeter.
# 191.55180392703136 is the area of a circle with the same perimeter.
# 0.4151872776374147  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       5587  255.0  138.0
# 255.0
# 138.0
# The relief of the subwatershed is:  117.0  meters.
# 7.94108843659  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.11153513608406458  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 3  = number of bridges in the subwatershed
# 34.11517672935875  = sum of all streets in the subwatershed (km)
# 6.19930622874  = sum of all railroads in the subwatershed (km)
# 7431  = total population in the subwatershed
# 37.8  = total percent of dependent population in the subwatershed
# 93.43658946280509  = population density of subwatershed (people/square km)
# 53027.0  = average median income in the subwatershed
# 53  = number of residential building footprints in the subwatershed
# 0.6664162618124976  = housing density (buildings per square km)
# 7508  = total 2013 population in the subwatershed
# -77  = population change between 2013 and 2018
# streams clipped
# length calculated
# 104.31591743931358  = length of all streams in subwatershed
# 79.529871999  = subwatershed area
# 1.3116570518386506 is the drainage density (streams/km)
# 4.00209314119  = watershed length (longest stream in subwatershed)
# 0.20139287425184632  is the shape factor.
# 0.02923470191031354  = relief ratio
# 0.117  is the relief in km
# 0.15346387506512213  is the ruggedness number
# 5.031415755452249  miles is the radius of a circle with the same area.
# 10.062831510904498  miles is the diameter of a circle with the same area.
# 0.21065676212311  = avg impervious percent
# Distance to stream avg 210.48683114747948
# Distance to stream std 145.13774314840813
# Raster name:  orb100yr06h
# 5155  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 5134  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5860  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5836  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 6925  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 6897  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3982  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3966  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4597  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4578  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 5475  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 5453  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2253  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 2074  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2664  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2453  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 3204  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2950  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4548  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4529  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 5211  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 5190  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 6184  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 6159  = avg rainfall in inches *1000
# 2.76 minutes to process.
# ------ Subwatershed: 051202081005 Number 181 of 1590 ------
# clipped dem to subwatershed area
# 64.0914460241  square kilometers
# perimeter calculated
# 67.0615787204  kilometers
# 5.1519742012024  = avg slope (%)
# 10.67318174489792 is the radius of a circle with the same perimeter.
# 357.88020889130405 is the area of a circle with the same perimeter.
# 0.17908630997688377  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       5925  255.0  142.0
# 255.0
# 142.0
# The relief of the subwatershed is:  113.0  meters.
# 15.9963651830536  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.3666272947989906  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 1  = number of bridges in the subwatershed
# 137.24262747657005  = sum of all streets in the subwatershed (km)
# 15.758961757349441  = sum of all railroads in the subwatershed (km)
# 26830  = total population in the subwatershed
# 41.983333333333334  = total percent of dependent population in the subwatershed
# 418.62060640527983  = population density of subwatershed (people/square km)
# 46568.833333333336  = average median income in the subwatershed
# 2755  = number of residential building footprints in the subwatershed
# 42.9854554844035  = housing density (buildings per square km)
# 26348  = total 2013 population in the subwatershed
# 482  = population change between 2013 and 2018
# streams clipped
# length calculated
# 49.363453754519185  = length of all streams in subwatershed
# 64.0914460241  = subwatershed area
# 0.770203464218256 is the drainage density (streams/km)
# 6.17570621798  = watershed length (longest stream in subwatershed)
# 0.5950770291008176  is the shape factor.
# 0.018297502506030953  = relief ratio
# 0.113  is the relief in km
# 0.08703299145666293  is the ruggedness number
# 4.516740073248164  miles is the radius of a circle with the same area.
# 9.033480146496329  miles is the diameter of a circle with the same area.
# 3.6242995262146  = avg impervious percent
# Distance to stream avg 623.9659918011207
# Distance to stream std 363.96921433388246
# Raster name:  orb100yr06h
# 5152  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 5131  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5849  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5825  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 6861  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 6833  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3961  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3945  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4571  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4552  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 5417  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 5395  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2220  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 2044  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2630  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2421  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 3162  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2911  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4534  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4515  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 5192  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 5171  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 6123  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 6098  = avg rainfall in inches *1000
# 3.68 minutes to process.
# ------ Subwatershed: 071200020501 Number 182 of 1590 ------
# clipped dem to subwatershed area
# 45.4726622953  square kilometers
# perimeter calculated
# 35.2766348272  kilometers
# 1.0551925897598  = avg slope (%)
# 5.614450808396589 is the radius of a circle with the same perimeter.
# 99.02946546154216 is the area of a circle with the same perimeter.
# 0.4591831540579121  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z       MIN_Z
# 0    0       4009  223.0  196.441358
# 223.0
# 196.441358025
# The relief of the subwatershed is:  26.558641975  meters.
# 0  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.10246484261163598  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 5  = number of bridges in the subwatershed
# 65.71783421553108  = sum of all streets in the subwatershed (km)
# 11.55813163793  = sum of all railroads in the subwatershed (km)
# 5874  = total population in the subwatershed
# 39.3  = total percent of dependent population in the subwatershed
# 129.176514052645  = population density of subwatershed (people/square km)
# 46562.5  = average median income in the subwatershed
# 48  = number of residential building footprints in the subwatershed
# 1.0555792772432686  = housing density (buildings per square km)
# 5887  = total 2013 population in the subwatershed
# -13  = population change between 2013 and 2018
# streams clipped
# length calculated
# 16.773633401326542  = length of all streams in subwatershed
# 45.4726622953  = subwatershed area
# 0.3688729129690796 is the drainage density (streams/km)
# 2.64683795213  = watershed length (longest stream in subwatershed)
# 0.15406511937524797  is the shape factor.
# 0.01003410199465644  = relief ratio
# 0.026558641975000002  is the relief in km
# 0.00979676362982112  is the ruggedness number
# 3.8045233551249087  miles is the radius of a circle with the same area.
# 7.609046710249817  miles is the diameter of a circle with the same area.
# 1.1055517196655  = avg impervious percent
# Distance to stream avg 1042.1560181787709
# Distance to stream std 854.5117999914098
# Raster name:  orb100yr06h
# 5051  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 5030  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5742  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5719  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 6726  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 6699  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3873  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3857  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4441  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4423  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 5210  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 5189  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2176  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 2003  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2538  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2336  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2937  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2704  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4450  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4432  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 5080  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 5059  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 5945  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 5921  = avg rainfall in inches *1000
# 4.38 minutes to process.
# ------ Subwatershed: 071200020305 Number 183 of 1590 ------
# clipped dem to subwatershed area
# 74.609333348  square kilometers
# perimeter calculated
# 54.9823494698  kilometers
# 1.0446807146072  = avg slope (%)
# 8.750712700924721 is the radius of a circle with the same perimeter.
# 240.56737191603023 is the area of a circle with the same perimeter.
# 0.31013903819858957  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       5173  226.0  194.0
# 226.0
# 194.0
# The relief of the subwatershed is:  32.0  meters.
# 9.3687433081419  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.315898037891  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 8  = number of bridges in the subwatershed
# 140.0606487474041  = sum of all streets in the subwatershed (km)
# 8.32299495181  = sum of all railroads in the subwatershed (km)
# 16756  = total population in the subwatershed
# 40.025  = total percent of dependent population in the subwatershed
# 224.5831620267274  = population density of subwatershed (people/square km)
# 60509.5  = average median income in the subwatershed
# 2046  = number of residential building footprints in the subwatershed
# 27.42284253441658  = housing density (buildings per square km)
# 18087  = total 2013 population in the subwatershed
# -1331  = population change between 2013 and 2018
# streams clipped
# length calculated
# 46.29914194441204  = length of all streams in subwatershed
# 74.609333348  = subwatershed area
# 0.6205542908212186 is the drainage density (streams/km)
# 4.66189163967  = watershed length (longest stream in subwatershed)
# 0.2912937656024188  is the shape factor.
# 0.006864166409982273  = relief ratio
# 0.032  is the relief in km
# 0.019857737306278996  is the ruggedness number
# 4.873283123957645  miles is the radius of a circle with the same area.
# 9.74656624791529  miles is the diameter of a circle with the same area.
# 4.8032011985779  = avg impervious percent
# Distance to stream avg 564.5324815459436
# Distance to stream std 418.01732438094035
# Raster name:  orb100yr06h
# 5029  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 5008  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5710  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5687  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 6596  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 6569  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3878  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3862  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4439  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4421  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 5150  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 5129  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2180  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 2007  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2537  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2336  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2935  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2702  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4440  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4422  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 5062  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 5041  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 5853  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 5829  = avg rainfall in inches *1000
# 5.41 minutes to process.
# ------ Subwatershed: 040500011204 Number 184 of 1590 ------
# clipped dem to subwatershed area
# 74.5425155735  square kilometers
# perimeter calculated
# 58.2724870992  kilometers
# 0.11248543858528  = avg slope (%)
# 9.27435436809638 is the radius of a circle with the same perimeter.
# 270.21984763415276 is the area of a circle with the same perimeter.
# 0.27585877287008975  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       5789  255.0  240.0
# 255.0
# 240.0
# The relief of the subwatershed is:  15.0  meters.
# 4.554529918237785  = area of all AE and A zones in the subwatershed (square km)
# 0.0943338459415635  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 1.8868316758618542  = area of all water bodies in the subwatershed (square km)
# 1  = number of dams in the subwatershed
# 9  = number of bridges in the subwatershed
# 133.95208720949654  = sum of all streets in the subwatershed (km)
# 11.5483201316  = sum of all railroads in the subwatershed (km)
# 25515  = total population in the subwatershed
# 46.65  = total percent of dependent population in the subwatershed
# 342.2878850237063  = population density of subwatershed (people/square km)
# 71426.5  = average median income in the subwatershed
# 1937  = number of residential building footprints in the subwatershed
# 25.9851708128912  = housing density (buildings per square km)
# 24210  = total 2013 population in the subwatershed
# 1305  = population change between 2013 and 2018
# streams clipped
# length calculated
# 78.54486218128352  = length of all streams in subwatershed
# 74.5425155735  = subwatershed area
# 1.0536921322951216 is the drainage density (streams/km)
# 4.99345868612  = watershed length (longest stream in subwatershed)
# 0.33450212215338204  is the shape factor.
# 0.00300392992970875  = relief ratio
# 0.015  is the relief in km
# 0.015805381984426825  is the ruggedness number
# 4.871100455549468  miles is the radius of a circle with the same area.
# 9.742200911098935  miles is the diameter of a circle with the same area.
# 5.4086232185364  = avg impervious percent
# Distance to stream avg 375.40479195622345
# Distance to stream std 239.90052829385343
# Raster name:  orb100yr06h
# 4572  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 4553  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5232  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5211  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 5721  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 5698  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3531  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3516  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4042  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4025  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 4505  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 4486  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 1982  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 1825  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2283  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2102  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2615  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2407  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4034  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4017  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 4616  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 4597  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 5098  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 5077  = avg rainfall in inches *1000
# 6.63 minutes to process.
# ------ Subwatershed: 051202030501 Number 185 of 1590 ------
# clipped dem to subwatershed area
# 63.5157154625  square kilometers
# perimeter calculated
# 46.2340599316  kilometers
# 0.41545253992081  = avg slope (%)
# 7.358379177321077 is the radius of a circle with the same perimeter.
# 170.1038719418501 is the area of a circle with the same perimeter.
# 0.373393707841129  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       5265  255.0  232.0
# 255.0
# 232.0
# The relief of the subwatershed is:  23.0  meters.
# 2.40019247822  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.21299660925383607  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 24  = number of bridges in the subwatershed
# 87.88882203730547  = sum of all streets in the subwatershed (km)
# 9.80215242577  = sum of all railroads in the subwatershed (km)
# 27883  = total population in the subwatershed
# 39.54  = total percent of dependent population in the subwatershed
# 438.9937167040536  = population density of subwatershed (people/square km)
# 69441.4  = average median income in the subwatershed
# 882  = number of residential building footprints in the subwatershed
# 13.886327085786151  = housing density (buildings per square km)
# 26839  = total 2013 population in the subwatershed
# 1044  = population change between 2013 and 2018
# streams clipped
# length calculated
# 89.95430136166738  = length of all streams in subwatershed
# 63.5157154625  = subwatershed area
# 1.4162526660787889 is the drainage density (streams/km)
# 4.28294719418  = watershed length (longest stream in subwatershed)
# 0.288804692422374  is the shape factor.
# 0.005370133918824444  = relief ratio
# 0.023  is the relief in km
# 0.03257381131981214  is the ruggedness number
# 4.4964074726108185  miles is the radius of a circle with the same area.
# 8.992814945221637  miles is the diameter of a circle with the same area.
# 0.91978740692139  = avg impervious percent
# Distance to stream avg 206.3956144553862
# Distance to stream std 171.09026817446983
# Raster name:  orb100yr06h
# 5149  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 5128  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5749  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5726  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 6394  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 6368  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3920  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3904  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4466  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4448  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 5105  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 5084  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2165  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 1993  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2562  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2359  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 3047  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2805  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4508  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4489  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 5086  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 5065  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 5736  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 5713  = avg rainfall in inches *1000
# 7.46 minutes to process.
# ------ Subwatershed: 051202010106 Number 186 of 1590 ------
# clipped dem to subwatershed area
# 58.3704925932  square kilometers
# perimeter calculated
# 46.509745667  kilometers
# 0  = avg slope (%)
# 7.402255924849911 is the radius of a circle with the same perimeter.
# 172.1385202134066 is the area of a circle with the same perimeter.
# 0.3390902426768622  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       4467  255.0  255.0
# 255.0
# 255.0
# The relief of the subwatershed is:  0.0  meters.
# 4.68429623769422  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.25969403813756897  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 12  = number of bridges in the subwatershed
# 77.59709650339097  = sum of all streets in the subwatershed (km)
# 4.21484878849  = sum of all railroads in the subwatershed (km)
# 7487  = total population in the subwatershed
# 42.650000000000006  = total percent of dependent population in the subwatershed
# 128.26686339926854  = population density of subwatershed (people/square km)
# 47823.5  = average median income in the subwatershed
# 310  = number of residential building footprints in the subwatershed
# 5.310902584983738  = housing density (buildings per square km)
# 7455  = total 2013 population in the subwatershed
# 32  = population change between 2013 and 2018
# streams clipped
# length calculated
# 69.60934584052853  = length of all streams in subwatershed
# 58.3704925932  = subwatershed area
# 1.192543402462871 is the drainage density (streams/km)
# 4.04135522208  = watershed length (longest stream in subwatershed)
# 0.2798083638741809  is the shape factor.
# 0.0  = relief ratio
# 0.0  is the relief in km
# 0.0  is the ruggedness number
# 4.310441375756465  miles is the radius of a circle with the same area.
# 8.62088275151293  miles is the diameter of a circle with the same area.
# 0.3040226995945  = avg impervious percent
# Distance to stream avg 343.7635736107953
# Distance to stream std 310.32511444167494
# Raster name:  orb100yr06h
# 4102  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 4085  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 4701  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 4682  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 5463  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 5441  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3323  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3309  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 3841  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 3825  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 4483  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 4465  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2010  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 1850  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2360  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2173  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2775  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2555  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 3710  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 3695  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 4271  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 4253  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 4972  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 4952  = avg rainfall in inches *1000
# 8.2 minutes to process.
# ------ Subwatershed: 051202060201 Number 187 of 1590 ------
# clipped dem to subwatershed area
# 44.0571057651  square kilometers
# perimeter calculated
# 43.6082267247  kilometers
# 1.7292846441269  = avg slope (%)
# 6.940464842708098 is the radius of a circle with the same perimeter.
# 151.33068221781204 is the area of a circle with the same perimeter.
# 0.29113134970004356  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z       MIN_Z
# 0    0       5377  241.0  183.075585
# 241.0
# 183.075584883
# The relief of the subwatershed is:  57.924415116999995  meters.
# 3.506788100782  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.27346115385256003  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 11  = number of bridges in the subwatershed
# 67.3896605239997  = sum of all streets in the subwatershed (km)
# 0.833118918945  = sum of all railroads in the subwatershed (km)
# 14214  = total population in the subwatershed
# 39.96666666666666  = total percent of dependent population in the subwatershed
# 322.62673076586145  = population density of subwatershed (people/square km)
# 53318.0  = average median income in the subwatershed
# 426  = number of residential building footprints in the subwatershed
# 9.669268841019909  = housing density (buildings per square km)
# 12746  = total 2013 population in the subwatershed
# 1468  = population change between 2013 and 2018
# streams clipped
# length calculated
# 41.75664037530249  = length of all streams in subwatershed
# 44.0571057651  = subwatershed area
# 0.9477844640530193 is the drainage density (streams/km)
# 4.95244768887  = watershed length (longest stream in subwatershed)
# 0.5567033441044318  is the shape factor.
# 0.011696118516744314  = relief ratio
# 0.05792441511699999  is the relief in km
# 0.05489986073725045  is the ruggedness number
# 3.744838090181765  miles is the radius of a circle with the same area.
# 7.48967618036353  miles is the diameter of a circle with the same area.
# 0.54827708005905  = avg impervious percent
# Distance to stream avg 261.973286739025
# Distance to stream std 275.31970356248536
# Raster name:  orb100yr06h
# 4817  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 4797  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5478  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5456  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 6354  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 6328  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3705  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3690  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4294  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4276  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 5007  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 4986  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2080  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 1915  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2491  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2293  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2936  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2703  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4241  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4224  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 4870  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 4850  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 5664  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 5641  = avg rainfall in inches *1000
# 9.04 minutes to process.
# ------ Subwatershed: 051202020203 Number 188 of 1590 ------
# clipped dem to subwatershed area
# 58.2905275277  square kilometers
# perimeter calculated
# 57.7806730971  kilometers
# 3.7220883369446  = avg slope (%)
# 9.196079738580359 is the radius of a circle with the same perimeter.
# 265.67783857488826 is the area of a circle with the same perimeter.
# 0.21940304784310902  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       6275  255.0  159.0
# 255.0
# 159.0
# The relief of the subwatershed is:  96.0  meters.
# 2.81304682575613  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.6301907440895986  = area of all water bodies in the subwatershed (square km)
# 3  = number of dams in the subwatershed
# 4  = number of bridges in the subwatershed
# 90.27462393116608  = sum of all streets in the subwatershed (km)
# 3.30650059717  = sum of all railroads in the subwatershed (km)
# 29712  = total population in the subwatershed
# 39.43333333333333  = total percent of dependent population in the subwatershed
# 509.7226129216395  = population density of subwatershed (people/square km)
# 55212.666666666664  = average median income in the subwatershed
# 820  = number of residential building footprints in the subwatershed
# 14.06746575779969  = housing density (buildings per square km)
# 29198  = total 2013 population in the subwatershed
# 514  = population change between 2013 and 2018
# streams clipped
# length calculated
# 51.33705847661674  = length of all streams in subwatershed
# 58.2905275277  = subwatershed area
# 0.8807101368609346 is the drainage density (streams/km)
# 4.57999817939  = watershed length (longest stream in subwatershed)
# 0.35985921234367996  is the shape factor.
# 0.020960707022111964  = relief ratio
# 0.096  is the relief in km
# 0.08454817313864972  is the ruggedness number
# 4.3074878041539835  miles is the radius of a circle with the same area.
# 8.614975608307967  miles is the diameter of a circle with the same area.
# 0.54213631153107  = avg impervious percent
# Distance to stream avg 475.5064153151907
# Distance to stream std 392.48983429089304
# Raster name:  orb100yr06h
# 5199  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 5178  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5832  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5808  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 6890  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 6862  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3964  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3948  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4534  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4515  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 5375  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 5353  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2199  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 2024  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2606  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2399  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 3110  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2863  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4555  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4536  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 5160  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 5139  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 6109  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 6084  = avg rainfall in inches *1000
# 9.9 minutes to process.
# ------ Subwatershed: 051202040702 Number 189 of 1590 ------
# clipped dem to subwatershed area
# 73.5093886702  square kilometers
# perimeter calculated
# 54.9240011127  kilometers
# 0.85704451799393  = avg slope (%)
# 8.741426271470965 is the radius of a circle with the same perimeter.
# 240.05705313042816 is the area of a circle with the same perimeter.
# 0.30621632529272436  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       5819  255.0  212.0
# 255.0
# 212.0
# The relief of the subwatershed is:  43.0  meters.
# 7.0176062062349995  = area of all AE and A zones in the subwatershed (square km)
# 0.18899435812330997  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.42012492354164716  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 19  = number of bridges in the subwatershed
# 142.74118798707505  = sum of all streets in the subwatershed (km)
# 1.85257806497  = sum of all railroads in the subwatershed (km)
# 56864  = total population in the subwatershed
# 39.38333333333333  = total percent of dependent population in the subwatershed
# 773.5610515701666  = population density of subwatershed (people/square km)
# 79723.66666666667  = average median income in the subwatershed
# 2148  = number of residential building footprints in the subwatershed
# 29.220757223774584  = housing density (buildings per square km)
# 53537  = total 2013 population in the subwatershed
# 3327  = population change between 2013 and 2018
# streams clipped
# length calculated
# 63.70895824031319  = length of all streams in subwatershed
# 73.5093886702  = subwatershed area
# 0.8666778406516689 is the drainage density (streams/km)
# 6.96793855753  = watershed length (longest stream in subwatershed)
# 0.6604893418355395  is the shape factor.
# 0.006171122153987918  = relief ratio
# 0.043  is the relief in km
# 0.037267147148021755  is the ruggedness number
# 4.837227009460213  miles is the radius of a circle with the same area.
# 9.674454018920425  miles is the diameter of a circle with the same area.
# 2.4757590293884  = avg impervious percent
# Distance to stream avg 439.02313162418307
# Distance to stream std 346.9824359673577
# Raster name:  orb100yr06h
# 4741  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 4722  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5335  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5313  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 5810  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 5786  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3655  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3640  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4197  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4180  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 4736  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 4717  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2055  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 1892  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2447  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2253  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2909  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2678  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4180  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4163  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 4753  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 4733  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 5270  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 5248  = avg rainfall in inches *1000
# 10.84 minutes to process.
# ------ Subwatershed: 051202050401 Number 190 of 1590 ------
# clipped dem to subwatershed area
# 47.6540012977  square kilometers
# perimeter calculated
# 40.0425851162  kilometers
# 0  = avg slope (%)
# 6.372975355421187 is the radius of a circle with the same perimeter.
# 127.59520405644892 is the area of a circle with the same perimeter.
# 0.37347799746938426  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       4591  255.0  255.0
# 255.0
# 255.0
# The relief of the subwatershed is:  0.0  meters.
# 0.6536521343016  = area of all AE and A zones in the subwatershed (square km)
# 0.149271238581569  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.048830835995555  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 11  = number of bridges in the subwatershed
# 59.46329074270348  = sum of all streets in the subwatershed (km)
# 10.56879674954  = sum of all railroads in the subwatershed (km)
# 12034  = total population in the subwatershed
# 39.150000000000006  = total percent of dependent population in the subwatershed
# 252.52863709853503  = population density of subwatershed (people/square km)
# 49866.5  = average median income in the subwatershed
# 241  = number of residential building footprints in the subwatershed
# 5.0572878129256225  = housing density (buildings per square km)
# 13025  = total 2013 population in the subwatershed
# -991  = population change between 2013 and 2018
# streams clipped
# length calculated
# 72.80673964850709  = length of all streams in subwatershed
# 47.6540012977  = subwatershed area
# 1.5278200710508034 is the drainage density (streams/km)
# 4.79060602776  = watershed length (longest stream in subwatershed)
# 0.4815945248718939  is the shape factor.
# 0.0  = relief ratio
# 0.0  is the relief in km
# 0.0  is the ruggedness number
# 3.8947066294232098  miles is the radius of a circle with the same area.
# 7.7894132588464196  miles is the diameter of a circle with the same area.
# 0.5102903842926  = avg impervious percent
# Distance to stream avg 150.26506122138372
# Distance to stream std 109.39542025441733
# Raster name:  orb100yr06h
# 4318  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 4300  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 4959  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 4939  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 5746  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 5723  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3474  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3460  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# ...
# 3558  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3543  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4119  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4102  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 4730  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 4711  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2060  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 1896  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2456  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2261  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2926  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2694  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4033  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4016  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 4628  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 4609  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 5252  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 5230  = avg rainfall in inches *1000
# 729.38 minutes to process.
# ------ Subwatershed: 051201010703 Number 364 of 1590 ------
# clipped dem to subwatershed area
# 82.797399235  square kilometers
# perimeter calculated
# 50.349356866  kilometers
# 0.17493537068367  = avg slope (%)
# 8.01334902672176 is the radius of a circle with the same perimeter.
# 201.73348491911383 is the area of a circle with the same perimeter.
# 0.41042962831975105  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       5745  255.0  242.0
# 255.0
# 242.0
# The relief of the subwatershed is:  13.0  meters.
# 6.156996007885  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.3818608808642221  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 12  = number of bridges in the subwatershed
# 108.87084353296619  = sum of all streets in the subwatershed (km)
# 9.64745539642  = sum of all railroads in the subwatershed (km)
# 15059  = total population in the subwatershed
# 42.075  = total percent of dependent population in the subwatershed
# 181.87769349202313  = population density of subwatershed (people/square km)
# 62772.0  = average median income in the subwatershed
# 485  = number of residential building footprints in the subwatershed
# 5.8576719133827755  = housing density (buildings per square km)
# 14742  = total 2013 population in the subwatershed
# 317  = population change between 2013 and 2018
# streams clipped
# length calculated
# 62.810043368728074  = length of all streams in subwatershed
# 82.797399235  = subwatershed area
# 0.7585992307615516 is the drainage density (streams/km)
# 7.48639750411  = watershed length (longest stream in subwatershed)
# 0.6769071022444952  is the shape factor.
# 0.0017364827332322463  = relief ratio
# 0.013  is the relief in km
# 0.00986178999990017  is the ruggedness number
# 5.133734578920762  miles is the radius of a circle with the same area.
# 10.267469157841523  miles is the diameter of a circle with the same area.
# 0.48001956939697  = avg impervious percent
# Distance to stream avg 493.46215847017527
# Distance to stream std 374.90912705641597
# Raster name:  orb100yr06h
# 4418  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 4400  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5024  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5003  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 5766  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 5742  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3455  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3441  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 3940  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 3924  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 4564  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 4545  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 1988  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 1830  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2290  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2108  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2673  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2461  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 3924  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 3908  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 4465  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 4447  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 5153  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 5132  = avg rainfall in inches *1000
# 739.25 minutes to process.
# ------ Subwatershed: 051201011006 Number 365 of 1590 ------
# clipped dem to subwatershed area
# 62.6740012702  square kilometers
# perimeter calculated
# 45.6404680747  kilometers
# 1.4795359373093  = avg slope (%)
# 7.263906099116345 is the radius of a circle with the same perimeter.
# 165.76403720716908 is the area of a circle with the same perimeter.
# 0.37809166768706953  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       4977  255.0  225.0
# 255.0
# 225.0
# The relief of the subwatershed is:  30.0  meters.
# 7.754583989091308  = area of all AE and A zones in the subwatershed (square km)
# 0.27900569240757794  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 1.0036826985193914  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 12  = number of bridges in the subwatershed
# 120.82023134421698  = sum of all streets in the subwatershed (km)
# 14.406238380859  = sum of all railroads in the subwatershed (km)
# 22134  = total population in the subwatershed
# 39.5  = total percent of dependent population in the subwatershed
# 353.1607931744449  = population density of subwatershed (people/square km)
# 88158.8  = average median income in the subwatershed
# 1088  = number of residential building footprints in the subwatershed
# 17.359670325011116  = housing density (buildings per square km)
# 22535  = total 2013 population in the subwatershed
# -401  = population change between 2013 and 2018
# streams clipped
# length calculated
# 76.36448953113451  = length of all streams in subwatershed
# 62.6740012702  = subwatershed area
# 1.2184396716895751 is the drainage density (streams/km)
# 3.22491915527  = watershed length (longest stream in subwatershed)
# 0.16593967749386973  is the shape factor.
# 0.009302558779179166  = relief ratio
# 0.03  is the relief in km
# 0.036553190150687254  is the ruggedness number
# 4.466514772280521  miles is the radius of a circle with the same area.
# 8.933029544561043  miles is the diameter of a circle with the same area.
# 1.9654136896133  = avg impervious percent
# Distance to stream avg 239.28927168172504
# Distance to stream std 215.41639217234982
# Raster name:  orb100yr06h
# 4577  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 4558  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5206  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5185  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 5825  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 5801  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3552  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3537  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4042  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4025  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 4579  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 4560  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2013  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 1853  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2308  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2125  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2651  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2441  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4048  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4031  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 4605  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 4586  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 5188  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 5167  = avg rainfall in inches *1000
# 749.61 minutes to process.
# ------ Subwatershed: 051201060504 Number 366 of 1590 ------
# clipped dem to subwatershed area
# 60.1978570404  square kilometers
# perimeter calculated
# 58.7548963194  kilometers
# 0.9847594499588  = avg slope (%)
# 9.351132180084317 is the radius of a circle with the same perimeter.
# 274.71240085492946 is the area of a circle with the same perimeter.
# 0.2191304682753997  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY      MAX_Z       MIN_Z
# 0    0       4881  254.62668  225.107549
# 254.626680455
# 225.107549121
# The relief of the subwatershed is:  29.519131334000008  meters.
# 0  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.204933053968759  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 2  = number of bridges in the subwatershed
# 84.66656961211854  = sum of all streets in the subwatershed (km)
# 0  = sum of all railroads in the subwatershed (km)
# 11968  = total population in the subwatershed
# 41.93333333333333  = total percent of dependent population in the subwatershed
# 198.81106385511418  = population density of subwatershed (people/square km)
# 50717.333333333336  = average median income in the subwatershed
# 347  = number of residential building footprints in the subwatershed
# 5.764324795932873  = housing density (buildings per square km)
# 11987  = total 2013 population in the subwatershed
# -19  = population change between 2013 and 2018
# streams clipped
# length calculated
# 45.9447479939924  = length of all streams in subwatershed
# 60.1978570404  = subwatershed area
# 0.7632289628376298 is the drainage density (streams/km)
# 8.2256101118  = watershed length (longest stream in subwatershed)
# 1.1239712680459366  is the shape factor.
# 0.003588685937308591  = relief ratio
# 0.02951913133400001  is the relief in km
# 0.022529855991916606  is the ruggedness number
# 4.377393405102839  miles is the radius of a circle with the same area.
# 8.754786810205678  miles is the diameter of a circle with the same area.
# 1.0156841278076  = avg impervious percent
# Distance to stream avg 555.8995047459013
# Distance to stream std 428.79589843833605
# Raster name:  orb100yr06h
# 4788  = avg rainfall in inches *1000
# Raster name:  orb100yr06ha_am
# 4768  = avg rainfall in inches *1000
# Raster name:  orb100yr12h
# 5437  = avg rainfall in inches *1000
# Raster name:  orb100yr12ha_am
# 5415  = avg rainfall in inches *1000
# Raster name:  orb100yr24h
# 6176  = avg rainfall in inches *1000
# Raster name:  orb100yr24ha_am
# 6151  = avg rainfall in inches *1000
# Raster name:  orb25yr06h
# 3708  = avg rainfall in inches *1000
# Raster name:  orb25yr06ha_am
# 3693  = avg rainfall in inches *1000
# Raster name:  orb25yr12h
# 4220  = avg rainfall in inches *1000
# Raster name:  orb25yr12ha_am
# 4203  = avg rainfall in inches *1000
# Raster name:  orb25yr24h
# 4854  = avg rainfall in inches *1000
# Raster name:  orb25yr24ha_am
# 4834  = avg rainfall in inches *1000
# Raster name:  orb2yr06h
# 2105  = avg rainfall in inches *1000
# Raster name:  orb2yr06ha_am
# 1938  = avg rainfall in inches *1000
# Raster name:  orb2yr12h
# 2419  = avg rainfall in inches *1000
# Raster name:  orb2yr12ha_am
# 2227  = avg rainfall in inches *1000
# Raster name:  orb2yr24h
# 2811  = avg rainfall in inches *1000
# Raster name:  orb2yr24ha_am
# 2588  = avg rainfall in inches *1000
# Raster name:  orb50yr06h
# 4234  = avg rainfall in inches *1000
# Raster name:  orb50yr06ha_am
# 4217  = avg rainfall in inches *1000
# Raster name:  orb50yr12h
# 4814  = avg rainfall in inches *1000
# Raster name:  orb50yr12ha_am
# 4794  = avg rainfall in inches *1000
# Raster name:  orb50yr24h
# 5500  = avg rainfall in inches *1000
# Raster name:  orb50yr24ha_am
# 5478  = avg rainfall in inches *1000
# 759.73 minutes to process.
# ------ Subwatershed: 051201111106 Number 367 of 1590 ------
# clipped dem to subwatershed area
# 43.4285020025  square kilometers
# perimeter calculated
# 34.7058437967  kilometers
# 1.5591160058975  = avg slope (%)
# 5.523606594419998 is the radius of a circle with the same perimeter.
# 95.85071383018125 is the area of a circle with the same perimeter.
# 0.4530848051840521  is the circulatory ratio
# created 3d polyline of subwatershed perimeter
# created perimeter points
# added z information
#    FID  FREQUENCY  MAX_Z  MIN_Z
# 0    0       3909  169.0  131.0
# 169.0
# 131.0
# The relief of the subwatershed is:  38.0  meters.
# 0  = area of all AE and A zones in the subwatershed (square km)
# 0  = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)
# 0.570466858531212  = area of all water bodies in the subwatershed (square km)
# 0  = number of dams in the subwatershed
# 0  = number of bridges in the subwatershed
# 19.606050383637903  = sum of all streets in the subwatershed (km)
# 0.529413477417  = sum of all railroads in the subwatershed (km)
# 2975  = total population in the subwatershed
# 34.2  = total percent of dependent population in the subwatershed
# 68.50339898504309  = population density of subwatershed (people/square km)
# 70231.0  = average median income in the subwatershed
# 38  = number of residential building footprints in the subwatershed
# 0.8750013988005504  = housing density (buildings per square km)
# 2948  = total 2013 population in the subwatershed
# 27  = population change between 2013 and 2018
# streams clipped
# length calculated
# 62.047795270122485  = length of all streams in subwatershed
# 43.4285020025  = subwatershed area
# 1.4287344119433512 is the drainage density (streams/km)
# 4.64480339503  = watershed length (longest stream in subwatershed)
# 0.4967751035308628  is the shape factor.
# 0.008181185890593452  = relief ratio
# 0.038  is the relief in km
# 0.054291907653847345  is the ruggedness number
# 3.7180265638572703  miles is the radius of a circle with the same area.
# 7.4360531277145405  miles is the diameter of a circle with the same area.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1b1fb515b47a> in <module>
#     640             #lu 24 = developed high intensity
#     641             lu_24_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
# --> 642                                                                                  "gridcode = 24")
#     643
#     644             lu_24 = arcpy.CopyFeatures_management(lu_24_select, "lu_24.shp")
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in SelectLayerByAttribute(in_layer_or_view, selection_type, where_clause, invert_where_clause)
#    8519     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    8520     try:
# -> 8521         retval = convertArcObjectToPythonObject(gp.SelectLayerByAttribute_management(*gp_fixargs((in_layer_or_view, selection_type, where_clause, invert_where_clause), True)))
#    8522         return retval
#    8523     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     509         val = getattr(self._gp, attr)
#     510         if callable(val):
# --> 511             return lambda *args: val(*gp_fixargs(args, True))
#     512         else:
#     513             return convertArcObjectToPythonObject(val)
#
# KeyboardInterrupt:

# %%
st = time()
outputs = {'subwatershed': subwatershed_list[0:189],
          'area': area_list[0:189],
          'perimeter': perimeter_list[0:189],
          'circulatory_ratio': circulatory_ratio_list[0:189],
          'relief': relief_list[0:189],
          'avg_slope': avg_slope_list[0:189],
           'watershed_length': watershed_length_list[0:189],
           'elongation_ratio': elongation_ratio_list[0:189],
           'drainage_density': drainage_density_list[0:189],
           'shape_factor': shape_factor_list[0:189],
           'relief_ratio': relief_ratio_list[0:189],
           'ruggedness': ruggedness_list[0:189],
           'aae_area': aae_list[0:189],
           'buildings_aae_count': buildings_aae_list[0:189],
           'x_area': x_list[0:189],
           'buildings_x_count': buildings_x_list[0:189],
           'water_bodies_area': water_bodies_list[0:189],
           'dams_count': dams_list[0:189],
           'bridges_count': bridges_list[0:189],
           'streets_km': streets_list[0:189],
           'railroads_km': railroads_list[0:189],
           'population': population_list[0:189],
           'population_density': population_density_list[0:189],
           'avg_median_income': avg_median_income_list[0:189],
           'housing_density': housing_density_list[0:189],
           'population_change': population_change_list[0:189],
           'dependent_population_pct': dependent_population_list[0:189],
           'dist_to_stream_avg (m)': dist_to_stream_avg_list[0:189],
           'dist_to_stream_stdev (m)': dist_to_stream_stdev_list[0:189],
           'lu_21_area' : lu_21_list[0:189],
           'lu_22_area' : lu_22_list[0:189],
           'lu_23_area' : lu_23_list[0:189],
           'lu_24_area': lu_24_list[0:189],
           'lu_41_area': lu_41_list[0:189],
           'lu_82_area': lu_82_list[0:189],
           'avg_impervious_percent': impervious_percent_list[0:189],
           'orb100yr06h': orb100yr06h_list[0:189],
           'orb100yr12h': orb100yr12h_list[0:189],
           'orb100yr24h': orb100yr24h_list[0:189],
           'orb25yr06h': orb25yr06h_list[0:189],
           'orb25yr12h': orb25yr12h_list[0:189],
           'orb25yr24h':orb25yr24h_list[0:189],
           'orb2yr06h': orb2yr06h_list[0:189],
           'orb2yr12h': orb2yr12h_list[0:189],
           'orb2yr24h': orb2yr24h_list[0:189],
           'orb50yr06h': orb50yr06h_list[0:189],
           'orb50yr12h': orb50yr12h_list[0:189],
           'orb50yr24h':orb50yr24h_list[0:189],
           'orb100yr06ha_am': orb100yr06ha_am_list[0:189],
           'orb100yr12ha_am': orb100yr12ha_am_list[0:189],
           'orb100yr24ha_am': orb100yr24ha_am_list[0:189],
           'orb25yr06ha_am': orb25yr06ha_am_list[0:189],
           'orb25yr12ha_am': orb25yr12ha_am_list[0:189],
           'orb25yr24ha_am': orb25yr24ha_am_list[0:189],
           'orb2yr06ha_am': orb2yr06ha_am_list[0:189],
           'orb2yr12ha_am': orb2yr12ha_am_list[0:189],
           'orb2yr24ha_am': orb2yr24ha_am_list[0:189],
           'orb50yr06ha_am': orb50yr06ha_am_list[0:189],
           'orb50yr12ha_am': orb50yr12ha_am_list[0:189],
           'orb50yr24ha_am': orb50yr24ha_am_list[0:189]
          }

# 
# 
# 
#  
#         
# 
            
outputs_df = pd.DataFrame(outputs, columns = ['subwatershed',
                                             'area',
                                             'perimeter',
                                             'circulatory_ratio',
                                             'relief',
                                             'avg_slope',
                                              'watershed_length',
                                              'elongation_ratio',
                                              'drainage_density',
                                              'shape_factor',
                                              'relief_ratio',
                                              'ruggedness',
                                              'aae_area',
                                              'buildings_aae_count',
                                              'x_area',
                                              'buildings_x_count',
                                              'water_bodies_area',
                                              'dams_count',
                                              'bridges_count',
                                              'streets_km',
                                              'railroads_km',
                                              'population',
                                              'population_density',
                                              'avg_median_income',
                                              'housing_density',
                                              'population_change',
                                              'dependent_population_pct',
                                              'dist_to_stream_avg (m)',
                                              'dist_to_stream_stdev (m)',
                                              'lu_189_area',
                                              'lu_22_area',
                                              'lu_23_area',
                                              'lu_24_area',
                                              'lu_41_area',
                                              'lu_82_area',
                                              'avg_impervious_percent',
                                             'orb100yr06h',
                                              'orb100yr12h',
                                              'orb100yr24h',
                                              'orb25yr06h',
                                              'orb25yr12h',
                                              'orb25yr24h',
                                              'orb2yr06h',
                                              'orb2yr12h',
                                              'orb2yr24h',
                                              'orb50yr06h',
                                              'orb50yr12h',
                                              'orb50yr24h',
                                              'orb100yr06ha_am',
                                              'orb100yr12ha_am',
                                              'orb100yr24ha_am',
                                              'orb25yr06ha_am',
                                              'orb25yr12ha_am',
                                              'orb25yr24ha_am',
                                              'orb2yr06ha_am',
                                              'orb2yr12ha_am',
                                              'orb2yr24ha_am',
                                              'orb50yr06ha_am',
                                              'orb50yr12ha_am',
                                              'orb50yr24ha_am'
                                             ])    
    

#     
#  
# 
# 
# 
#




print(outputs_df)

outputs_df.to_excel(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\output\IN_subwatershed_data_178_366.xlsx")
print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
#      subwatershed       area  perimeter  circulatory_ratio  relief  \
# 0    051402011102  59.198011  42.827943           0.405567    48.0
# 1    051402011102  59.198011  42.827943           0.405567    48.0
# 2    051402011102  59.198011  42.827943           0.405567    48.0
# 3    041000030506  70.572820  64.592767           0.212559    15.0
# 4    051202080905  79.529872  49.062317           0.415187   117.0
# ..            ...        ...        ...                ...     ...
# 184  071200030203  57.009648  40.921815           0.427808    44.0
# 185  051402010905  58.285685  37.224962           0.528571    72.0
# 186  051202081509  54.130025  38.027782           0.470377    52.0
# 187  051202040204  42.920926  34.310329           0.458173     7.0
# 188  051201010703  82.797399  50.349357           0.410430    13.0
#
#              avg_slope  watershed_length  elongation_ratio  drainage_density  \
# 0      3.1010601520538          3.857231          2.250780          1.139659
# 1      3.1010601520538          3.857231          2.250780          1.139659
# 2      3.1010601520538          3.857231          2.250780          1.139659
# 3     0.57826292514801          4.353638          2.177316          0.880034
# 4       8.124945640564          4.002093          2.514392          1.311657
# ..                 ...               ...               ...               ...
# 184   0.79663628339767          3.974016          2.143876          0.977829
# 185    3.1941001415253          3.035533          2.837926          1.533393
# 186    2.6638729572296          4.885767          1.699188          1.487604
# 187  0.018896382302046          3.672837          2.012741          0.710968
# 188   0.17493537068367          7.486398          1.371483          0.758599
#
#      shape_factor  ...  orb100yr24ha_am  orb25yr06ha_am  orb25yr12ha_am  \
# 0        0.251330  ...             7143            3980            4678
# 1        0.251330  ...             5575            3312            3816
# 2        0.251330  ...             6897            3966            4578
# 3        0.268576  ...             6833            3945            4552
# 4        0.201393  ...             6699            3857            4423
# ..            ...  ...              ...             ...             ...
# 184      0.277020  ...             6992            3920            4563
# 185      0.158091  ...             5751            3543            4102
# 186      0.440989  ...             5742            3441            3924
# 187      0.314293  ...             5801            3537            4025
# 188      0.676907  ...             6151            3693            4203
#
#     orb25yr24ha_am  orb2yr06ha_am orb2yr12ha_am  orb2yr24ha_am orb50yr06ha_am  \
# 0             5612           2120          2517           3010           4517
# 1             4378           1720          1998           2341           3783
# 2             5453           2074          2453           2950           4529
# 3             5395           2044          2421           2911           4515
# 4             5189           2003          2336           2704           4432
# ..             ...            ...           ...            ...            ...
# 184           5463           2075          2456           2922           4460
# 185           4711           1896          2261           2694           4016
# 186           4545           1830          2108           2461           3908
# 187           4560           1853          2125           2441           4031
# 188           4834           1938          2227           2588           4217
#
#     orb50yr12ha_am  orb50yr24ha_am
