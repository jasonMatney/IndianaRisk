# %%
#########################################################################
#Data Collection 
#
# Functions for handling subwatershed characteristics data collection
#
# Authors: Shannon McAvoy (smcavoy@dewberry.com)
#
# Editor: Jason Matney (jmatney@dewberry.com)
#
# Copyright: Dewberry Engineers Inc.
#########################################################################

# %%
import pandas as pd
import arcpy
import numpy as np
from numpy import mean
from numpy import std
import os
from arcpy import management
from arcgis.gis import GIS
from scipy.stats import skew
from scipy.stats import kurtosis
from time import time

# %%
# Login for ArcPro, AGOL or API Server 
#gis = GIS("https://www.arcgis.com", username="dpiazza_dewberry", password="*****")

# %%
path = "C:\\Users\jmatney\Documents\GitHub\IndianaRisk\data\Indiana_ML"
hucs = "C:\\Users\jmatney\Documents\GitHub\IndianaRisk\data\shp"

# %%
arcpy.env.overwriteOutput = True

# %%
st = time()

# Set Local Variables
output_workspace = os.path.join(path, "working_dsn")

arcpy.env.workspace = output_workspace

##### change these based on what subwatersheds you want #####

# all_subwatersheds = r"P:\Temp\McAvoy\ML_DataCollection\Indiana_ML\Indiana_HUC12_groups\1.shp"
all_subwatersheds = os.path.join(hucs, "wbdhu12_a_IN_only.shp")

# All centroids of subwatersheds
all_centroids = os.path.join(hucs, "wbdhu12_a_IN_only_centroids.shp")

#set source for streams data
streams = os.path.join(path, "Indiana_50c_streams_edited\Hydrography_HighRes_FlowLine_NHD_USGS.shp")

#####these are the same for all subwatersheds in Indiana#####

#set source for dem
dem_Indiana = os.path.join(path, "Indiana_3dep\Indiana_DEM_1.tif")

#set source for slope dem
dem_slope = os.path.join(path, "Indiana_SlopeRaster\Indiana_clip_slope.tif")

#set source for NHFL Data
nfhl_sfha = os.path.join(path, "NFHL_18_20200310.gdb\S_FLD_HAZ_AR")


#set source for water bodies data 
water_bodies = os.path.join(path, "IndianaMAP_WaterBodies\Water_Bodies_Lakes_LocalRes\Hydrography_LocalRes_WaterbodyDiscrete_NHD_IN.shp")

#set source for dams data 
dams = os.path.join(path, "IndianaMAP_Dams\Dams_IDNR\Dams_IDNR_IN.shp")

#set source for bridges data
bridges = os.path.join(path, "IndianaMAP_Bridges\Bridges_County_INDOT\Bridges_County_INDOT_IN.shp")

#set source for streets data
streets = os.path.join(path, "IndianaMAP_Streets\Streets_Centerlines_IGIO\County_Street_Centerlines_IGIO_IN.gdb\County_Street_Centerlines_IGIO_IN_Dec2019")


#set source for railraods data
railroads = os.path.join(path, "IndianaMAP_Railroads\Railroads_Active_Abandoned_INDOT\Rail_System_Active_Abandoned_INDOT_IN.shp")

#set source for ACS population data
population = os.path.join(path, "Indiana_PopulationData\Indiana_PopulationData.shp")

#set source for ACS median income data 
median_income = os.path.join(path, "Indiana_IncomeData\Indiana_IncomeData.shp")

#set source for county boundary data
county_boundary = os.path.join(path, "MarionCounty_Boundary\Marion_County_Boundary.shp")

#source for Bing building footprints for Indiana (attrubuted with open street maps data)
building_footprints = os.path.join(path, "BuildingFootprints_Indiana\Building_Footprints_Attributed_IN.shp")

#folder with partial duration files, set as workspace temporarily, then reset when done
directory_rainfall = os.path.join(path, "MarionCounty_Rainfall\All_Rainfall_Clipped_IN")

#set source for nlcd land use data
lu_usa = os.path.join(path, r"NLCD_Impervious\NLCD_indiana_polygon.shp")

#set source for impervious indicator data
impervious_usa = os.path.join(path, "NLCD_Impervious\\NLCD_2016_Impervious_L48_20190405_PERCENT\\NLCD_2016_Impervious_L48_20190405.img")



subwatershed_list = []
area_list = []
perimeter_list = []
watershed_length_list = []
elongation_ratio_list = []
shape_factor_list = []
circulatory_ratio_list = []
relief_list = []
relief_ratio_list = []
avg_slope_list = []
drainage_density_list = []
ruggedness_list = []
aae_list = []
buildings_aae_list = []
x_list = []
buildings_x_list = []
water_bodies_list = []
dams_list = []
bridges_list = []
streets_list = []
railroads_list = []
population_list = []
dependent_population_list = []
population_density_list = []
avg_median_income_list = []
housing_density_list = []
population_change_list = []
dist_to_stream_avg_list = []
dist_to_stream_stdev_list = []
dist_to_stream_skewness_list = []
dist_to_stream_kurtosis_list = []

lu_21_list = []
lu_22_list = []
lu_23_list = []
lu_24_list = []
lu_41_list = []
lu_82_list = []
impervious_percent_list = []

orb100yr06h_list = []
orb100yr12h_list = []
orb100yr24h_list = []
orb25yr06h_list = []
orb25yr12h_list = []
orb25yr24h_list = []
orb2yr06h_list = []
orb2yr12h_list = []
orb2yr24h_list = []
orb50yr06h_list = []
orb50yr12h_list = []
orb50yr24h_list = []
orb100yr06ha_am_list = []
orb100yr12ha_am_list = []
orb100yr24ha_am_list = []
orb25yr06ha_am_list = []
orb25yr12ha_am_list = []
orb25yr24ha_am_list = []
orb2yr06ha_am_list = []
orb2yr12ha_am_list = []
orb2yr24ha_am_list = []
orb50yr06ha_am_list = []
orb50yr12ha_am_list = []
orb50yr24ha_am_list = []


#########################################################################################################
print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
# 0.02 minutes to process.

# %%
# GLOBAL VARIABLES
LOG_NAME = 'DataCollection_export.log'

# %%
completed_hucs = pd.read_excel(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\output\completed_hucs.xlsx", converters={'subwatershed': lambda x: str(x)})

# %%
done = completed_hucs['subwatershed'].str.strip('[]').tolist()

# %%
len(done)
# Out:
# 311

# %%
row_count=len(done)
with arcpy.da.SearchCursor(all_subwatersheds, ['HUC12']) as cursor:

    for row in cursor:
        if row[0] not in done:
            st = time()
            subwatershed_number = row[0]

            row_count += 1

            subwatershed_list.append(subwatershed_number)

            print("------ Subwatershed:", subwatershed_number, "Number", row_count, "of 1590 ------")              

            #select subwatershed from shapefile with all of them
            subwatershed_selection = arcpy.SelectLayerByAttribute_management(all_subwatersheds, "NEW_SELECTION",
                                                                             "HUC12 = " + "'"+subwatershed_number+"'")

            #select centroid from shapefile with all of them
            centroid_selection = arcpy.SelectLayerByAttribute_management(all_centroids, "NEW_SELECTION",
                                                                             "HUC12 = " + "'"+subwatershed_number+"'")
            #copy selected subwatershed to it's own file
            subwatershed = arcpy.CopyFeatures_management(subwatershed_selection, "subwatershed")

            #copy selected centroid to it's own file
            centroid = arcpy.CopyFeatures_management(centroid_selection, "centroid")

            #clip building footprints to subwatershed area
            building_footprints_clip = arcpy.Clip_analysis(building_footprints, subwatershed, "building_footprints.shp")

            #select buildings that are marked residential
            building_footprints_residential = arcpy.SelectLayerByAttribute_management(building_footprints_clip, "NEW_SELECTION","RES_NONRES = 'Res'")

#             #clip dem to subwatershed area
#             # dem_clip = arcpy.Clip_management(dem_Indiana, "#", "dem_clip.tif", subwatershed, "#" , "ClippingGeometry", "NO_MAINTAIN_EXTENT")
#             dem_clip =  os.path.join(path, "working_dsn\dem_clip.tif")
#             arcpy.Clip_management(dem_Indiana, "#", dem_clip, subwatershed_selection)
#             print("clipped dem to subwatershed area")

#             #calculate area of subwatershed
#             arcpy.AddField_management(subwatershed, "AREA", "DOUBLE")

#             area = arcpy.CalculateGeometryAttributes_management(subwatershed, "AREA AREA_GEODESIC", '', 
#                                                                 "SQUARE_KILOMETERS",
#                                                                 None)

#             #print area
#             rows = arcpy.SearchCursor(area)

#             for row in rows:
#                 area = row.getValue("AREA")

#             area_list.append(area)
#             print(area, " square kilometers")


#             #calculate perimeter of subwatershed
#             arcpy.AddField_management(subwatershed, "PERIMETER", "DOUBLE")
#             perimeter = arcpy.CalculateGeometryAttributes_management(subwatershed, "PERIMETER PERIMETER_LENGTH_GEODESIC",
#                                                                      "KILOMETERS")

#             print("perimeter calculated")

#             #print perimeter
#             rows = arcpy.SearchCursor(perimeter)

#             for row in rows:
#                 perimeter = row.getValue("PERIMETER")

#             perimeter_list.append(perimeter)
#             print(perimeter, " kilometers")



#             #get average slope using zonal statistics from slope dem
#             avg_slope = arcpy.sa.ZonalStatistics(subwatershed, "FID", dem_slope, "MEAN")

#             #get slope value
#             avg_slope_result = arcpy.GetRasterProperties_management(avg_slope, "MAXIMUM")

#             avg_slope_value = avg_slope_result.getOutput(0)

#             avg_slope_list.append(avg_slope_value)

#             print(avg_slope_value, " = avg slope (%)")


#             #calculate circulatory ratio
#             #ratio of area to the area of a circle having equal perimeter as the perimeter of drainage basin

#             #area of a circle with same perimeter as above
#             #C = 2(pi)r
#             #r = C/(2pi)
#             #A = (pi)r^2
#             circle_radius = perimeter/(2*numpy.pi)
#             print(circle_radius, "is the radius of a circle with the same perimeter.")
#             circle_area = (numpy.pi*(circle_radius**2))
#             print(circle_area, "is the area of a circle with the same perimeter.")

#             #ratio of subwatershed perimeter to circle circumference
#             circulatory_ratio = area / circle_area

#             circulatory_ratio_list.append(circulatory_ratio)
#             print(circulatory_ratio, " is the circulatory ratio")


#             #calculate relief
#             #elevation difference before basin outlet and highest point located in the perimeter of basin

#             #find highest point on perimeter

#             #use Raster Domain tool to get z-enabled polyline of perimeter
#             perimeter_polyline = arcpy.RasterDomain_3d(dem_clip, "perimeter_polyline.shp", "LINE")
#             print("created 3d polyline of subwatershed perimeter")

#             #Convert each vertices of the polyline into points
#             perimeter_points = arcpy.FeatureVerticesToPoints_management(perimeter_polyline, "perimeter_points.shp")
#             print("created perimeter points")

#             #get Z values into the attribute table for the points
#             perimeter_points_Z = arcpy.AddZInformation_3d(perimeter_points, "Z")
#             print("added z information")

#             #get the max value from all of the points
#             perimeter_stats = arcpy.Statistics_analysis(perimeter_points_Z, "perimeter_stats", [["Z", "MAX"], ["Z", "MIN"]])

#             # Get a list of field names to display
#             field_names = [i.name for i in arcpy.ListFields(perimeter_stats) if i.type != 'OID']

#             # Open a cursor to extract results from stats table
#             cursor = arcpy.da.SearchCursor(perimeter_stats, field_names)

#             # Create a pandas dataframe to display results
#             df = pd.DataFrame(data=[row for row in cursor],
#                                   columns=field_names)

#             print(df)

#             #get the values for max Z and min Z into a format to use them

#             rows = arcpy.SearchCursor(perimeter_stats)

#             for row in rows:
#                 max_z = row.getValue("MAX_Z")
#                 min_z = row.getValue("MIN_Z")


#             print(max_z)
#             print(min_z)

#             relief = max_z - min_z
#             print("The relief of the subwatershed is: ", relief," meters.")

#             relief_list.append(relief)



            #find area covered by A and AE zones and X NFHL Zones

#             #clip to subwatershed area
#             nfhl_sfha_clip = arcpy.Clip_analysis(nfhl_sfha, subwatershed, "nfhl_sfha.shp")

#             #select Zone A and Zone AE
#             nfhl_sfha_aae_selection = arcpy.management.SelectLayerByAttribute(nfhl_sfha_clip, "NEW_SELECTION", 
#                                                                "FLD_ZONE = 'AE' Or FLD_ZONE = 'A'", None)

#             #copy features to new feature class
#             nfhl_sfha_aae = arcpy.CopyFeatures_management(nfhl_sfha_aae_selection, "nfhl_sfha_aae")

#             #add new field for area
#             nfhl_sfha_aae_addfield = arcpy.AddField_management(nfhl_sfha_aae, "AREA", "DOUBLE")

#             #calculate the area for each of the features
#             aae_area = arcpy.CalculateGeometryAttributes_management(nfhl_sfha_aae_addfield, "AREA AREA_GEODESIC", '', 
#                                                                 "SQUARE_KILOMETERS",
#                                                                 None)
#             #get the sum of all of the areas
#             aae_area_list = []  

#             rows = arcpy.SearchCursor(aae_area)  
#             for row in rows:  
#                 aae_area_feature = row.getValue("AREA")  
#                 aae_area_list.append(aae_area_feature)  

#             aae_area_sum = sum(aae_area_list)

#             aae_list.append(aae_area_sum)

#             print(aae_area_sum, " = area of all AE and A zones in the subwatershed (square km)")



#             #select Zone X, 0.2% chance flood area
#             nfhl_sfha_x_selection = arcpy.management.SelectLayerByAttribute(nfhl_sfha_clip, "NEW_SELECTION", 
#                                                                "FLD_ZONE = 'X' And ZONE_SUBTY = '0.2 PCT ANNUAL CHANCE FLOOD HAZARD'",
#                                                                               None)

#             #copy features to new feature class
#             nfhl_sfha_x = arcpy.CopyFeatures_management(nfhl_sfha_x_selection, "nfhl_sfha_x")

#             #add new field for area
#             nfhl_sfha_x_addfield = arcpy.AddField_management(nfhl_sfha_x, "AREA", "DOUBLE")

#             #calculate the area for each of the features
#             x_area = arcpy.CalculateGeometryAttributes_management(nfhl_sfha_x_addfield, "AREA AREA_GEODESIC", '', 
#                                                                 "SQUARE_KILOMETERS",
#                                                                 None)
#             #get the sum of all of the areas
#             x_area_list = []  

#             rows = arcpy.SearchCursor(x_area)  
#             for row in rows:  
#                 x_area_feature = row.getValue("AREA")  
#                 x_area_list.append(x_area_feature)  

#             x_area_sum = sum(x_area_list)

#             x_list.append(x_area_sum)

#             print(x_area_sum, " = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)")


#             #calculate area covered by lakes/reserviors 

#             #clip to subwatershed area
#             water_bodies_clip = arcpy.Clip_analysis(water_bodies, subwatershed, "water_bodies.shp")

#             #copy features to new feature class
#             water_bodies_copy = arcpy.CopyFeatures_management(water_bodies_clip, "water_bodies_copy.shp")

#             #add new field for area
#             water_bodies_addfield = arcpy.AddField_management(water_bodies_copy, "AREA", "DOUBLE")

#             #calculate the area for each of the features
#             water_bodies_area = arcpy.CalculateGeometryAttributes_management(water_bodies_addfield, "AREA AREA_GEODESIC", '', 
#                                                                 "SQUARE_KILOMETERS",
#                                                                 None)
#             #get the sum of all of the areas
#             water_bodies_area_list = []  

#             rows = arcpy.SearchCursor(water_bodies_area)  
#             for row in rows:  
#                 wb_area_values = row.getValue("AREA")  
#                 water_bodies_area_list.append(wb_area_values)  

#             water_bodies_area_sum = sum(water_bodies_area_list)

#             water_bodies_list.append(water_bodies_area_sum)
#             print(water_bodies_area_sum, " = area of all water bodies in the subwatershed (square km)")


#             #count all of the dams in the subwatershed

#             #clip dams to subwatershed
#             dams_clip = arcpy.Clip_analysis(dams, subwatershed, "dams.shp")

#             #count number of dam points
#             dams_count = arcpy.GetCount_management(dams_clip)

#             dams_list.append(dams_count)

#             print(dams_count, " = number of dams in the subwatershed")



#             #count all of the bridges in the subwatershed

#             #clip bridges to subwatershed
#             bridges_clip = arcpy.Clip_analysis(bridges, subwatershed, "bridges.shp")

#             #count number of dam points
#             bridges_count = arcpy.GetCount_management(bridges_clip)

#             bridges_list.append(bridges_count)

#             print(bridges_count, " = number of bridges in the subwatershed")



#             #calculate the kilometers of streets in the subwatershed

#             #clip streets to subwatershed area 
#             streets_clip = arcpy.Clip_analysis(streets, subwatershed, "streets.shp")

#             #add field to calculate length of each street
#             streets_addfield = arcpy.AddField_management(streets_clip, "LENGTH_KM", "DOUBLE")

#             #calculate the area for each of the features
#             streets_length = arcpy.CalculateGeometryAttributes_management(streets_addfield, "LENGTH_KM LENGTH_GEODESIC", 
#                                                                           'KILOMETERS')
#             #get the sum of all of the areas
#             streets_lengths_list = []  

#             rows = arcpy.SearchCursor(streets_length)  
#             for row in rows:  
#                 streets_lengths_values = row.getValue("LENGTH_KM")  
#                 streets_lengths_list.append(streets_lengths_values)  

#             streets_length_sum = sum(streets_lengths_list)

#             streets_list.append(streets_length_sum)

#             print(streets_length_sum, " = sum of all streets in the subwatershed (km)")


#             #calculate km of railroads in subwatershed

#             #clip railroads to subwatershed area 
#             railroads_clip = arcpy.Clip_analysis(railroads, subwatershed, "railroads.shp")

#             #add field to calculate length of each railroad
#             railroads_addfield = arcpy.AddField_management(railroads_clip, "LENGTH_KM", "DOUBLE")

#             #calculate the area for each of the features
#             railroads_length = arcpy.CalculateGeometryAttributes_management(railroads_addfield, "LENGTH_KM LENGTH_GEODESIC", 'KILOMETERS', 
#                                                                 "",
#                                                                 None)
#             #get the sum of all of the areas
#             railroads_lengths_list = []  

#             rows = arcpy.SearchCursor(railroads_length)  
#             for row in rows:  
#                 railroads_lengths_values = row.getValue("LENGTH_KM")  
#                 railroads_lengths_list.append(railroads_lengths_values)  

#             railroads_length_sum = sum(railroads_lengths_list)

#             railroads_list.append(railroads_length_sum)

#             print(railroads_length_sum, " = sum of all railroads in the subwatershed (km)")   


#             #ACS population data - 5 year estimates (2014-2018) gotten from ESRI Living Atlas Data
#             #data is chosen to be on census tract level


#             #clip to subwatershed
#             population_clip = arcpy.Clip_analysis(population, subwatershed, "population.shp")

#             #get total population
#             #field = B01001_001E = Total Population (alias)
#             #when clipped, field name changes to B01001_001

#             #get the sum of all of the populations in each tract
#             total_pop_list = []  

#             rows = arcpy.SearchCursor(population_clip)  
#             for row in rows:  
#                 total_pop_value = row.getValue('B01001_001') 
#                 total_pop_list.append(total_pop_value)  

#             total_pop_sum = sum(total_pop_list)

#             population_list.append(total_pop_sum)
#             print(total_pop_sum, " = total population in the subwatershed") 

#             #get the average of percentages of dependent age groups in each tract
#             #field = B01001_calc_pctDependE = Percent of Population in Dependent Age Groups (under 18 and 65+) (alias)
#             #when clipped field changes to B01001_61
#             dependent_pop_list = []  

#             rows = arcpy.SearchCursor(population_clip)  
#             for row in rows:  
#                 dependent_pop_value = row.getValue('B01001__61') 
#                 dependent_pop_list.append(dependent_pop_value)  

#             dependent_pop_avg_pct = mean(dependent_pop_list)

#             dependent_population_list.append(dependent_pop_avg_pct)

#             print(dependent_pop_avg_pct, " = total percent of dependent population in the subwatershed") 

#             #find population density
#             population_density = total_pop_sum / area

#             population_density_list.append(population_density)

#             print(population_density, " = population density of subwatershed (people/square km)")


#             #ACS population data - 5 year estimates (2014-2018) gotten from ESRI Living Atlas Data
#             #data is chosen to be on census tract level

#             #clip to subwatershed
#             median_income_clip = arcpy.Clip_analysis(median_income, subwatershed, "median_income.shp")

#             #get average median income 
#             #field = B19049_001 = Median Household Income in past 12 months 
#             #^(inflation-adjusted dollars to last year of 5-year range) (alias)

#             #get the sum of all of the populations in each tract
#             total_median_income_list = []  

#             rows = arcpy.SearchCursor(median_income_clip)  
#             for row in rows:  
#                 median_income_value = row.getValue('B19049_001') 
#                 total_median_income_list.append(median_income_value)  

#             median_income_average = mean(total_median_income_list)

#             avg_median_income_list.append(median_income_average)

#             print(median_income_average, " = average median income in the subwatershed") 


#             #get housing density

#             #clip building footprints to subwatershed area
#               building_footprints_clip = arcpy.Clip_analysis(building_footprints, subwatershed, "building_footprints.shp")

#             #select buildings that are marked residential
#               building_footprints_residential = arcpy.SelectLayerByAttribute_management(building_footprints_clip, "NEW_SELECTION",
#                                                                                  "RES_NONRES = 'Res'")

#             #get count of how many buildings there are 
#             buildings_count = arcpy.GetCount_management(building_footprints_residential)

#             buildings_count_number = buildings_count.getOutput(0)
#             print(buildings_count_number, " = number of residential building footprints in the subwatershed")

#             #divide number of buildings by subwatershed area
#             housing_density = int(buildings_count_number) / area

#             housing_density_list.append(housing_density)

#             print(housing_density, " = housing density (buildings per square km)")


#             #find total population from the 2013 5-year ACS estimates
#             #get the sum of all of the 2013 populations in each tract
#             #field = DP05_0001E = TotalPopulation from the 2013 ACS 5yr estimates
#             total_pop_list_2013 = []  

#             rows = arcpy.SearchCursor(population_clip)  
#             for row in rows:  
#                 total_pop_value_2013 = row.getValue('DP05_0001E')
#                 if total_pop_value_2013 != '0':
#                     total_pop_list_2013.append(int(total_pop_value_2013))  

#             total_pop_sum_2013 = sum( total_pop_list_2013)

#             print(total_pop_sum_2013, " = total 2013 population in the subwatershed") 

#             #find population change between 2018 and 2013
#             population_change = total_pop_sum - total_pop_sum_2013

#             population_change_list.append(population_change)
#             print(population_change, " = population change between 2013 and 2018")




            #calculate drainage density
            #the total length of all streams and tributaries divided by basin area

            #all streams in subwatershed
            streams_clip = arcpy.Clip_analysis(streams, subwatershed, "streams")
            print("streams clipped")

#             #add field for length
#             streams_addfield = arcpy.AddField_management(streams_clip, "LENGTH", "DOUBLE")

#             #calculate geometry 
#             streams_calculate = arcpy.CalculateGeometryAttributes_management(streams_addfield, [["LENGTH", "LENGTH_GEODESIC"]], 
#                                                                              "KILOMETERS")
#             print("length calculated")

#             #get the sum of all of the areas
#             stream_length_list = []  

#             rows = arcpy.SearchCursor(streams_calculate)  
#             for row in rows:  
#                 stream_length = row.getValue("LENGTH")  
#                 stream_length_list.append(stream_length)  

#             stream_length_sum = sum(stream_length_list)

#             print(stream_length_sum, " = length of all streams in subwatershed")

#             print(area, " = subwatershed area")

#             drainage_density = stream_length_sum / area

#             drainage_density_list.append(drainage_density)

#             print(drainage_density, "is the drainage density (streams/km)")

#             #find watershed length
#             #watershed length = distance from outlet to watershed boundary along the main channel
#             #we are assuming that the longest stream above is the main channel

#             watershed_length = max(stream_length_list)

#             watershed_length_list.append(watershed_length)

#             print(watershed_length, " = watershed length (longest stream in subwatershed)")


#             #calculate shape factor 
#             #watershed length squared divided by watershed area

#             shape_factor = (watershed_length**2) / area

#             shape_factor_list.append(shape_factor)

#             print(shape_factor, " is the shape factor.")



#             #calculate relief ratio
#             #relief divided by watershed length
#             #length is is kilometers, convert to meters

#             watershed_length_meters = watershed_length * 1000

#             relief_ratio = relief / watershed_length_meters

#             relief_ratio_list.append(relief_ratio)

#             print(relief_ratio, " = relief ratio")


#             #calculate ruggedness number
#             #product of relief and drainage density

#             #relief is in meters, convert first to km
#             relief_km = relief / 1000
#             print(relief_km, " is the relief in km")

#             ruggedness = relief_km * drainage_density

#             ruggedness_list.append(ruggedness)
#             print(ruggedness, " is the ruggedness number")


            #calculate elongation ratio
            #ratio of diameter of a circle having the same area as the basin to the max basin length


            # diameter of circle with same area
#             A = (pi)r^2
#             r = sqrt(A/pi)
#             d = r*2

#             radius = numpy.sqrt(area/numpy.pi)
#             print(radius, " miles is the radius of a circle with the same area.")

#             diameter = radius*2
#             print(diameter, " miles is the diameter of a circle with the same area.")

#             elongation_ratio = diameter / watershed_length

#             elongation_ratio_list.append(elongation_ratio)


#             #get number of buildings inside the aae zone

#             buildings_aae_select = arcpy.SelectLayerByLocation_management(building_footprints_clip, "INTERSECT", nfhl_sfha_aae )

#             buildings_aae = arcpy.CopyFeatures_management(buildings_aae_select, "buildings_aae.shp")

#             buildings_aae_count = arcpy.GetCount_management(buildings_aae)

#             buildings_aae_list.append(buildings_aae_count)

#             #get number of buildings inside the x zone

#             buildings_x_select = arcpy.SelectLayerByLocation_management(building_footprints_clip, "INTERSECT", nfhl_sfha_x )

#             buildings_x = arcpy.CopyFeatures_management(buildings_x_select, "buildings_x.shp")

#             buildings_x_count = arcpy.GetCount_management(buildings_x)

#             buildings_x_list.append(buildings_x_count)

            #get area of various land use codes
            #clip usa land use polygon to the subwatershed
#             lu_subwatershed = arcpy.Clip_analysis(lu_usa, subwatershed, "lu_subwatershed.shp")

#             lu_subwatershed_area = arcpy.AddGeometryAttributes_management(lu_subwatershed, "AREA_GEODESIC", '',
#                                                               "SQUARE_KILOMETERS")


#             #lu 21 = developed open space
#             lu_21_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 21")

#             lu_21 = arcpy.CopyFeatures_management(lu_21_select, "lu_21.shp")

#             #get the sum of all of the areas
#             lu_21_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_21)  
#             for row in rows:  
#                 lu_21_polygon = row.getValue("AREA_GEO")  
#                 lu_21_polygons_list.append(lu_21_polygon)  

#             lu_21_area_sum = sum(lu_21_polygons_list)

#             lu_21_list.append(lu_21_area_sum)



#             #lu 22 = developed low intensity
#             lu_22_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 22")

#             lu_22 = arcpy.CopyFeatures_management(lu_22_select, "lu_22.shp")

#             #get the sum of all of the areas
#             lu_22_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_22)  
#             for row in rows:  
#                 lu_22_polygon = row.getValue("AREA_GEO")  
#                 lu_22_polygons_list.append(lu_22_polygon)  

#             lu_22_area_sum = sum(lu_22_polygons_list)

#             lu_22_list.append(lu_22_area_sum)


#             #lu 23 = developed medium intensity
#             lu_23_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 23")

#             lu_23 = arcpy.CopyFeatures_management(lu_23_select, "lu_23.shp")

#             #get the sum of all of the areas
#             lu_23_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_23)  
#             for row in rows:  
#                 lu_23_polygon = row.getValue("AREA_GEO")  
#                 lu_23_polygons_list.append(lu_23_polygon)  

#             lu_23_area_sum = sum(lu_23_polygons_list)

#             lu_23_list.append(lu_23_area_sum)



#             #lu 24 = developed high intensity
#             lu_24_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 24")

#             lu_24 = arcpy.CopyFeatures_management(lu_24_select, "lu_24.shp")

#             #get the sum of all of the areas
#             lu_24_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_24)  
#             for row in rows:  
#                 lu_24_polygon = row.getValue("AREA_GEO")  
#                 lu_24_polygons_list.append(lu_24_polygon)  

#             lu_24_area_sum = sum(lu_24_polygons_list)

#             lu_24_list.append(lu_24_area_sum)



#             #lu 41 = deciduous forest
#             lu_41_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 41")

#             lu_41 = arcpy.CopyFeatures_management(lu_41_select, "lu_41.shp")

#             #get the sum of all of the areas
#             lu_41_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_41)  
#             for row in rows:  
#                 lu_41_polygon = row.getValue("AREA_GEO")  
#                 lu_41_polygons_list.append(lu_41_polygon)  

#             lu_41_area_sum = sum(lu_41_polygons_list)

#             lu_41_list.append(lu_41_area_sum)


#             #lu 82 = cultivated crops
#             lu_82_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 82")

#             lu_82 = arcpy.CopyFeatures_management(lu_82_select, "lu_82.shp")

#             #get the sum of all of the areas
#             lu_82_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_82)  
#             for row in rows:  
#                 lu_82_polygon = row.getValue("AREA_GEO")  
#                 lu_82_polygons_list.append(lu_82_polygon)  

#             lu_82_area_sum = sum(lu_82_polygons_list)

#             lu_82_list.append(lu_82_area_sum)

            
#             #get percent impervious indicator for subwatershed area
#             avg_impervious_pct = arcpy.sa.ZonalStatistics(subwatershed, "FID", impervious_usa, "MEAN" )

#             #get avg value  value
#             avg_impervious_result = arcpy.GetRasterProperties_management(avg_impervious_pct, "MAXIMUM")

#             #avg_impervious_pct_value = avg_impervious_result.getOutput(0)
#             print(impervious_value, " = avg impervious percent ")

#             impervious_percent_list.append(impervious_value)



#             #get distance from residential buildings to streams

            building_footprints_residential_copy = arcpy.CopyFeatures_management(building_footprints_residential, "buildings_res.shp")


#             #project buildings and streams so they are in the same GCS
            output_coord_system = arcpy.SpatialReference(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\Indiana_ML\working_dsn\NAD1983_ProjectionFile.prj")

            streams_project = arcpy.Project_management(streams_clip, "streams_project.shp",
                                                      output_coord_system)

            buildings_project = arcpy.Project_management(building_footprints_residential_copy, "buildings_res_project.shp",
                                                      output_coord_system)

            #use near tool to get distance to steams

            buildings_near = arcpy.Near_analysis(buildings_project, streams_project, "", "LOCATION", "", "GEODESIC")

            #get all the distances in to the streams
            dist_to_stream_list = []
            rows = arcpy.SearchCursor(buildings_near)  
            for row in rows:  
                dist_to_stream = row.getValue("NEAR_DIST")  
                dist_to_stream_list.append(dist_to_stream)  

            dist_to_stream_avg = mean(dist_to_stream_list)

            dist_to_stream_stdev = std(dist_to_stream_list)
            
            dist_to_stream_skewness = skew(dist_to_stream_list)
        
            dist_to_stream_kurtosis = kurtosis(dist_to_stream_list)


            print("Distance to stream avg", dist_to_stream_avg)
            print("Distance to stream std", dist_to_stream_stdev)
            print("Distance to stream skewness", dist_to_stream_skewness)
            print("Distance to stream kurtosis", dist_to_stream_kurtosis)

            dist_to_stream_avg_list.append(dist_to_stream_avg)
            dist_to_stream_stdev_list.append(dist_to_stream_stdev)
            dist_to_stream_skewness_list.append(dist_to_stream_skewness)
            dist_to_stream_kurtosis_list.append(dist_to_stream_kurtosis)


#          ## LOOP    

#             #loop through all rainfall rasters in the same folder 


#             arcpy.env.workspace = directory_rainfall

#             rasters = arcpy.ListRasters("orb*")

#             for raster in rasters:

#                 raster_name = os.path.basename(raster).rstrip(os.path.splitext(raster)[1])
#                 print("Raster name: ", raster_name)

#                 #get average rainfall for duration using zonal statistics
#                 #elevRaster = arcpy.sa.Raster(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\Indiana_ML\working_dsn\dem_clip.tif")

#                 centroid_rainfall = arcpy.sa.ExtractValuesToPoints(centroid, raster, r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\shp\Centroid_Rainfall.shp", "NONE", "VALUE_ONLY")

#                 # Open a cursor on some fields in a table  
#                 rainfall_value = arcpy.da.SearchCursor(centroid_rainfall, ("RASTERVALU",)).next()[0]


#         #         avg_rainfall = arcpy.sa.ZonalStatistics(subwatershed, "FID", raster, "MEAN" )

#         #         #get avg value  value
#         #         avg_result = arcpy.GetRasterProperties_management(avg_rainfall, "MAXIMUM")

#                 #rainfall_value = avg_result.getOutput(0)
#                 print(rainfall_value, " = avg rainfall in inches *1000")

#                 if raster_name == "orb100yr06h":
#                     orb100yr06h_list.append(rainfall_value)

#                 elif raster_name == "orb100yr12h":
#                     orb100yr12h_list.append(rainfall_value)

#                 elif raster_name == "orb100yr24h":
#                     orb100yr24h_list.append(rainfall_value)

#                 elif raster_name == "orb25yr06h":
#                     orb25yr06h_list.append(rainfall_value)

#                 elif raster_name == "orb25yr12h":
#                     orb25yr12h_list.append(rainfall_value)

#                 elif raster_name == "orb25yr24h":
#                     orb25yr24h_list.append(rainfall_value)

#                 elif raster_name == "orb2yr06h":
#                     orb2yr06h_list.append(rainfall_value)

#                 elif raster_name == "orb2yr12h":
#                     orb2yr12h_list.append(rainfall_value)

#                 elif raster_name == "orb2yr24h":
#                     orb2yr24h_list.append(rainfall_value)

#                 elif raster_name == "orb50yr06h":
#                     orb50yr06h_list.append(rainfall_value)

#                 elif raster_name == "orb50yr12h":
#                     orb50yr12h_list.append(rainfall_value)

#                 elif raster_name == "orb50yr24h":
#                     orb50yr24h_list.append(rainfall_value)

#                 elif raster_name == "orb100yr06ha_am":
#                     orb100yr06ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb100yr12ha_am":
#                     orb100yr12ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb100yr24ha_am":
#                     orb100yr24ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb25yr06ha_am":
#                     orb25yr06ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb25yr12ha_am":
#                     orb25yr12ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb25yr24ha_am":
#                     orb25yr24ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb2yr06ha_am":
#                     orb2yr06ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb2yr12ha_am":
#                     orb2yr12ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb2yr24ha_am":
#                     orb2yr24ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb50yr06ha_am":
#                     orb50yr06ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb50yr12ha_am":
#                     orb50yr12ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb50yr24ha_am":
#                     orb50yr24ha_am_list.append(rainfall_value)

#                 else:
#                     continue 



            #set workspace environment back to the newly created folder
            arcpy.env.workspace = output_workspace
            print(round(((time()-st)/60), 2) , 'minutes to process.')  


    
    
#########################################################################################


    
    
print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
# ------ Subwatershed: 050800030201 Number 312 of 1590 ------
# streams clipped
# Distance to stream avg 450.7104858711798
# Distance to stream std 261.2974531384665
# Distance to stream skewness -0.07387876818430196
# Distance to stream kurtosis -0.9347787547062216
# 0.19 minutes to process.
# ------ Subwatershed: 041000040503 Number 313 of 1590 ------
# streams clipped
# Distance to stream avg 429.96315266065614
# Distance to stream std 400.50172126199925
# Distance to stream skewness 1.3708327823230462
# Distance to stream kurtosis 1.367295693604218
# 0.17 minutes to process.
# ------ Subwatershed: 051202090406 Number 314 of 1590 ------
# streams clipped
# Distance to stream avg 258.8972788825322
# Distance to stream std 164.8775886351803
# Distance to stream skewness 0.85295431779005
# Distance to stream kurtosis 0.678535939364842
# 0.21 minutes to process.
# ------ Subwatershed: 051202070705 Number 315 of 1590 ------
# streams clipped
# Distance to stream avg 246.51953412197938
# Distance to stream std 202.29437220212398
# Distance to stream skewness 1.832284055639949
# Distance to stream kurtosis 3.706783553213575
# 0.15 minutes to process.
# ------ Subwatershed: 051201030504 Number 316 of 1590 ------
# streams clipped
# Distance to stream avg 356.1490305864866
# Distance to stream std 289.0746267866887
# Distance to stream skewness 1.7939231083966793
# Distance to stream kurtosis 4.2068817588871354
# 0.23 minutes to process.
# ------ Subwatershed: 051201020405 Number 317 of 1590 ------
# streams clipped
# Distance to stream avg 339.5230038740004
# Distance to stream std 251.95192869115073
# Distance to stream skewness 1.5866717220767386
# Distance to stream kurtosis 3.520853209976221
# 0.14 minutes to process.
# ------ Subwatershed: 071200021301 Number 318 of 1590 ------
# streams clipped
# Distance to stream avg 286.7369118989362
# Distance to stream std 264.75920461399755
# Distance to stream skewness 1.8850694600808788
# Distance to stream kurtosis 4.183676682240962
# 0.13 minutes to process.
# ------ Subwatershed: 051201060701 Number 319 of 1590 ------
# streams clipped
# Distance to stream avg 345.96872705770346
# Distance to stream std 328.65549733353186
# Distance to stream skewness 2.4479371621193056
# Distance to stream kurtosis 7.673174106152697
# 0.14 minutes to process.
# ------ Subwatershed: 051402010703 Number 320 of 1590 ------
# streams clipped
# Distance to stream avg 349.4225418957842
# Distance to stream std 238.293250044761
# Distance to stream skewness 0.4848953301393987
# Distance to stream kurtosis -0.8852051236338752
# 0.31 minutes to process.
# ------ Subwatershed: 051202010103 Number 321 of 1590 ------
# streams clipped
# Distance to stream avg 702.6510272372551
# Distance to stream std 720.7881040059851
# Distance to stream skewness 2.2806136820950726
# Distance to stream kurtosis 6.853397929692417
# 0.14 minutes to process.
# ------ Subwatershed: 040500011003 Number 322 of 1590 ------
# streams clipped
# Distance to stream avg 471.1089118667202
# Distance to stream std 310.8214725620402
# Distance to stream skewness 0.6031402008052492
# Distance to stream kurtosis -0.46182832448042754
# 0.2 minutes to process.
# ------ Subwatershed: 051202080304 Number 323 of 1590 ------
# streams clipped
# Distance to stream avg 696.2609214950087
# Distance to stream std 422.19776564329163
# Distance to stream skewness 0.6548645395668621
# Distance to stream kurtosis 0.599917574273471
# 0.23 minutes to process.
# ------ Subwatershed: 051201050101 Number 324 of 1590 ------
# streams clipped
# Distance to stream avg 786.4391578028661
# Distance to stream std 505.1239422198241
# Distance to stream skewness 0.37386162575172555
# Distance to stream kurtosis -1.0218335127129765
# 0.14 minutes to process.
# ------ Subwatershed: 051401010806 Number 325 of 1590 ------
# streams clipped
# Distance to stream avg 338.9383286258288
# Distance to stream std 292.21143645152637
# Distance to stream skewness 2.0332188745040067
# Distance to stream kurtosis 5.440366458385935
# 0.63 minutes to process.
# ------ Subwatershed: 040400010103 Number 326 of 1590 ------
# streams clipped
# Distance to stream avg 405.3885124912444
# Distance to stream std 284.05737802146103
# Distance to stream skewness 0.7262855139180892
# Distance to stream kurtosis -0.29153030294076476
# 0.24 minutes to process.
# ------ Subwatershed: 051201110703 Number 327 of 1590 ------
# streams clipped
# Distance to stream avg 542.1185416356807
# Distance to stream std 314.85222626319097
# Distance to stream skewness 0.050293707831631805
# Distance to stream kurtosis -1.2144693104477977
# 0.16 minutes to process.
# ------ Subwatershed: 051202040901 Number 328 of 1590 ------
# streams clipped
# Distance to stream avg 284.3849969405524
# Distance to stream std 193.50348613541559
# Distance to stream skewness 0.8180442492235255
# Distance to stream kurtosis -0.20912299173971416
# 0.17 minutes to process.
# ------ Subwatershed: 051202010804 Number 329 of 1590 ------
# streams clipped
# Distance to stream avg 848.2745292772242
# Distance to stream std 636.8421101143431
# Distance to stream skewness 1.6917929547747064
# Distance to stream kurtosis 4.685041389030871
# 0.49 minutes to process.
# ------ Subwatershed: 071200011305 Number 330 of 1590 ------
# streams clipped
# Distance to stream avg 332.53572983189906
# Distance to stream std 294.57320878103695
# Distance to stream skewness 2.1924135219039145
# Distance to stream kurtosis 6.062350544763801
# 0.15 minutes to process.
# ------ Subwatershed: 071200010806 Number 331 of 1590 ------
# streams clipped
# Distance to stream avg 244.07645356605818
# Distance to stream std 165.03706995957023
# Distance to stream skewness 1.319719494357511
# Distance to stream kurtosis 2.589117217022104
# 0.14 minutes to process.
# ------ Subwatershed: 071200011006 Number 332 of 1590 ------
# streams clipped
# Distance to stream avg 432.2471289663872
# Distance to stream std 414.72701591898687
# Distance to stream skewness 1.5321429503228456
# Distance to stream kurtosis 1.5717568104207915
# 0.14 minutes to process.
# ------ Subwatershed: 051202021006 Number 333 of 1590 ------
# streams clipped
# Distance to stream avg 410.37678226120056
# Distance to stream std 295.71646576554843
# Distance to stream skewness 1.0175716662420522
# Distance to stream kurtosis 1.3797933062688061
# 0.15 minutes to process.
# ------ Subwatershed: 051202060601 Number 334 of 1590 ------
# streams clipped
# Distance to stream avg 430.24612122386424
# Distance to stream std 285.77020621800074
# Distance to stream skewness 0.45318962513603056
# Distance to stream kurtosis -0.8834735326315912
# 0.19 minutes to process.
# ------ Subwatershed: 051202020309 Number 335 of 1590 ------
# streams clipped
# Distance to stream avg 316.2412587876661
# Distance to stream std 166.75054672608184
# Distance to stream skewness 0.3547412980809111
# Distance to stream kurtosis -0.3684016383194213
# 0.14 minutes to process.
# ------ Subwatershed: 051201081503 Number 336 of 1590 ------
# streams clipped
# Distance to stream avg 457.07442857838316
# Distance to stream std 242.6227152627309
# Distance to stream skewness 0.20652017123891395
# Distance to stream kurtosis -1.1221074871536092
# 0.16 minutes to process.
# ------ Subwatershed: 051201060406 Number 337 of 1590 ------
# streams clipped
# Distance to stream avg 504.09630663339124
# Distance to stream std 484.76522433875556
# Distance to stream skewness 1.621945897833407
# Distance to stream kurtosis 2.5575257276592493
# 0.15 minutes to process.
# ------ Subwatershed: 051401010605 Number 338 of 1590 ------
# streams clipped
# Distance to stream avg 371.7820266906732
# Distance to stream std 242.66652734637134
# Distance to stream skewness 1.093280720949484
# Distance to stream kurtosis 1.4245593680423116
# 0.39 minutes to process.
# ------ Subwatershed: 051202080807 Number 339 of 1590 ------
# streams clipped
# Distance to stream avg 574.7220040343101
# Distance to stream std 492.04846962665226
# Distance to stream skewness 1.612318961657386
# Distance to stream kurtosis 2.3196176853671995
# 0.24 minutes to process.
# ------ Subwatershed: 051202011406 Number 340 of 1590 ------
# streams clipped
# Distance to stream avg 289.4734284813829
# Distance to stream std 218.9787805360278
# Distance to stream skewness 1.2295825849340731
# Distance to stream kurtosis 1.5032477231293733
# 0.22 minutes to process.
# ------ Subwatershed: 071200011310 Number 341 of 1590 ------
# streams clipped
# Distance to stream avg 374.61211674957417
# Distance to stream std 234.22348769787882
# Distance to stream skewness 0.6228138768137359
# Distance to stream kurtosis -0.37074920732509886
# 0.16 minutes to process.
# ------ Subwatershed: 071200010312 Number 342 of 1590 ------
# streams clipped
# Distance to stream avg 510.1296132899481
# Distance to stream std 390.1634019017761
# Distance to stream skewness 1.1449410040997985
# Distance to stream kurtosis 1.1151586582971271
# 0.18 minutes to process.
# ------ Subwatershed: 051201020102 Number 343 of 1590 ------
# streams clipped
# Distance to stream avg 245.90121866860588
# Distance to stream std 186.83703314056248
# Distance to stream skewness 1.063187174310809
# Distance to stream kurtosis 0.43160724425895625
# 0.19 minutes to process.
# ------ Subwatershed: 051202081002 Number 344 of 1590 ------
# streams clipped
# Distance to stream avg 645.4399277312432
# Distance to stream std 459.9884481869018
# Distance to stream skewness 1.3113703873025826
# Distance to stream kurtosis 1.775166152490499
# 0.19 minutes to process.
# ------ Subwatershed: 051201070205 Number 345 of 1590 ------
# streams clipped
# Distance to stream avg 568.7161885850728
# Distance to stream std 824.3421622835467
# Distance to stream skewness 4.293883081464951
# Distance to stream kurtosis 22.345608173473565
# 0.18 minutes to process.
# ------ Subwatershed: 051201050501 Number 346 of 1590 ------
# streams clipped
# Distance to stream avg 489.8804871147876
# Distance to stream std 436.2771204399708
# Distance to stream skewness 1.6794734664554662
# Distance to stream kurtosis 3.05261190248868
# 0.19 minutes to process.
# ------ Subwatershed: 071200020403 Number 347 of 1590 ------
# streams clipped
# Distance to stream avg 327.03626053305413
# Distance to stream std 311.19422086424305
# Distance to stream skewness 4.116147197767042
# Distance to stream kurtosis 25.282759934651637
# 0.17 minutes to process.
# ------ Subwatershed: 051401040604 Number 348 of 1590 ------
# streams clipped
# Distance to stream avg 189.26624183586745
# Distance to stream std 128.4418802785973
# Distance to stream skewness 1.497867708503189
# Distance to stream kurtosis 3.749806079782953
# 0.18 minutes to process.
# ------ Subwatershed: 051401040301 Number 349 of 1590 ------
# streams clipped
# Distance to stream avg 169.34417064980184
# Distance to stream std 110.18697530110768
# Distance to stream skewness 1.2379316100477131
# Distance to stream kurtosis 2.1254308718671338
# 0.2 minutes to process.
# ------ Subwatershed: 051201090704 Number 350 of 1590 ------
# streams clipped
# Distance to stream avg 281.83030135976765
# Distance to stream std 200.64557331799938
# Distance to stream skewness 2.417515323723
# Distance to stream kurtosis 5.427390893010342
# 0.14 minutes to process.
# ------ Subwatershed: 050800030305 Number 351 of 1590 ------
# streams clipped
# Distance to stream avg 198.96813424931534
# Distance to stream std 188.1790698489508
# Distance to stream skewness 1.3810941659906972
# Distance to stream kurtosis 1.0594217608836969
# 0.16 minutes to process.
# ------ Subwatershed: 051201130206 Number 352 of 1590 ------
# streams clipped
# Distance to stream avg 138.27218302468333
# Distance to stream std 102.75534883571017
# Distance to stream skewness 0.5577539653890932
# Distance to stream kurtosis -1.4536763405435544
# 0.15 minutes to process.
# ------ Subwatershed: 051202020206 Number 353 of 1590 ------
# streams clipped
# Distance to stream avg 350.79441669433356
# Distance to stream std 269.5543025839655
# Distance to stream skewness 1.297225879537004
# Distance to stream kurtosis 1.947364290225524
# 0.19 minutes to process.
# ------ Subwatershed: 051202050301 Number 354 of 1590 ------
# streams clipped
# Distance to stream avg 522.6278643098381
# Distance to stream std 406.4530727759231
# Distance to stream skewness 1.1363285925844697
# Distance to stream kurtosis 0.8721919955508581
# 0.17 minutes to process.
# ------ Subwatershed: 051401010302 Number 355 of 1590 ------
# streams clipped
# Distance to stream avg 380.1917106791703
# Distance to stream std 251.63818535975872
# Distance to stream skewness 1.0772348125308706
# Distance to stream kurtosis 1.457629743706919
# 0.41 minutes to process.
# ------ Subwatershed: 050800030805 Number 356 of 1590 ------
# streams clipped
# Distance to stream avg 251.51039188456141
# Distance to stream std 166.4285626033791
# Distance to stream skewness 0.5868849530043638
# Distance to stream kurtosis -0.3543536912581575
# 0.18 minutes to process.
# ------ Subwatershed: 051201040509 Number 357 of 1590 ------
# streams clipped
# Distance to stream avg 439.96058752647764
# Distance to stream std 438.5321907630118
# Distance to stream skewness 1.7350938048449571
# Distance to stream kurtosis 2.702746663859018
# 0.17 minutes to process.
# ------ Subwatershed: 051201060303 Number 358 of 1590 ------
# streams clipped
# Distance to stream avg 487.3267020967294
# Distance to stream std 400.0497049792144
# Distance to stream skewness 1.3108551968356832
# Distance to stream kurtosis 1.2240217180840558
# 0.18 minutes to process.
# ------ Subwatershed: 051201060101 Number 359 of 1590 ------
# streams clipped
# Distance to stream avg 450.2271657989719
# Distance to stream std 350.88969459891194
# Distance to stream skewness 1.2301751696921301
# Distance to stream kurtosis 1.384834149154491
# 0.16 minutes to process.
# ------ Subwatershed: 071200030203 Number 360 of 1590 ------
# streams clipped
# Distance to stream avg 469.8492994133856
# Distance to stream std 257.82324447104816
# Distance to stream skewness 0.07276255193858965
# Distance to stream kurtosis -0.6243831057230018
# 0.23 minutes to process.
# ------ Subwatershed: 051402010905 Number 361 of 1590 ------
# streams clipped
# Distance to stream avg 290.67575865131107
# Distance to stream std 166.25222056032214
# Distance to stream skewness 0.6969411902922948
# Distance to stream kurtosis 0.05710621418849815
# 0.17 minutes to process.
# ------ Subwatershed: 051202081509 Number 362 of 1590 ------
# streams clipped
# Distance to stream avg 355.2723130560426
# Distance to stream std 284.2677857508559
# Distance to stream skewness 0.8652718620984555
# Distance to stream kurtosis -0.5633989932203911
# 0.16 minutes to process.
# ------ Subwatershed: 051202040204 Number 363 of 1590 ------
# streams clipped
# Distance to stream avg 582.5733549934316
# Distance to stream std 776.9100583471974
# Distance to stream skewness 2.2344536761130986
# Distance to stream kurtosis 4.0583136322012905
# 0.17 minutes to process.
# ------ Subwatershed: 051201010703 Number 364 of 1590 ------
# streams clipped
# Distance to stream avg 493.46215847017527
# Distance to stream std 374.90912705641597
# Distance to stream skewness 1.2029570691297404
# Distance to stream kurtosis 1.7231508052547753
# 0.18 minutes to process.
# ------ Subwatershed: 051201011006 Number 365 of 1590 ------
# streams clipped
# Distance to stream avg 239.28927168172504
# Distance to stream std 215.41639217234982
# Distance to stream skewness 2.329282018552845
# Distance to stream kurtosis 8.19251637146309
# 0.23 minutes to process.
# ------ Subwatershed: 051201060504 Number 366 of 1590 ------
# streams clipped
# Distance to stream avg 555.8995047459013
# Distance to stream std 428.79589843833605
# Distance to stream skewness 1.126978528468534
# Distance to stream kurtosis 0.3902621455148263
# 0.19 minutes to process.
# ------ Subwatershed: 051201111106 Number 367 of 1590 ------
# streams clipped
# Distance to stream avg 139.1302674431158
# Distance to stream std 77.16978882320643
# Distance to stream skewness 1.0547847321249408
# Distance to stream kurtosis 1.5987099434952903
# 0.18 minutes to process.
# ------ Subwatershed: 051202020504 Number 368 of 1590 ------
# streams clipped
# Distance to stream avg 443.47125397296384
# Distance to stream std 286.55710729235324
# Distance to stream skewness 0.6799949431055413
# Distance to stream kurtosis -0.5394100353613345
# 0.18 minutes to process.
# ------ Subwatershed: 051201111509 Number 369 of 1590 ------
# streams clipped
# Distance to stream avg 389.49322704761084
# Distance to stream std 193.4060737158351
# Distance to stream skewness 0.23787215553468152
# Distance to stream kurtosis -0.6235308805553812
# 0.24 minutes to process.
# ------ Subwatershed: 051202030809 Number 370 of 1590 ------
# streams clipped
# Distance to stream avg 422.2588880203932
# Distance to stream std 251.8040618584756
# Distance to stream skewness 0.30243304476029065
# Distance to stream kurtosis -0.8512525830616275
# 0.24 minutes to process.
# ------ Subwatershed: 051202030803 Number 371 of 1590 ------
# streams clipped
# Distance to stream avg 315.0836015715234
# Distance to stream std 209.5450800839413
# Distance to stream skewness 1.2960481701122641
# Distance to stream kurtosis 2.5348294407345184
# 0.19 minutes to process.
# ------ Subwatershed: 051201110403 Number 372 of 1590 ------
# streams clipped
# Distance to stream avg 398.8755956086552
# Distance to stream std 326.151145146793
# Distance to stream skewness 1.690734016476495
# Distance to stream kurtosis 2.8908193977296586
# 0.21 minutes to process.
# ------ Subwatershed: 051201070308 Number 373 of 1590 ------
# streams clipped
# Distance to stream avg 629.4544188236144
# Distance to stream std 438.47891342764296
# Distance to stream skewness 1.3757535732791493
# Distance to stream kurtosis 4.994714316443881
# 0.26 minutes to process.
# ------ Subwatershed: 071200020201 Number 374 of 1590 ------
# streams clipped
# Distance to stream avg 709.5015165465762
# Distance to stream std 828.1011277891768
# Distance to stream skewness 2.3703419612613397
# Distance to stream kurtosis 5.1901909627776615
# 0.18 minutes to process.
# ------ Subwatershed: 071200011306 Number 375 of 1590 ------
# streams clipped
# Distance to stream avg 449.2843593238117
# Distance to stream std 342.41012624171526
# Distance to stream skewness 1.4055895967898355
# Distance to stream kurtosis 2.7604405531601035
# 0.5 minutes to process.
# ------ Subwatershed: 051201111203 Number 376 of 1590 ------
# streams clipped
# Distance to stream avg 183.15137008170842
# Distance to stream std 122.77793632272224
# Distance to stream skewness 0.8971238542861989
# Distance to stream kurtosis -0.09278891172709658
# 0.2 minutes to process.
# ------ Subwatershed: 051202060105 Number 377 of 1590 ------
# streams clipped
# Distance to stream avg 319.684890469899
# Distance to stream std 324.9983757768849
# Distance to stream skewness 1.3974659230833002
# Distance to stream kurtosis 0.8050537933049058
# 0.24 minutes to process.
# ------ Subwatershed: 051202040603 Number 378 of 1590 ------
# streams clipped
# Distance to stream avg 395.43656624946505
# Distance to stream std 243.32689282794863
# Distance to stream skewness 0.5372527325181696
# Distance to stream kurtosis -0.1252122067107866
# 0.58 minutes to process.
# ------ Subwatershed: 050800030504 Number 379 of 1590 ------
# streams clipped
# Distance to stream avg 258.2435766199808
# Distance to stream std 160.17065227440654
# Distance to stream skewness 0.5281479540885835
# Distance to stream kurtosis -0.6371905245254816
# 0.23 minutes to process.
# ------ Subwatershed: 051202050404 Number 380 of 1590 ------
# streams clipped
# Distance to stream avg 296.9274566674113
# Distance to stream std 227.3988205436155
# Distance to stream skewness 1.054636282521457
# Distance to stream kurtosis 0.7255298727168658
# 0.22 minutes to process.
# ------ Subwatershed: 051201110303 Number 381 of 1590 ------
# streams clipped
# Distance to stream avg 496.16170011219043
# Distance to stream std 348.2147565268517
# Distance to stream skewness 0.8574719475021788
# Distance to stream kurtosis -0.20450730892870217
# 0.25 minutes to process.
# ------ Subwatershed: 050800030103 Number 382 of 1590 ------
# streams clipped
# Distance to stream avg 332.75569520705983
# Distance to stream std 226.1496229553172
# Distance to stream skewness 0.5910325355860666
# Distance to stream kurtosis -0.29855498077587805
# 0.24 minutes to process.
# ------ Subwatershed: 051201010701 Number 383 of 1590 ------
# streams clipped
# Distance to stream avg 338.0190467793533
# Distance to stream std 228.74755118162435
# Distance to stream skewness 0.6017709684126598
# Distance to stream kurtosis -0.4573057513024126
# 0.23 minutes to process.
# ------ Subwatershed: 051201130501 Number 384 of 1590 ------
# streams clipped
# Distance to stream avg 383.92859924777423
# Distance to stream std 324.5491270377915
# Distance to stream skewness 1.7891708940341469
# Distance to stream kurtosis 2.9651046881418672
# 0.24 minutes to process.
# ------ Subwatershed: 051202090603 Number 385 of 1590 ------
# streams clipped
# Distance to stream avg 286.40569146649324
# Distance to stream std 313.8238106110981
# Distance to stream skewness 2.6943822332659515
# Distance to stream kurtosis 6.787165533754866
# 0.23 minutes to process.
# ------ Subwatershed: 051202050603 Number 386 of 1590 ------
# streams clipped
# Distance to stream avg 757.9491674038044
# Distance to stream std 407.2698086099326
# Distance to stream skewness 0.7213153968319853
# Distance to stream kurtosis 0.44802766263817073
# 0.28 minutes to process.
# ------ Subwatershed: 051202010109 Number 387 of 1590 ------
# streams clipped
# Distance to stream avg 542.7754093994639
# Distance to stream std 360.25006670597276
# Distance to stream skewness 0.9898839439974219
# Distance to stream kurtosis 1.0177008419046034
# 0.3 minutes to process.
# ------ Subwatershed: 051201020305 Number 388 of 1590 ------
# streams clipped
# Distance to stream avg 353.5392263762027
# Distance to stream std 382.2879012550875
# Distance to stream skewness 2.629448779006851
# Distance to stream kurtosis 7.903536430396493
# 0.23 minutes to process.
# ------ Subwatershed: 051201040503 Number 389 of 1590 ------
# streams clipped
# Distance to stream avg 532.381165479667
# Distance to stream std 589.0174106298372
# Distance to stream skewness 1.9185602788182154
# Distance to stream kurtosis 2.870598033301113
# 0.23 minutes to process.
# ------ Subwatershed: 051201060202 Number 390 of 1590 ------
# streams clipped
# Distance to stream avg 636.4892251764287
# Distance to stream std 479.0890549353547
# Distance to stream skewness 1.3415096165707154
# Distance to stream kurtosis 3.1160898573274034
# 0.43 minutes to process.
# ------ Subwatershed: 050902030403 Number 391 of 1590 ------
# streams clipped
# Distance to stream avg 244.079357077768
# Distance to stream std 136.8307231760203
# Distance to stream skewness 0.779707051182409
# Distance to stream kurtosis 0.6768931263608824
# 0.31 minutes to process.
# ------ Subwatershed: 051402020705 Number 392 of 1590 ------
# streams clipped
# Distance to stream avg 590.0183445425384
# Distance to stream std 360.77502197420125
# Distance to stream skewness 0.5925589784628522
# Distance to stream kurtosis -1.3203686255952074
# 0.23 minutes to process.
# ------ Subwatershed: 050902030808 Number 393 of 1590 ------
# streams clipped
# Distance to stream avg 248.3604282757133
# Distance to stream std 102.24266427306637
# Distance to stream skewness -0.02312531159377481
# Distance to stream kurtosis -0.10956782112151542
# 0.23 minutes to process.
# ------ Subwatershed: 051201111804 Number 394 of 1590 ------
# streams clipped
# Distance to stream avg 436.5455191974676
# Distance to stream std 225.97697165460812
# Distance to stream skewness 0.4576405785191238
# Distance to stream kurtosis 0.0992365811073812
# 0.24 minutes to process.
# ------ Subwatershed: 050800030205 Number 395 of 1590 ------
# streams clipped
# Distance to stream avg 259.17879526026684
# Distance to stream std 245.59880392431054
# Distance to stream skewness 1.772879987189275
# Distance to stream kurtosis 2.7317202612412244
# 0.25 minutes to process.
# ------ Subwatershed: 051201081206 Number 396 of 1590 ------
# streams clipped
# Distance to stream avg 276.42801987934683
# Distance to stream std 252.5859502409591
# Distance to stream skewness 2.583513814359213
# Distance to stream kurtosis 11.245080403977104
# 0.3 minutes to process.
# ------ Subwatershed: 051201080707 Number 397 of 1590 ------
# streams clipped
# Distance to stream avg 149.5722137211501
# Distance to stream std 126.62040325125645
# Distance to stream skewness 2.172456918879762
# Distance to stream kurtosis 6.806309040009435
# 0.24 minutes to process.
# ------ Subwatershed: 051201011407 Number 398 of 1590 ------
# streams clipped
# Distance to stream avg 300.8234674155615
# Distance to stream std 300.2446737407073
# Distance to stream skewness 1.7472440224612877
# Distance to stream kurtosis 2.970989820714056
# 0.26 minutes to process.
# ------ Subwatershed: 051201060105 Number 399 of 1590 ------
# streams clipped
# Distance to stream avg 362.3013612648517
# Distance to stream std 238.29420752987426
# Distance to stream skewness 0.7502935790419878
# Distance to stream kurtosis 0.06833209936280271
# 0.38 minutes to process.
# ------ Subwatershed: 051402020103 Number 400 of 1590 ------
# streams clipped
# Distance to stream avg 252.10592613955401
# Distance to stream std 162.08110654838163
# Distance to stream skewness 0.5105807324482445
# Distance to stream kurtosis -0.36593738736306447
# 0.32 minutes to process.
# ------ Subwatershed: 051201080101 Number 401 of 1590 ------
# streams clipped
# Distance to stream avg 576.6231141681077
# Distance to stream std 480.4680352285063
# Distance to stream skewness 1.7595819291107135
# Distance to stream kurtosis 3.6387802599002796
# 0.27 minutes to process.
# ------ Subwatershed: 051201100201 Number 402 of 1590 ------
# streams clipped
# Distance to stream avg 582.9466006399264
# Distance to stream std 458.42345267489657
# Distance to stream skewness 1.0085891906738687
# Distance to stream kurtosis 0.5286405114010275
# 0.25 minutes to process.
# ------ Subwatershed: 041000030704 Number 403 of 1590 ------
# streams clipped
# Distance to stream avg 506.67806092076313
# Distance to stream std 406.00732494010924
# Distance to stream skewness 1.423852893483502
# Distance to stream kurtosis 1.9300644940730427
# 0.29 minutes to process.
# ------ Subwatershed: 040400010504 Number 404 of 1590 ------
# streams clipped
# Distance to stream avg 200.0929819045516
# Distance to stream std 214.26249996581703
# Distance to stream skewness 4.205970488454185
# Distance to stream kurtosis 26.05337890723219
# 0.35 minutes to process.
# ------ Subwatershed: 051201010402 Number 405 of 1590 ------
# streams clipped
# Distance to stream avg 341.73877281384625
# Distance to stream std 339.77007712390133
# Distance to stream skewness 1.6466430744986782
# Distance to stream kurtosis 1.698856935746476
# 0.26 minutes to process.
# ------ Subwatershed: 050800020601 Number 406 of 1590 ------
# streams clipped
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\numpy\core\_methods.py:110: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Distance to stream avg nan
# Distance to stream std nan
# Distance to stream skewness nan
# Distance to stream kurtosis nan
# 0.25 minutes to process.
# ------ Subwatershed: 051401010201 Number 407 of 1590 ------
# streams clipped
# Distance to stream avg 244.79432738461753
# Distance to stream std 178.95158176731096
# Distance to stream skewness 1.0014271585742698
# Distance to stream kurtosis 0.5104346980323453
# 0.27 minutes to process.
# ------ Subwatershed: 051202060204 Number 408 of 1590 ------
# streams clipped
# Distance to stream avg 374.35624755233613
# Distance to stream std 239.925556088037
# Distance to stream skewness 0.9041384992880349
# Distance to stream kurtosis 1.327332022634562
# 0.28 minutes to process.
# ------ Subwatershed: 051202011603 Number 409 of 1590 ------
# streams clipped
# Distance to stream avg 383.9422150173875
# Distance to stream std 242.24600663093835
# Distance to stream skewness 0.3248613194993467
# Distance to stream kurtosis -0.7082822944854854
# 0.41 minutes to process.
# ------ Subwatershed: 051202030201 Number 410 of 1590 ------
# streams clipped
# Distance to stream avg 155.31181668490058
# Distance to stream std 100.20023882993372
# Distance to stream skewness 1.4591513041339748
# Distance to stream kurtosis 3.3151519031276306
# 0.28 minutes to process.
# ------ Subwatershed: 051202011105 Number 411 of 1590 ------
# streams clipped
# Distance to stream avg 375.3129646566586
# Distance to stream std 282.646575051529
# Distance to stream skewness 1.1992165117779727
# Distance to stream kurtosis 1.0257440864245018
# 0.39 minutes to process.
# ------ Subwatershed: 051202010304 Number 412 of 1590 ------
# streams clipped
# Distance to stream avg 390.95066947299586
# Distance to stream std 303.2155248270487
# Distance to stream skewness 1.371670725180483
# Distance to stream kurtosis 1.7328219480961087
# 0.34 minutes to process.
# ------ Subwatershed: 051202080103 Number 413 of 1590 ------
# streams clipped
# Distance to stream avg 314.9043024083006
# Distance to stream std 182.49045646236402
# Distance to stream skewness 1.03672369198412
# Distance to stream kurtosis 2.0296264973471105
# 0.25 minutes to process.
# ------ Subwatershed: 051202010904 Number 414 of 1590 ------
# streams clipped
# Distance to stream avg 855.4953775679727
# Distance to stream std 797.4881144755843
# Distance to stream skewness 1.4822673480965085
# Distance to stream kurtosis 1.3726918693174666
# 1.57 minutes to process.
# ------ Subwatershed: 051201050403 Number 415 of 1590 ------
# streams clipped
# Distance to stream avg 972.9911156980285
# Distance to stream std 872.2866577535777
# Distance to stream skewness 0.8049463546884139
# Distance to stream kurtosis -0.6521413530792453
# 0.26 minutes to process.
# ------ Subwatershed: 050902031010 Number 416 of 1590 ------
# streams clipped
# Distance to stream avg 337.4993763405094
# Distance to stream std 145.0286036225494
# Distance to stream skewness -0.3502018821430362
# Distance to stream kurtosis -0.6556448633593264
# 0.27 minutes to process.
# ------ Subwatershed: 051202080802 Number 417 of 1590 ------
# streams clipped
# Distance to stream avg 512.7288602731704
# Distance to stream std 470.3493886058854
# Distance to stream skewness 1.7455827783592257
# Distance to stream kurtosis 3.1378159954486176
# 0.4 minutes to process.
# ------ Subwatershed: 051202010307 Number 418 of 1590 ------
# streams clipped
# Distance to stream avg 835.0160013762218
# Distance to stream std 584.8379399700788
# Distance to stream skewness 0.8563776901487323
# Distance to stream kurtosis -0.1715018600373588
# 0.43 minutes to process.
# ------ Subwatershed: 051201070101 Number 419 of 1590 ------
# streams clipped
# Distance to stream avg 1967.5105644972948
# Distance to stream std 1128.8916118139837
# Distance to stream skewness -0.6045189617883248
# Distance to stream kurtosis -1.2788312967594524
# 0.3 minutes to process.
# ------ Subwatershed: 051202010403 Number 420 of 1590 ------
# streams clipped
# Distance to stream avg 502.03249179999625
# Distance to stream std 379.92188492163547
# Distance to stream skewness 1.6103472674408303
# Distance to stream kurtosis 3.080993743940131
# 0.32 minutes to process.
# ------ Subwatershed: 051201050602 Number 421 of 1590 ------
# streams clipped
# Distance to stream avg 410.73414266672626
# Distance to stream std 378.35763454461096
# Distance to stream skewness 1.307144111994419
# Distance to stream kurtosis 1.7401441816300025
# 0.29 minutes to process.
# ------ Subwatershed: 051201011303 Number 422 of 1590 ------
# streams clipped
# Distance to stream avg 325.03081640911415
# Distance to stream std 204.6247664830196
# Distance to stream skewness 0.7602554115381787
# Distance to stream kurtosis 0.16533548786678365
# 0.31 minutes to process.
# ------ Subwatershed: 051201130602 Number 423 of 1590 ------
# streams clipped
# Distance to stream avg nan
# Distance to stream std nan
# Distance to stream skewness nan
# Distance to stream kurtosis nan
# 0.26 minutes to process.
# ------ Subwatershed: 051402010805 Number 424 of 1590 ------
# streams clipped
# Distance to stream avg 447.6103595898456
# Distance to stream std 204.01335747335062
# Distance to stream skewness 0.062411858031609806
# Distance to stream kurtosis -0.7393636331207389
# 0.29 minutes to process.
# ------ Subwatershed: 051202081302 Number 425 of 1590 ------
# streams clipped
# Distance to stream avg 246.2533146311705
# Distance to stream std 188.8501069204455
# Distance to stream skewness 1.1645556667331338
# Distance to stream kurtosis 1.5966485618498698
# 0.35 minutes to process.
# ------ Subwatershed: 051202081308 Number 426 of 1590 ------
# streams clipped
# Distance to stream avg 274.73704930180094
# Distance to stream std 205.54372698234977
# Distance to stream skewness 1.0118464753270353
# Distance to stream kurtosis 0.9060897407426696
# 0.28 minutes to process.
# ------ Subwatershed: 051201110902 Number 427 of 1590 ------
# streams clipped
# Distance to stream avg 309.97959335122385
# Distance to stream std 179.0188024850048
# Distance to stream skewness 1.169974611847628
# Distance to stream kurtosis 4.078332679205979
# 0.28 minutes to process.
# ------ Subwatershed: 051202030507 Number 428 of 1590 ------
# streams clipped
# Distance to stream avg 234.65314258482303
# Distance to stream std 176.62659818293636
# Distance to stream skewness 1.1528840975128312
# Distance to stream kurtosis 1.6734679838643336
# 0.3 minutes to process.
# ------ Subwatershed: 051202011306 Number 429 of 1590 ------
# streams clipped
# Distance to stream avg 400.5806074500544
# Distance to stream std 287.84336059720675
# Distance to stream skewness 0.9129075069812613
# Distance to stream kurtosis 0.29220449308934127
# 0.68 minutes to process.
# ------ Subwatershed: 051201110104 Number 430 of 1590 ------
# streams clipped
# Distance to stream avg 410.874120603933
# Distance to stream std 290.98479744590503
# Distance to stream skewness 1.9689339954687888
# Distance to stream kurtosis 9.630276811603729
# 0.29 minutes to process.
# ------ Subwatershed: 051201100602 Number 431 of 1590 ------
# streams clipped
# Distance to stream avg 458.52818145015505
# Distance to stream std 344.7821653922968
# Distance to stream skewness 1.1834501098103583
# Distance to stream kurtosis 1.6414137718921973
# 0.31 minutes to process.
# ------ Subwatershed: 051401010801 Number 432 of 1590 ------
# streams clipped
# Distance to stream avg 221.48143292266224
# Distance to stream std 152.29006658685734
# Distance to stream skewness 0.6649259658712616
# Distance to stream kurtosis -0.4069210264359806
# 0.34 minutes to process.
# ------ Subwatershed: 051401041103 Number 433 of 1590 ------
# streams clipped
# Distance to stream avg 273.1347068103145
# Distance to stream std 131.0612715328399
# Distance to stream skewness -0.06439049189831296
# Distance to stream kurtosis -0.44020518710745726
# 0.3 minutes to process.
# ------ Subwatershed: 051202060301 Number 434 of 1590 ------
# streams clipped
# Distance to stream avg 310.5854439709314
# Distance to stream std 197.8186805257155
# Distance to stream skewness 0.6643429984816376
# Distance to stream kurtosis -0.2451351817173486
# 0.41 minutes to process.
# ------ Subwatershed: 051202040803 Number 435 of 1590 ------
# streams clipped
# Distance to stream avg 439.4398610275875
# Distance to stream std 361.9859193221454
# Distance to stream skewness 1.5943659129203167
# Distance to stream kurtosis 4.1950229257164455
# 0.31 minutes to process.
# ------ Subwatershed: 051201030403 Number 436 of 1590 ------
# streams clipped
# Distance to stream avg 794.6196456397956
# Distance to stream std 655.630711206685
# Distance to stream skewness 1.2131195881531762
# Distance to stream kurtosis 0.8128647882674591
# 0.34 minutes to process.
# ------ Subwatershed: 051201020302 Number 437 of 1590 ------
# streams clipped
# Distance to stream avg 498.1565560513412
# Distance to stream std 407.1195986653073
# Distance to stream skewness 0.6329471383775167
# Distance to stream kurtosis -1.0271458702766838
# 0.33 minutes to process.
# ------ Subwatershed: 051201030602 Number 438 of 1590 ------
# streams clipped
# Distance to stream avg 403.2717117919629
# Distance to stream std 316.2588193800043
# Distance to stream skewness 1.2449486199238395
# Distance to stream kurtosis 1.232522951380104
# 0.31 minutes to process.
# ------ Subwatershed: 071200011202 Number 439 of 1590 ------
# streams clipped
# Distance to stream avg 550.4756673811261
# Distance to stream std 252.45522902565568
# Distance to stream skewness -0.3155887897171813
# Distance to stream kurtosis -0.9918451761059646
# 0.31 minutes to process.
# ------ Subwatershed: 071200010310 Number 440 of 1590 ------
# streams clipped
# Distance to stream avg 882.8331341963727
# Distance to stream std 653.3552679388774
# Distance to stream skewness 0.8461298045627517
# Distance to stream kurtosis -0.4056815751335767
# 0.33 minutes to process.
# ------ Subwatershed: 041000030405 Number 441 of 1590 ------
# streams clipped
# Distance to stream avg 447.22723747730294
# Distance to stream std 381.28169071469625
# Distance to stream skewness 0.8845546836152097
# Distance to stream kurtosis -0.43102315029928073
# 0.32 minutes to process.
# ------ Subwatershed: 051202011704 Number 442 of 1590 ------
# streams clipped
# Distance to stream avg 359.70823070313213
# Distance to stream std 204.84481542238797
# Distance to stream skewness 0.5149320902428416
# Distance to stream kurtosis -0.6160485552339456
# 0.33 minutes to process.
# ------ Subwatershed: 051201081501 Number 443 of 1590 ------
# streams clipped
# Distance to stream avg 343.28340728738664
# Distance to stream std 235.67692390561524
# Distance to stream skewness 0.707356293259231
# Distance to stream kurtosis -0.13156579668788204
# 0.34 minutes to process.
# ------ Subwatershed: 051201080406 Number 444 of 1590 ------
# streams clipped
# Distance to stream avg 507.01487124113373
# Distance to stream std 494.16706356288796
# Distance to stream skewness 2.0676527151589332
# Distance to stream kurtosis 5.328758784943581
# 0.32 minutes to process.
# ------ Subwatershed: 071200010604 Number 445 of 1590 ------
# streams clipped
# Distance to stream avg 510.4393459646064
# Distance to stream std 286.6267695743077
# Distance to stream skewness 0.5951033072037064
# Distance to stream kurtosis -0.5085875820187011
# 0.39 minutes to process.
# ------ Subwatershed: 051402010503 Number 446 of 1590 ------
# streams clipped
# Distance to stream avg 191.53393239474974
# Distance to stream std 121.45925033868149
# Distance to stream skewness 1.0179174793560126
# Distance to stream kurtosis 0.3822629503501851
# 0.33 minutes to process.
# ------ Subwatershed: 051202090404 Number 447 of 1590 ------
# streams clipped
# Distance to stream avg 511.0640401461302
# Distance to stream std 284.0286111691974
# Distance to stream skewness 0.22120115892409686
# Distance to stream kurtosis -0.8636360499052778
# 0.45 minutes to process.
# ------ Subwatershed: 051201081304 Number 448 of 1590 ------
# streams clipped
# Distance to stream avg 460.3607905075003
# Distance to stream std 219.73237118600713
# Distance to stream skewness -0.04489485628983358
# Distance to stream kurtosis -0.5736919484615486
# 0.37 minutes to process.
# ------ Subwatershed: 051201061206 Number 449 of 1590 ------
# streams clipped
# Distance to stream avg 197.04370278789753
# Distance to stream std 165.8750709040962
# Distance to stream skewness 1.8054229051447979
# Distance to stream kurtosis 3.379027381177538
# 0.35 minutes to process.
# ------ Subwatershed: 051201060604 Number 450 of 1590 ------
# streams clipped
# Distance to stream avg 265.7193138799342
# Distance to stream std 185.97785683335115
# Distance to stream skewness 0.930158223594956
# Distance to stream kurtosis 0.380012430971723
# 0.35 minutes to process.
# ------ Subwatershed: 040500011701 Number 451 of 1590 ------
# streams clipped
# Distance to stream avg 289.9628257613267
# Distance to stream std 266.42286175433213
# Distance to stream skewness 2.325503398188727
# Distance to stream kurtosis 6.602139186031081
# 0.36 minutes to process.
# ------ Subwatershed: 051202010609 Number 452 of 1590 ------
# streams clipped
# Distance to stream avg 410.64969860539816
# Distance to stream std 370.2544342150905
# Distance to stream skewness 1.7072481872769356
# Distance to stream kurtosis 3.276358879966585
# 0.38 minutes to process.
# ------ Subwatershed: 051201060407 Number 453 of 1590 ------
# streams clipped
# Distance to stream avg 790.4048447082777
# Distance to stream std 451.17083850110856
# Distance to stream skewness -0.3080977339965904
# Distance to stream kurtosis -1.2595616419514024
# 0.39 minutes to process.
# ------ Subwatershed: 051201040301 Number 454 of 1590 ------
# streams clipped
# Distance to stream avg 379.3068703686633
# Distance to stream std 248.98169703214006
# Distance to stream skewness 1.0119576334968963
# Distance to stream kurtosis 0.9475090440860479
# 0.36 minutes to process.
# ------ Subwatershed: 071200010101 Number 455 of 1590 ------
# streams clipped
# Distance to stream avg 466.8667060468847
# Distance to stream std 380.59447088941164
# Distance to stream skewness 1.2772354262043166
# Distance to stream kurtosis 1.2545119552407735
# 0.38 minutes to process.
# ------ Subwatershed: 050902030803 Number 456 of 1590 ------
# streams clipped
# Distance to stream avg 284.59866048589134
# Distance to stream std 199.28160430196664
# Distance to stream skewness 1.0349575627521956
# Distance to stream kurtosis 1.4512494532112843
# 0.41 minutes to process.
# ------ Subwatershed: 041000030403 Number 457 of 1590 ------
# streams clipped
# Distance to stream avg 347.4538142728178
# Distance to stream std 301.8125261638242
# Distance to stream skewness 1.273607181802633
# Distance to stream kurtosis 1.2225486679925321
# 0.39 minutes to process.
# ------ Subwatershed: 040500011303 Number 458 of 1590 ------
# streams clipped
# Distance to stream avg 528.7179989577365
# Distance to stream std 294.66635820942173
# Distance to stream skewness 0.24738764062315258
# Distance to stream kurtosis -1.169801863038328
# 0.37 minutes to process.
# ------ Subwatershed: 050800030701 Number 459 of 1590 ------
# streams clipped
# Distance to stream avg 300.25687527677906
# Distance to stream std 244.62679260663552
# Distance to stream skewness 1.174635379684576
# Distance to stream kurtosis 1.09083189113277
# 0.37 minutes to process.
# ------ Subwatershed: 051202060307 Number 460 of 1590 ------
# streams clipped
# Distance to stream avg 346.3867981780768
# Distance to stream std 225.889700683961
# Distance to stream skewness 1.562921506085564
# Distance to stream kurtosis 4.149066075189865
# 0.39 minutes to process.
# ------ Subwatershed: 051201080701 Number 461 of 1590 ------
# streams clipped
# Distance to stream avg 1151.9278697014513
# Distance to stream std 805.0417074266124
# Distance to stream skewness 0.11654653124466516
# Distance to stream kurtosis -1.509285204955977
# 0.39 minutes to process.
# ------ Subwatershed: 051201020107 Number 462 of 1590 ------
# streams clipped
# Distance to stream avg 326.54844041270786
# Distance to stream std 271.42105468685384
# Distance to stream skewness 2.130598944747322
# Distance to stream kurtosis 5.205717871059251
# 0.38 minutes to process.
# ------ Subwatershed: 051201011507 Number 463 of 1590 ------
# streams clipped
# Distance to stream avg 341.25167837679265
# Distance to stream std 230.2622420239894
# Distance to stream skewness 0.7859102501233147
# Distance to stream kurtosis 0.30511496435830754
# 0.5 minutes to process.
# ------ Subwatershed: 071200011004 Number 464 of 1590 ------
# streams clipped
# Distance to stream avg 547.7207823696132
# Distance to stream std 317.8679467206551
# Distance to stream skewness 0.35206288542514375
# Distance to stream kurtosis -0.6337345861807981
# 0.53 minutes to process.
# ------ Subwatershed: 051401041202 Number 465 of 1590 ------
# streams clipped
# Distance to stream avg 291.2987838016417
# Distance to stream std 171.88078952064328
# Distance to stream skewness 0.2693525201905855
# Distance to stream kurtosis -0.6268243246755723
# 0.43 minutes to process.
# ------ Subwatershed: 040500012209 Number 466 of 1590 ------
# streams clipped
# Distance to stream avg nan
# Distance to stream std nan
# Distance to stream skewness nan
# Distance to stream kurtosis nan
# 0.42 minutes to process.
# ------ Subwatershed: 051402010402 Number 467 of 1590 ------
# streams clipped
# Distance to stream avg 222.42715338598413
# Distance to stream std 145.58726271552263
# Distance to stream skewness 0.5879768355427519
# Distance to stream kurtosis -0.19026754755228925
# 0.44 minutes to process.
# ------ Subwatershed: 051202021001 Number 468 of 1590 ------
# streams clipped
# Distance to stream avg 285.07285796401476
# Distance to stream std 164.58025301076367
# Distance to stream skewness 0.4827124727927529
# Distance to stream kurtosis -0.25532977660109424
# 0.49 minutes to process.
# ------ Subwatershed: 051201081201 Number 469 of 1590 ------
# streams clipped
# Distance to stream avg 458.94980517951257
# Distance to stream std 418.6722181108412
# Distance to stream skewness 2.369442842563658
# Distance to stream kurtosis 6.611145354520806
# 0.45 minutes to process.
# ------ Subwatershed: 040500011901 Number 470 of 1590 ------
# streams clipped
# Distance to stream avg 324.1724551964913
# Distance to stream std 253.27488660570114
# Distance to stream skewness 1.098932262264845
# Distance to stream kurtosis 1.1969633388025906
# 0.47 minutes to process.
# ------ Subwatershed: 051202070105 Number 471 of 1590 ------
# streams clipped
# Distance to stream avg 236.53865955803332
# Distance to stream std 177.12770077187304
# Distance to stream skewness 1.203388569535886
# Distance to stream kurtosis 1.4701299473715155
# 0.47 minutes to process.
# ------ Subwatershed: 051201090702 Number 472 of 1590 ------
# streams clipped
# Distance to stream avg 1232.3996706301666
# Distance to stream std 643.8050624991815
# Distance to stream skewness -0.28144919976850463
# Distance to stream kurtosis -1.6849317086870808
# 0.42 minutes to process.
# ------ Subwatershed: 051201061101 Number 473 of 1590 ------
# streams clipped
# Distance to stream avg 672.4234062051636
# Distance to stream std 567.1362450031119
# Distance to stream skewness 1.098397906431801
# Distance to stream kurtosis 0.9468429536754548
# 0.44 minutes to process.
# ------ Subwatershed: 051201060705 Number 474 of 1590 ------
# streams clipped
# Distance to stream avg 319.10977641070275
# Distance to stream std 244.65405206100095
# Distance to stream skewness 1.2366065570607492
# Distance to stream kurtosis 1.24512175046919
# 0.44 minutes to process.
# ------ Subwatershed: 051402011204 Number 475 of 1590 ------
# streams clipped
# Distance to stream avg 650.8011545101515
# Distance to stream std 693.3034186262793
# Distance to stream skewness 1.9448454598973082
# Distance to stream kurtosis 3.471469061234318
# 0.64 minutes to process.
# ------ Subwatershed: 051202020803 Number 476 of 1590 ------
# streams clipped
# Distance to stream avg 583.9063026596275
# Distance to stream std 529.3458700023035
# Distance to stream skewness 3.3331167984810386
# Distance to stream kurtosis 18.085554525578846
# 0.43 minutes to process.
# ------ Subwatershed: 051401010203 Number 477 of 1590 ------
# streams clipped
# Distance to stream avg 205.42598049155572
# Distance to stream std 158.2705218212864
# Distance to stream skewness 0.9576926273758299
# Distance to stream kurtosis 0.2507140705897841
# 0.43 minutes to process.
# ------ Subwatershed: 051202070303 Number 478 of 1590 ------
# streams clipped
# Distance to stream avg 266.97324016010924
# Distance to stream std 175.98136487481153
# Distance to stream skewness 0.8460668336701741
# Distance to stream kurtosis 0.2578755537234274
# 0.46 minutes to process.
# ------ Subwatershed: 040500011103 Number 479 of 1590 ------
# streams clipped
# Distance to stream avg 751.4904493018411
# Distance to stream std 767.1243527773856
# Distance to stream skewness 1.6025040039558764
# Distance to stream kurtosis 2.1371197220867195
# 0.46 minutes to process.
# ------ Subwatershed: 051401010403 Number 480 of 1590 ------
# streams clipped
# Distance to stream avg 486.33703025379344
# Distance to stream std 389.1234656738999
# Distance to stream skewness 1.3793267425881792
# Distance to stream kurtosis 1.9030327267991751
# 0.5 minutes to process.
# ------ Subwatershed: 051202070502 Number 481 of 1590 ------
# streams clipped
# Distance to stream avg 274.2395284217445
# Distance to stream std 194.86773808142945
# Distance to stream skewness 1.5261926313734624
# ...
# streams clipped
# Distance to stream avg 308.98226910195694
# Distance to stream std 258.10961528278057
# Distance to stream skewness 1.5848883743643196
# Distance to stream kurtosis 2.520517821250552
# 2.17 minutes to process.
# ------ Subwatershed: 051402020303 Number 707 of 1590 ------
# streams clipped
# Distance to stream avg 226.14323371002342
# Distance to stream std 157.87827598627774
# Distance to stream skewness 1.1169886220334044
# Distance to stream kurtosis 1.6336234336047797
# 2.41 minutes to process.
# ------ Subwatershed: 041000040501 Number 708 of 1590 ------
# streams clipped
# Distance to stream avg 526.8881805119457
# Distance to stream std 376.6428385948973
# Distance to stream skewness 1.283444016280926
# Distance to stream kurtosis 2.25970552768314
# 2.2 minutes to process.
# ------ Subwatershed: 071200010804 Number 709 of 1590 ------
# streams clipped
# Distance to stream avg 541.8794787284967
# Distance to stream std 256.52974825744127
# Distance to stream skewness 0.3289644361102599
# Distance to stream kurtosis 0.13674178910564638
# 2.2 minutes to process.
# ------ Subwatershed: 051202010101 Number 710 of 1590 ------
# streams clipped
# Distance to stream avg 324.2865263261242
# Distance to stream std 273.58387298207737
# Distance to stream skewness 1.5856994932565327
# Distance to stream kurtosis 2.957128865241688
# 2.19 minutes to process.
# ------ Subwatershed: 071200021305 Number 711 of 1590 ------
# streams clipped
# Distance to stream avg 294.694404589
# Distance to stream std 0.0
# Distance to stream skewness 0.0
# Distance to stream kurtosis -3.0
# 2.25 minutes to process.
# ------ Subwatershed: 051202080404 Number 712 of 1590 ------
# streams clipped
# Distance to stream avg 210.43895155171822
# Distance to stream std 179.88918296967367
# Distance to stream skewness 1.2751412825388584
# Distance to stream kurtosis 1.1223421080046228
# 2.41 minutes to process.
# ------ Subwatershed: 050800030603 Number 713 of 1590 ------
# streams clipped
# Distance to stream avg 202.6928353369209
# Distance to stream std 162.4743060865286
# Distance to stream skewness 1.054040075206116
# Distance to stream kurtosis 0.3786469363317626
# 2.33 minutes to process.
# ------ Subwatershed: 051201081603 Number 714 of 1590 ------
# streams clipped
# Distance to stream avg 348.12762584500007
# Distance to stream std 230.00920021786314
# Distance to stream skewness 0.4139377397549327
# Distance to stream kurtosis -0.43911939521552323
# 2.25 minutes to process.
# ------ Subwatershed: 071200010102 Number 715 of 1590 ------
# streams clipped
# Distance to stream avg 531.798698095227
# Distance to stream std 425.65632873870754
# Distance to stream skewness 1.0577762511461717
# Distance to stream kurtosis 0.6069354388878367
# 2.38 minutes to process.
# ------ Subwatershed: 050800030707 Number 716 of 1590 ------
# streams clipped
# Distance to stream avg 479.7400014437597
# Distance to stream std 304.60163469261295
# Distance to stream skewness 0.7265920920787774
# Distance to stream kurtosis 0.24119442835976557
# 2.65 minutes to process.
# ------ Subwatershed: 051202090401 Number 717 of 1590 ------
# streams clipped
# Distance to stream avg 245.05501964255413
# Distance to stream std 182.70598722120144
# Distance to stream skewness 1.11779656096104
# Distance to stream kurtosis 0.748756462486579
# 2.54 minutes to process.
# ------ Subwatershed: 051202090106 Number 718 of 1590 ------
# streams clipped
# Distance to stream avg 423.5944660242293
# Distance to stream std 261.3515885551022
# Distance to stream skewness 1.2452119332275975
# Distance to stream kurtosis 3.9366386485988984
# 2.48 minutes to process.
# ------ Subwatershed: 051201060607 Number 719 of 1590 ------
# streams clipped
# Distance to stream avg 301.750210653523
# Distance to stream std 170.35871131055214
# Distance to stream skewness 0.46096082898758894
# Distance to stream kurtosis 0.32448793573967594
# 2.51 minutes to process.
# ------ Subwatershed: 071200011308 Number 720 of 1590 ------
# streams clipped
# Distance to stream avg 335.9081139557625
# Distance to stream std 231.05698754656933
# Distance to stream skewness 1.2086495149916032
# Distance to stream kurtosis 1.8501715199034834
# 2.76 minutes to process.
# ------ Subwatershed: 051202020705 Number 721 of 1590 ------
# streams clipped
# Distance to stream avg 404.3321474030497
# Distance to stream std 309.1636766898933
# Distance to stream skewness 1.1974294409992416
# Distance to stream kurtosis 0.9877866660866275
# 2.56 minutes to process.
# ------ Subwatershed: 051202020307 Number 722 of 1590 ------
# streams clipped
# Distance to stream avg 236.8862910808109
# Distance to stream std 135.84336756129468
# Distance to stream skewness 0.5523254365805166
# Distance to stream kurtosis -0.4701640060808896
# 2.83 minutes to process.
# ------ Subwatershed: 051202020602 Number 723 of 1590 ------
# streams clipped
# Distance to stream avg 586.2454633616858
# Distance to stream std 351.6508619785726
# Distance to stream skewness 0.6939392698614381
# Distance to stream kurtosis 0.11250518449458236
# 2.76 minutes to process.
# ------ Subwatershed: 051202070102 Number 724 of 1590 ------
# streams clipped
# Distance to stream avg nan
# Distance to stream std nan
# Distance to stream skewness nan
# Distance to stream kurtosis nan
# 2.58 minutes to process.
# ------ Subwatershed: 051202030703 Number 725 of 1590 ------
# streams clipped
# Distance to stream avg 313.9068185092786
# Distance to stream std 183.80265866295187
# Distance to stream skewness 0.5538630768416757
# Distance to stream kurtosis -0.40629004941675495
# 2.48 minutes to process.
# ------ Subwatershed: 051202020103 Number 726 of 1590 ------
# streams clipped
# Distance to stream avg 247.04009068559813
# Distance to stream std 152.14226877125503
# Distance to stream skewness 0.6738793577589272
# Distance to stream kurtosis 0.18377476662384362
# 2.33 minutes to process.
# ------ Subwatershed: 051202090802 Number 727 of 1590 ------
# streams clipped
# Distance to stream avg 204.69175041344278
# Distance to stream std 113.38822297746287
# Distance to stream skewness 0.8191002097664823
# Distance to stream kurtosis 1.4700171716405643
# 2.31 minutes to process.
# ------ Subwatershed: 051202011404 Number 728 of 1590 ------
# streams clipped
# Distance to stream avg 237.38262614453515
# Distance to stream std 222.92131935344756
# Distance to stream skewness 2.074289500210821
# Distance to stream kurtosis 6.198561363757836
# 2.37 minutes to process.
# ------ Subwatershed: 051202040806 Number 729 of 1590 ------
# streams clipped
# Distance to stream avg 552.8697178151521
# Distance to stream std 413.00609923319365
# Distance to stream skewness 1.1126816989136312
# Distance to stream kurtosis 0.5090510300961504
# 2.52 minutes to process.
# ------ Subwatershed: 051201030510 Number 730 of 1590 ------
# streams clipped
# Distance to stream avg 447.99702494958376
# Distance to stream std 283.6998116246216
# Distance to stream skewness 0.712928635515678
# Distance to stream kurtosis 0.31383750721427184
# 2.43 minutes to process.
# ------ Subwatershed: 051201011603 Number 731 of 1590 ------
# streams clipped
# Distance to stream avg 493.21433269052443
# Distance to stream std 372.6185408147311
# Distance to stream skewness 0.7643495586238992
# Distance to stream kurtosis -0.41111816754002684
# 2.61 minutes to process.
# ------ Subwatershed: 071200011303 Number 732 of 1590 ------
# streams clipped
# Distance to stream avg 591.9123442747292
# Distance to stream std 347.46988808781396
# Distance to stream skewness 0.2030000043761889
# Distance to stream kurtosis -1.415820624994151
# 2.43 minutes to process.
# ------ Subwatershed: 051202080302 Number 733 of 1590 ------
# streams clipped
# Distance to stream avg 546.4114161277372
# Distance to stream std 447.64274434552635
# Distance to stream skewness 1.307095089078593
# Distance to stream kurtosis 1.5517562778641043
# 2.33 minutes to process.
# ------ Subwatershed: 051202070902 Number 734 of 1590 ------
# streams clipped
# Distance to stream avg 274.6103473950062
# Distance to stream std 177.18588779416768
# Distance to stream skewness 0.8564368137672153
# Distance to stream kurtosis -0.020825266886927984
# 2.33 minutes to process.
# ------ Subwatershed: 051202040104 Number 735 of 1590 ------
# streams clipped
# Distance to stream avg 466.70950729358293
# Distance to stream std 414.7806999048466
# Distance to stream skewness 1.586873176948294
# Distance to stream kurtosis 3.224430573205316
# 2.38 minutes to process.
# ------ Subwatershed: 051201060404 Number 736 of 1590 ------
# streams clipped
# Distance to stream avg 674.7350768132133
# Distance to stream std 409.2373508338773
# Distance to stream skewness 0.595749826131235
# Distance to stream kurtosis 0.8624567517771946
# 2.33 minutes to process.
# ------ Subwatershed: 071200010204 Number 737 of 1590 ------
# streams clipped
# Distance to stream avg 643.8921895645818
# Distance to stream std 414.6911020263334
# Distance to stream skewness 1.1332712955663327
# Distance to stream kurtosis 1.8157822760599531
# 2.42 minutes to process.
# ------ Subwatershed: 051401010603 Number 738 of 1590 ------
# streams clipped
# Distance to stream avg 250.10411872867337
# Distance to stream std 174.2594068814043
# Distance to stream skewness 1.0307252530804334
# Distance to stream kurtosis 2.2982511379635193
# 2.4 minutes to process.
# ------ Subwatershed: 051202081205 Number 739 of 1590 ------
# streams clipped
# Distance to stream avg 1196.0221915707652
# Distance to stream std 836.8395029348941
# Distance to stream skewness 1.029874129348342
# Distance to stream kurtosis 1.011767611707624
# 2.42 minutes to process.
# ------ Subwatershed: 051201111507 Number 740 of 1590 ------
# streams clipped
# Distance to stream avg 327.83147841641613
# Distance to stream std 180.44606882786422
# Distance to stream skewness 0.7170849639234915
# Distance to stream kurtosis 2.050335835050925
# 2.43 minutes to process.
# ------ Subwatershed: 051201111201 Number 741 of 1590 ------
# streams clipped
# Distance to stream avg 299.1473567264862
# Distance to stream std 208.28553571738917
# Distance to stream skewness 1.1699524924180877
# Distance to stream kurtosis 2.2885933191858276
# 2.42 minutes to process.
# ------ Subwatershed: 051202030801 Number 742 of 1590 ------
# streams clipped
# Distance to stream avg 244.73421730364163
# Distance to stream std 175.19305725020737
# Distance to stream skewness 1.181686912112695
# Distance to stream kurtosis 1.2434927369945736
# 2.42 minutes to process.
# ------ Subwatershed: 051201070404 Number 743 of 1590 ------
# streams clipped
# Distance to stream avg 302.72333829963367
# Distance to stream std 251.57099124562947
# Distance to stream skewness 2.328942857246182
# Distance to stream kurtosis 7.183942245529934
# 2.5 minutes to process.
# ------ Subwatershed: 051201061307 Number 744 of 1590 ------
# streams clipped
# Distance to stream avg 713.5560378868912
# Distance to stream std 588.2227626332811
# Distance to stream skewness 1.0231089403730804
# Distance to stream kurtosis -0.0325741232482466
# 2.42 minutes to process.
# ------ Subwatershed: 051201040507 Number 745 of 1590 ------
# streams clipped
# Distance to stream avg 366.8979969928636
# Distance to stream std 337.6505842954638
# Distance to stream skewness 1.5154611466309524
# Distance to stream kurtosis 2.1467751033200004
# 2.45 minutes to process.
# ------ Subwatershed: 041000030804 Number 746 of 1590 ------
# streams clipped
# Distance to stream avg 283.3206821551081
# Distance to stream std 212.51258314887266
# Distance to stream skewness 1.292219984753936
# Distance to stream kurtosis 2.0929741966918423
# 2.58 minutes to process.
# ------ Subwatershed: 051201010603 Number 747 of 1590 ------
# streams clipped
# Distance to stream avg 336.60179895179505
# Distance to stream std 285.4143831174585
# Distance to stream skewness 1.3946957939948934
# Distance to stream kurtosis 1.4836421088309013
# 2.67 minutes to process.
# ------ Subwatershed: 051201060804 Number 748 of 1590 ------
# streams clipped
# Distance to stream avg 681.608029948631
# Distance to stream std 593.647441950696
# Distance to stream skewness 1.4681038734986285
# Distance to stream kurtosis 1.9202265452754919
# 2.64 minutes to process.
# ------ Subwatershed: 051201060502 Number 749 of 1590 ------
# streams clipped
# Distance to stream avg 349.75860107028626
# Distance to stream std 227.947222581777
# Distance to stream skewness 1.5821484110589277
# Distance to stream kurtosis 4.5721436379444
# 2.75 minutes to process.
# ------ Subwatershed: 051201011004 Number 750 of 1590 ------
# streams clipped
# Distance to stream avg 377.048887800575
# Distance to stream std 337.5964621990835
# Distance to stream skewness 1.7242653491398987
# Distance to stream kurtosis 3.305115405378128
# 2.99 minutes to process.
# ------ Subwatershed: 040400010401 Number 751 of 1590 ------
# streams clipped
# Distance to stream avg 421.8788640419365
# Distance to stream std 391.16322465373395
# Distance to stream skewness 1.8675803565396247
# Distance to stream kurtosis 3.4719463753034727
# 2.86 minutes to process.
# ------ Subwatershed: 051401040902 Number 752 of 1590 ------
# streams clipped
# Distance to stream avg 3043.9220640640947
# Distance to stream std 2223.3431812373706
# Distance to stream skewness 0.8684140067870043
# Distance to stream kurtosis 0.18164455274034808
# 2.71 minutes to process.
# ------ Subwatershed: 051202070701 Number 753 of 1590 ------
# streams clipped
# Distance to stream avg 339.4703179291833
# Distance to stream std 210.81691064146827
# Distance to stream skewness 0.4641596518318885
# Distance to stream kurtosis -0.7099868678636496
# 2.66 minutes to process.
# ------ Subwatershed: 050902030503 Number 754 of 1590 ------
# streams clipped
# Distance to stream avg 260.0339774169317
# Distance to stream std 180.61716582577805
# Distance to stream skewness 0.9626100531442632
# Distance to stream kurtosis 0.34025936218057895
# 2.62 minutes to process.
# ------ Subwatershed: 051202011503 Number 755 of 1590 ------
# streams clipped
# Distance to stream avg 478.4704785246192
# Distance to stream std 334.4262535425581
# Distance to stream skewness 0.7861496001336252
# Distance to stream kurtosis -0.28122551045052635
# 2.72 minutes to process.
# ------ Subwatershed: 051202040502 Number 756 of 1590 ------
# streams clipped
# Distance to stream avg 459.66414353633365
# Distance to stream std 433.2580165077432
# Distance to stream skewness 1.9910208549763098
# Distance to stream kurtosis 4.546589770217585
# 2.63 minutes to process.
# ------ Subwatershed: 051201030502 Number 757 of 1590 ------
# streams clipped
# Distance to stream avg 305.9427425943672
# Distance to stream std 215.69179617726408
# Distance to stream skewness 1.0879912175144733
# Distance to stream kurtosis 1.4971013598689362
# 2.6 minutes to process.
# ------ Subwatershed: 071200020205 Number 758 of 1590 ------
# streams clipped
# Distance to stream avg 300.52804628505504
# Distance to stream std 227.0235406373014
# Distance to stream skewness 1.0656390503535913
# Distance to stream kurtosis 0.5507453328861254
# 2.63 minutes to process.
# ------ Subwatershed: 051402010903 Number 759 of 1590 ------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-3802e6fc5990> in <module>
#      30
#      31             #select buildings that are marked residential
# ---> 32             building_footprints_residential = arcpy.SelectLayerByAttribute_management(building_footprints_clip, "NEW_SELECTION","RES_NONRES = 'Res'")
#      33
#      34 #             #clip dem to subwatershed area
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in SelectLayerByAttribute(in_layer_or_view, selection_type, where_clause, invert_where_clause)
#    8519     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    8520     try:
# -> 8521         retval = convertArcObjectToPythonObject(gp.SelectLayerByAttribute_management(*gp_fixargs((in_layer_or_view, selection_type, where_clause, invert_where_clause), True)))
#    8522         return retval
#    8523     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     509         val = getattr(self._gp, attr)
#     510         if callable(val):
# --> 511             return lambda *args: val(*gp_fixargs(args, True))
#     512         else:
#     513             return convertArcObjectToPythonObject(val)
#
# KeyboardInterrupt:

# %%
len(dist_to_stream_kurtosis_list)
# Out:
# 447

# %%
st = time()
outputs = {'subwatershed': subwatershed_list[0:447],
#           'area': area_list[0:447],
#           'perimeter': perimeter_list[0:447],
#           'circulatory_ratio': circulatory_ratio_list[0:447],
#           'relief': relief_list[0:447],
#           'avg_slope': avg_slope_list[0:447],
#            'watershed_length': watershed_length_list[0:447],
#            'elongation_ratio': elongation_ratio_list[0:447],
#            'drainage_density': drainage_density_list[0:447],
#            'shape_factor': shape_factor_list[0:447],
#            'relief_ratio': relief_ratio_list[0:447],
#            'ruggedness': ruggedness_list[0:447]}
#            'aae_area': aae_list[0:447],
#            'buildings_aae_count': buildings_aae_list[0:447],
#            'x_area': x_list[0:447],
#            'buildings_x_count': buildings_x_list[0:447],
#            'water_bodies_area': water_bodies_list[0:447],
#            'dams_count': dams_list[0:447],
#            'bridges_count': bridges_list[0:447],
#            'streets_km': streets_list[0:447],
#            'railroads_km': railroads_list[0:447],
#            'population': population_list[0:447],
#            'population_density': population_density_list[0:447],
#            'avg_median_income': avg_median_income_list[0:447],
#            'housing_density': housing_density_list[0:447],
#            'population_change': population_change_list[0:447],
#            'dependent_population_pct': dependent_population_list[0:447],
           'dist_to_stream_avg (m)': dist_to_stream_avg_list[0:447],
           'dist_to_stream_stdev (m)': dist_to_stream_stdev_list[0:447],
           'dist_to_stream_skewness (m)': dist_to_stream_skewness_list[0:447],
           'dist_to_stream_kurtosis (m)': dist_to_stream_kurtosis_list[0:447]
#            'lu_21_area' : lu_21_list[0:447],
#            'lu_22_area' : lu_22_list[0:447],
#            'lu_23_area' : lu_23_list[0:447],
#            'lu_24_area': lu_24_list[0:447],
#            'lu_41_area': lu_41_list[0:447],
#            'lu_82_area': lu_82_list[0:447],
#            'avg_impervious_percent': impervious_percent_list[0:447],
#            'orb100yr06h': orb100yr06h_list[0:447],
#            'orb100yr12h': orb100yr12h_list[0:447],
#            'orb100yr24h': orb100yr24h_list[0:447],
#            'orb25yr06h': orb25yr06h_list[0:447],
#            'orb25yr12h': orb25yr12h_list[0:447],
#            'orb25yr24h':orb25yr24h_list[0:447],
#            'orb2yr06h': orb2yr06h_list[0:447],
#            'orb2yr12h': orb2yr12h_list[0:447],
#            'orb2yr24h': orb2yr24h_list[0:447],
#            'orb50yr06h': orb50yr06h_list[0:447],
#            'orb50yr12h': orb50yr12h_list[0:447],
#            'orb50yr24h':orb50yr24h_list[0:447],
#            'orb100yr06ha_am': orb100yr06ha_am_list[0:447],
#            'orb100yr12ha_am': orb100yr12ha_am_list[0:447],
#            'orb100yr24ha_am': orb100yr24ha_am_list[0:447],
#            'orb25yr06ha_am': orb25yr06ha_am_list[0:447],
#            'orb25yr12ha_am': orb25yr12ha_am_list[0:447],
#            'orb25yr24ha_am': orb25yr24ha_am_list[0:447],
#            'orb2yr06ha_am': orb2yr06ha_am_list[0:447],
#            'orb2yr12ha_am': orb2yr12ha_am_list[0:447],
#            'orb2yr24ha_am': orb2yr24ha_am_list[0:447],
#            'orb50yr06ha_am': orb50yr06ha_am_list[0:447],
#            'orb50yr12ha_am': orb50yr12ha_am_list[0:447],
#            'orb50yr24ha_am': orb50yr24ha_am_list[0:447]
         }

# 
# 
# 
#  
#         
# 
            
outputs_df = pd.DataFrame(outputs, columns = ['subwatershed',
#                                              'area',
#                                              'perimeter',
#                                              'circulatory_ratio',
#                                              'relief',
#                                              'avg_slope',
#                                               'watershed_length',
#                                               'elongation_ratio',
#                                               'drainage_density',
#                                               'shape_factor',
#                                               'relief_ratio',
#                                               'ruggedness'
#                                               'aae_area',
#                                               'buildings_aae_count',
#                                               'x_area',
#                                               'buildings_x_count',
#                                               'water_bodies_area',
#                                               'dams_count',
#                                               'bridges_count',
#                                               'streets_km',
#                                               'railroads_km',
#                                               'population',
#                                               'population_density',
#                                               'avg_median_income',
#                                               'housing_density',
#                                               'population_change',
#                                               'dependent_population_pct',
                                              'dist_to_stream_avg (m)',
                                              'dist_to_stream_stdev (m)',
                                              'dist_to_stream_skewness (m)',
                                              'dist_to_stream_kurtosis (m)'
#                                               'lu_21_area'
#                                               'lu_22_area',
#                                               'lu_23_area',
#                                               'lu_24_area',
#                                               'lu_41_area',
#                                               'lu_82_area',
#                                               'avg_impervious_percent',
#                                              'orb100yr06h',
#                                               'orb100yr12h',
#                                               'orb100yr24h',
#                                               'orb25yr06h',
#                                               'orb25yr12h',
#                                               'orb25yr24h',
#                                               'orb2yr06h',
#                                               'orb2yr12h',
#                                               'orb2yr24h',
#                                               'orb50yr06h',
#                                               'orb50yr12h',
#                                               'orb50yr24h',
#                                               'orb100yr06ha_am',
#                                               'orb100yr12ha_am',
#                                               'orb100yr24ha_am',
#                                               'orb25yr06ha_am',
#                                               'orb25yr12ha_am',
#                                               'orb25yr24ha_am',
#                                               'orb2yr06ha_am',
#                                               'orb2yr12ha_am',
#                                               'orb2yr24ha_am',
#                                               'orb50yr06ha_am',
#                                               'orb50yr12ha_am',
#                                               'orb50yr24ha_am'
                                             ])    
    

#     
#  
# 
# 
# 
#




print(outputs_df)

outputs_df.to_excel(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\output\Distance_to_stream_moments_3.xlsx")
print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
#      subwatershed  dist_to_stream_avg (m)  dist_to_stream_stdev (m)  \
# 0    050800030201              450.710486                261.297453
# 1    041000040503              429.963153                400.501721
# 2    051202090406              258.897279                164.877589
# 3    051202070705              246.519534                202.294372
# 4    051201030504              356.149031                289.074627
# ..            ...                     ...                       ...
# 442  050902030503              260.033977                180.617166
# 443  051202011503              478.470479                334.426254
# 444  051202040502              459.664144                433.258017
# 445  051201030502              305.942743                215.691796
# 446  071200020205              300.528046                227.023541
#
#      dist_to_stream_skewness (m)  dist_to_stream_kurtosis (m)
# 0                      -0.073879                    -0.934779
# 1                       1.370833                     1.367296
# 2                       0.852954                     0.678536
# 3                       1.832284                     3.706784
# 4                       1.793923                     4.206882
# ..                           ...                          ...
# 442                     0.962610                     0.340259
# 443                     0.786150                    -0.281226
# 444                     1.991021                     4.546590
# 445                     1.087991                     1.497101
# 446                     1.065639                     0.550745
#
# [447 rows x 5 columns]
# 0.02 minutes to process.

# %%
length_dict = {key: len(value) for key, value in outputs.items()}
length_dict
