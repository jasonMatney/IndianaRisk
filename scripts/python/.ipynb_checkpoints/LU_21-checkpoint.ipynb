# %%
#########################################################################
#Data Collection 
#
# Functions for handling subwatershed characteristics data collection
#
# Authors: Shannon McAvoy (smcavoy@dewberry.com)
#
# Editor: Jason Matney (jmatney@dewberry.com)
#
# Copyright: Dewberry Engineers Inc.
#########################################################################

# %%
import pandas as pd
import arcpy
import numpy as np
from numpy import mean
from numpy import std
import os
from arcpy import management
from arcgis.gis import GIS
from time import time

# %%
# Login for ArcPro, AGOL or API Server 
#gis = GIS("https://www.arcgis.com", username="dpiazza_dewberry", password="*****")

# %%
path = "C:\\Users\jmatney\Documents\GitHub\IndianaRisk\data\Indiana_ML"
hucs = "C:\\Users\jmatney\Documents\GitHub\IndianaRisk\data\shp"

# %%
arcpy.env.overwriteOutput = True

# %%
st = time()

# Set Local Variables
output_workspace = os.path.join(path, "working_dsn")

arcpy.env.workspace = output_workspace

##### change these based on what subwatersheds you want #####

# all_subwatersheds = r"P:\Temp\McAvoy\ML_DataCollection\Indiana_ML\Indiana_HUC12_groups\1.shp"
all_subwatersheds = os.path.join(hucs, "wbdhu12_a_IN_only.shp")

# All centroids of subwatersheds
all_centroids = os.path.join(hucs, "wbdhu12_a_IN_only_centroids.shp")

#set source for streams data
streams = os.path.join(path, "Indiana_50c_streams_edited\Hydrography_HighRes_FlowLine_NHD_USGS.shp")

#####these are the same for all subwatersheds in Indiana#####

#set source for dem
dem_Indiana = os.path.join(path, "Indiana_3dep\Indiana_DEM_1.tif")

#set source for slope dem
dem_slope = os.path.join(path, "Indiana_SlopeRaster\Indiana_clip_slope.tif")

#set source for NHFL Data
nfhl_sfha = os.path.join(path, "NFHL_18_20200310.gdb\S_FLD_HAZ_AR")


#set source for water bodies data 
water_bodies = os.path.join(path, "IndianaMAP_WaterBodies\Water_Bodies_Lakes_LocalRes\Hydrography_LocalRes_WaterbodyDiscrete_NHD_IN.shp")

#set source for dams data 
dams = os.path.join(path, "IndianaMAP_Dams\Dams_IDNR\Dams_IDNR_IN.shp")

#set source for bridges data
bridges = os.path.join(path, "IndianaMAP_Bridges\Bridges_County_INDOT\Bridges_County_INDOT_IN.shp")

#set source for streets data
streets = os.path.join(path, "IndianaMAP_Streets\Streets_Centerlines_IGIO\County_Street_Centerlines_IGIO_IN.gdb\County_Street_Centerlines_IGIO_IN_Dec2019")


#set source for railraods data
railroads = os.path.join(path, "IndianaMAP_Railroads\Railroads_Active_Abandoned_INDOT\Rail_System_Active_Abandoned_INDOT_IN.shp")

#set source for ACS population data
population = os.path.join(path, "Indiana_PopulationData\Indiana_PopulationData.shp")

#set source for ACS median income data 
median_income = os.path.join(path, "Indiana_IncomeData\Indiana_IncomeData.shp")

#set source for county boundary data
county_boundary = os.path.join(path, "MarionCounty_Boundary\Marion_County_Boundary.shp")

#source for Bing building footprints for Indiana (attrubuted with open street maps data)
building_footprints = os.path.join(path, "BuildingFootprints_Indiana\Building_Footprints_Attributed_IN.shp")

#folder with partial duration files, set as workspace temporarily, then reset when done
directory_rainfall = os.path.join(path, "MarionCounty_Rainfall\All_Rainfall_Clipped_IN")

#set source for nlcd land use data
lu_usa = os.path.join(path, r"NLCD_Impervious\NLCD_indiana_polygon.shp")

#set source for impervious indicator data
impervious_usa = os.path.join(path, "NLCD_Impervious\\NLCD_2016_Impervious_L48_20190405_PERCENT\\NLCD_2016_Impervious_L48_20190405.img")



subwatershed_list = []
area_list = []
perimeter_list = []
watershed_length_list = []
elongation_ratio_list = []
shape_factor_list = []
circulatory_ratio_list = []
relief_list = []
relief_ratio_list = []
avg_slope_list = []
drainage_density_list = []
ruggedness_list = []
aae_list = []
buildings_aae_list = []
x_list = []
buildings_x_list = []
water_bodies_list = []
dams_list = []
bridges_list = []
streets_list = []
railroads_list = []
population_list = []
dependent_population_list = []
population_density_list = []
avg_median_income_list = []
housing_density_list = []
population_change_list = []
dist_to_stream_avg_list = []
dist_to_stream_stdev_list = []

lu_21_list = []
lu_22_list = []
lu_23_list = []
lu_24_list = []
lu_41_list = []
lu_82_list = []
impervious_percent_list = []

orb100yr06h_list = []
orb100yr12h_list = []
orb100yr24h_list = []
orb25yr06h_list = []
orb25yr12h_list = []
orb25yr24h_list = []
orb2yr06h_list = []
orb2yr12h_list = []
orb2yr24h_list = []
orb50yr06h_list = []
orb50yr12h_list = []
orb50yr24h_list = []
orb100yr06ha_am_list = []
orb100yr12ha_am_list = []
orb100yr24ha_am_list = []
orb25yr06ha_am_list = []
orb25yr12ha_am_list = []
orb25yr24ha_am_list = []
orb2yr06ha_am_list = []
orb2yr12ha_am_list = []
orb2yr24ha_am_list = []
orb50yr06ha_am_list = []
orb50yr12ha_am_list = []
orb50yr24ha_am_list = []


#########################################################################################################
print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
# 0.01 minutes to process.

# %%
# GLOBAL VARIABLES
LOG_NAME = 'DataCollection_export.log'

# %%
completed_hucs = pd.read_excel(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\output\completed_hucs.xlsx", converters={'subwatershed': lambda x: str(x)})

# %%
done = completed_hucs['subwatershed'].str.strip('[]').tolist()

# %%
len(done)
# Out:
# 1057

# %%
row_count=len(done)
with arcpy.da.SearchCursor(all_subwatersheds, ['HUC12']) as cursor:

    for row in cursor:
        if row[0] not in done:
            st = time()
            subwatershed_number = row[0]

            row_count += 1

            subwatershed_list.append(subwatershed_number)

            print("------ Subwatershed:", subwatershed_number, "Number", row_count, "of 1590 ------")              

            #select subwatershed from shapefile with all of them
            subwatershed_selection = arcpy.SelectLayerByAttribute_management(all_subwatersheds, "NEW_SELECTION",
                                                                             "HUC12 = " + "'"+subwatershed_number+"'")

            #select centroid from shapefile with all of them
            centroid_selection = arcpy.SelectLayerByAttribute_management(all_centroids, "NEW_SELECTION",
                                                                             "HUC12 = " + "'"+subwatershed_number+"'")
            #copy selected subwatershed to it's own file
            subwatershed = arcpy.CopyFeatures_management(subwatershed_selection, "subwatershed")

#             #copy selected centroid to it's own file
#             centroid = arcpy.CopyFeatures_management(centroid_selection, "centroid")

#             #clip dem to subwatershed area
#             # dem_clip = arcpy.Clip_management(dem_Indiana, "#", "dem_clip.tif", subwatershed, "#" , "ClippingGeometry", "NO_MAINTAIN_EXTENT")
#             dem_clip =  os.path.join(path, "working_dsn\dem_clip.tif")
#             arcpy.Clip_management(dem_Indiana, "#", dem_clip, subwatershed_selection)
#             print("clipped dem to subwatershed area")

#             #calculate area of subwatershed
#             arcpy.AddField_management(subwatershed, "AREA", "DOUBLE")

#             area = arcpy.CalculateGeometryAttributes_management(subwatershed, "AREA AREA_GEODESIC", '', 
#                                                                 "SQUARE_KILOMETERS",
#                                                                 None)

#             #print area
#             rows = arcpy.SearchCursor(area)

#             for row in rows:
#                 area = row.getValue("AREA")

#             area_list.append(area)
#             print(area, " square kilometers")


#             #calculate perimeter of subwatershed
#             arcpy.AddField_management(subwatershed, "PERIMETER", "DOUBLE")
#             perimeter = arcpy.CalculateGeometryAttributes_management(subwatershed, "PERIMETER PERIMETER_LENGTH_GEODESIC",
#                                                                      "KILOMETERS")

#             print("perimeter calculated")

#             #print perimeter
#             rows = arcpy.SearchCursor(perimeter)

#             for row in rows:
#                 perimeter = row.getValue("PERIMETER")

#             perimeter_list.append(perimeter)
#             print(perimeter, " kilometers")



#             #get average slope using zonal statistics from slope dem
#             avg_slope = arcpy.sa.ZonalStatistics(subwatershed, "FID", dem_slope, "MEAN")

#             #get slope value
#             avg_slope_result = arcpy.GetRasterProperties_management(avg_slope, "MAXIMUM")

#             avg_slope_value = avg_slope_result.getOutput(0)

#             avg_slope_list.append(avg_slope_value)

#             print(avg_slope_value, " = avg slope (%)")


#             #calculate circulatory ratio
#             #ratio of area to the area of a circle having equal perimeter as the perimeter of drainage basin

#             #area of a circle with same perimeter as above
#             #C = 2(pi)r
#             #r = C/(2pi)
#             #A = (pi)r^2
#             circle_radius = perimeter/(2*numpy.pi)
#             print(circle_radius, "is the radius of a circle with the same perimeter.")
#             circle_area = (numpy.pi*(circle_radius**2))
#             print(circle_area, "is the area of a circle with the same perimeter.")

#             #ratio of subwatershed perimeter to circle circumference
#             circulatory_ratio = area / circle_area

#             circulatory_ratio_list.append(circulatory_ratio)
#             print(circulatory_ratio, " is the circulatory ratio")


#             #calculate relief
#             #elevation difference before basin outlet and highest point located in the perimeter of basin

#             #find highest point on perimeter

#             #use Raster Domain tool to get z-enabled polyline of perimeter
#             perimeter_polyline = arcpy.RasterDomain_3d(dem_clip, "perimeter_polyline.shp", "LINE")
#             print("created 3d polyline of subwatershed perimeter")

#             #Convert each vertices of the polyline into points
#             perimeter_points = arcpy.FeatureVerticesToPoints_management(perimeter_polyline, "perimeter_points.shp")
#             print("created perimeter points")

#             #get Z values into the attribute table for the points
#             perimeter_points_Z = arcpy.AddZInformation_3d(perimeter_points, "Z")
#             print("added z information")

#             #get the max value from all of the points
#             perimeter_stats = arcpy.Statistics_analysis(perimeter_points_Z, "perimeter_stats", [["Z", "MAX"], ["Z", "MIN"]])

#             # Get a list of field names to display
#             field_names = [i.name for i in arcpy.ListFields(perimeter_stats) if i.type != 'OID']

#             # Open a cursor to extract results from stats table
#             cursor = arcpy.da.SearchCursor(perimeter_stats, field_names)

#             # Create a pandas dataframe to display results
#             df = pd.DataFrame(data=[row for row in cursor],
#                                   columns=field_names)

#             print(df)

#             #get the values for max Z and min Z into a format to use them

#             rows = arcpy.SearchCursor(perimeter_stats)

#             for row in rows:
#                 max_z = row.getValue("MAX_Z")
#                 min_z = row.getValue("MIN_Z")


#             print(max_z)
#             print(min_z)

#             relief = max_z - min_z
#             print("The relief of the subwatershed is: ", relief," meters.")

#             relief_list.append(relief)



#             find area covered by A and AE zones and X NFHL Zones

#             #clip to subwatershed area
#             nfhl_sfha_clip = arcpy.Clip_analysis(nfhl_sfha, subwatershed, "nfhl_sfha.shp")

#             #select Zone A and Zone AE
#             nfhl_sfha_aae_selection = arcpy.management.SelectLayerByAttribute(nfhl_sfha_clip, "NEW_SELECTION", 
#                                                                "FLD_ZONE = 'AE' Or FLD_ZONE = 'A'", None)

#             #copy features to new feature class
#             nfhl_sfha_aae = arcpy.CopyFeatures_management(nfhl_sfha_aae_selection, "nfhl_sfha_aae")

#             #add new field for area
#             nfhl_sfha_aae_addfield = arcpy.AddField_management(nfhl_sfha_aae, "AREA", "DOUBLE")

#             #calculate the area for each of the features
#             aae_area = arcpy.CalculateGeometryAttributes_management(nfhl_sfha_aae_addfield, "AREA AREA_GEODESIC", '', 
#                                                                 "SQUARE_KILOMETERS",
#                                                                 None)
#             #get the sum of all of the areas
#             aae_area_list = []  

#             rows = arcpy.SearchCursor(aae_area)  
#             for row in rows:  
#                 aae_area_feature = row.getValue("AREA")  
#                 aae_area_list.append(aae_area_feature)  

#             aae_area_sum = sum(aae_area_list)

#             aae_list.append(aae_area_sum)

#             print(aae_area_sum, " = area of all AE and A zones in the subwatershed (square km)")



#             #select Zone X, 0.2% chance flood area
#             nfhl_sfha_x_selection = arcpy.management.SelectLayerByAttribute(nfhl_sfha_clip, "NEW_SELECTION", 
#                                                                "FLD_ZONE = 'X' And ZONE_SUBTY = '0.2 PCT ANNUAL CHANCE FLOOD HAZARD'",
#                                                                               None)

#             #copy features to new feature class
#             nfhl_sfha_x = arcpy.CopyFeatures_management(nfhl_sfha_x_selection, "nfhl_sfha_x")

#             #add new field for area
#             nfhl_sfha_x_addfield = arcpy.AddField_management(nfhl_sfha_x, "AREA", "DOUBLE")

#             #calculate the area for each of the features
#             x_area = arcpy.CalculateGeometryAttributes_management(nfhl_sfha_x_addfield, "AREA AREA_GEODESIC", '', 
#                                                                 "SQUARE_KILOMETERS",
#                                                                 None)
#             #get the sum of all of the areas
#             x_area_list = []  

#             rows = arcpy.SearchCursor(x_area)  
#             for row in rows:  
#                 x_area_feature = row.getValue("AREA")  
#                 x_area_list.append(x_area_feature)  

#             x_area_sum = sum(x_area_list)

#             x_list.append(x_area_sum)

#             print(x_area_sum, " = area of all X zones, 0.2PCT zone subtype in the subwatershed (square km)")


#             #calculate area covered by lakes/reserviors 

#             #clip to subwatershed area
#             water_bodies_clip = arcpy.Clip_analysis(water_bodies, subwatershed, "water_bodies.shp")

#             #copy features to new feature class
#             water_bodies_copy = arcpy.CopyFeatures_management(water_bodies_clip, "water_bodies_copy.shp")

#             #add new field for area
#             water_bodies_addfield = arcpy.AddField_management(water_bodies_copy, "AREA", "DOUBLE")

#             #calculate the area for each of the features
#             water_bodies_area = arcpy.CalculateGeometryAttributes_management(water_bodies_addfield, "AREA AREA_GEODESIC", '', 
#                                                                 "SQUARE_KILOMETERS",
#                                                                 None)
#             #get the sum of all of the areas
#             water_bodies_area_list = []  

#             rows = arcpy.SearchCursor(water_bodies_area)  
#             for row in rows:  
#                 wb_area_values = row.getValue("AREA")  
#                 water_bodies_area_list.append(wb_area_values)  

#             water_bodies_area_sum = sum(water_bodies_area_list)

#             water_bodies_list.append(water_bodies_area_sum)
#             print(water_bodies_area_sum, " = area of all water bodies in the subwatershed (square km)")


#             #count all of the dams in the subwatershed

#             #clip dams to subwatershed
#             dams_clip = arcpy.Clip_analysis(dams, subwatershed, "dams.shp")

#             #count number of dam points
#             dams_count = arcpy.GetCount_management(dams_clip)

#             dams_list.append(dams_count)

#             print(dams_count, " = number of dams in the subwatershed")



#             #count all of the bridges in the subwatershed

#             #clip bridges to subwatershed
#             bridges_clip = arcpy.Clip_analysis(bridges, subwatershed, "bridges.shp")

#             #count number of dam points
#             bridges_count = arcpy.GetCount_management(bridges_clip)

#             bridges_list.append(bridges_count)

#             print(bridges_count, " = number of bridges in the subwatershed")



#             #calculate the kilometers of streets in the subwatershed

#             #clip streets to subwatershed area 
#             streets_clip = arcpy.Clip_analysis(streets, subwatershed, "streets.shp")

#             #add field to calculate length of each street
#             streets_addfield = arcpy.AddField_management(streets_clip, "LENGTH_KM", "DOUBLE")

#             #calculate the area for each of the features
#             streets_length = arcpy.CalculateGeometryAttributes_management(streets_addfield, "LENGTH_KM LENGTH_GEODESIC", 
#                                                                           'KILOMETERS')
#             #get the sum of all of the areas
#             streets_lengths_list = []  

#             rows = arcpy.SearchCursor(streets_length)  
#             for row in rows:  
#                 streets_lengths_values = row.getValue("LENGTH_KM")  
#                 streets_lengths_list.append(streets_lengths_values)  

#             streets_length_sum = sum(streets_lengths_list)

#             streets_list.append(streets_length_sum)

#             print(streets_length_sum, " = sum of all streets in the subwatershed (km)")


#             #calculate km of railroads in subwatershed

#             #clip railroads to subwatershed area 
#             railroads_clip = arcpy.Clip_analysis(railroads, subwatershed, "railroads.shp")

#             #add field to calculate length of each railroad
#             railroads_addfield = arcpy.AddField_management(railroads_clip, "LENGTH_KM", "DOUBLE")

#             #calculate the area for each of the features
#             railroads_length = arcpy.CalculateGeometryAttributes_management(railroads_addfield, "LENGTH_KM LENGTH_GEODESIC", 'KILOMETERS', 
#                                                                 "",
#                                                                 None)
#             #get the sum of all of the areas
#             railroads_lengths_list = []  

#             rows = arcpy.SearchCursor(railroads_length)  
#             for row in rows:  
#                 railroads_lengths_values = row.getValue("LENGTH_KM")  
#                 railroads_lengths_list.append(railroads_lengths_values)  

#             railroads_length_sum = sum(railroads_lengths_list)

#             railroads_list.append(railroads_length_sum)

#             print(railroads_length_sum, " = sum of all railroads in the subwatershed (km)")   


#             #ACS population data - 5 year estimates (2014-2018) gotten from ESRI Living Atlas Data
#             #data is chosen to be on census tract level


#             #clip to subwatershed
#             population_clip = arcpy.Clip_analysis(population, subwatershed, "population.shp")

#             #get total population
#             #field = B01001_001E = Total Population (alias)
#             #when clipped, field name changes to B01001_001

#             #get the sum of all of the populations in each tract
#             total_pop_list = []  

#             rows = arcpy.SearchCursor(population_clip)  
#             for row in rows:  
#                 total_pop_value = row.getValue('B01001_001') 
#                 total_pop_list.append(total_pop_value)  

#             total_pop_sum = sum(total_pop_list)

#             population_list.append(total_pop_sum)
#             print(total_pop_sum, " = total population in the subwatershed") 

#             #get the average of percentages of dependent age groups in each tract
#             #field = B01001_calc_pctDependE = Percent of Population in Dependent Age Groups (under 18 and 65+) (alias)
#             #when clipped field changes to B01001_61
#             dependent_pop_list = []  

#             rows = arcpy.SearchCursor(population_clip)  
#             for row in rows:  
#                 dependent_pop_value = row.getValue('B01001__61') 
#                 dependent_pop_list.append(dependent_pop_value)  

#             dependent_pop_avg_pct = mean(dependent_pop_list)

#             dependent_population_list.append(dependent_pop_avg_pct)

#             print(dependent_pop_avg_pct, " = total percent of dependent population in the subwatershed") 

#             #find population density
#             population_density = total_pop_sum / area

#             population_density_list.append(population_density)

#             print(population_density, " = population density of subwatershed (people/square km)")


#             #ACS population data - 5 year estimates (2014-2018) gotten from ESRI Living Atlas Data
#             #data is chosen to be on census tract level

#             #clip to subwatershed
#             median_income_clip = arcpy.Clip_analysis(median_income, subwatershed, "median_income.shp")

#             #get average median income 
#             #field = B19049_001 = Median Household Income in past 12 months 
#             #^(inflation-adjusted dollars to last year of 5-year range) (alias)

#             #get the sum of all of the populations in each tract
#             total_median_income_list = []  

#             rows = arcpy.SearchCursor(median_income_clip)  
#             for row in rows:  
#                 median_income_value = row.getValue('B19049_001') 
#                 total_median_income_list.append(median_income_value)  

#             median_income_average = mean(total_median_income_list)

#             avg_median_income_list.append(median_income_average)

#             print(median_income_average, " = average median income in the subwatershed") 


#             #get housing density

#             #clip building footprints to subwatershed area
#             building_footprints_clip = arcpy.Clip_analysis(building_footprints, subwatershed, "building_footprints.shp")

#             #select buildings that are marked residential
#             building_footprints_residential = arcpy.SelectLayerByAttribute_management(building_footprints_clip, "NEW_SELECTION",
#                                                                                  "RES_NONRES = 'Res'")

#             #get count of how many buildings there are 
#             buildings_count = arcpy.GetCount_management(building_footprints_residential)

#             buildings_count_number = buildings_count.getOutput(0)
#             print(buildings_count_number, " = number of residential building footprints in the subwatershed")

#             #divide number of buildings by subwatershed area
#             housing_density = int(buildings_count_number) / area

#             housing_density_list.append(housing_density)

#             print(housing_density, " = housing density (buildings per square km)")


#            #find total population from the 2013 5-year ACS estimates
#             #get the sum of all of the 2013 populations in each tract
#             #field = DP05_0001E = TotalPopulation from the 2013 ACS 5yr estimates
#             total_pop_list_2013 = []  

#             rows = arcpy.SearchCursor(population_clip)  
#             for row in rows:  
#                 total_pop_value_2013 = row.getValue('DP05_0001E')
#                 if total_pop_value_2013 != '0':
#                     total_pop_list_2013.append(int(total_pop_value_2013))  

#             total_pop_sum_2013 = sum( total_pop_list_2013)

#             print(total_pop_sum_2013, " = total 2013 population in the subwatershed") 

#             #find population change between 2018 and 2013
#             population_change = total_pop_sum - total_pop_sum_2013

#             population_change_list.append(population_change)
#             print(population_change, " = population change between 2013 and 2018")




#             #calculate drainage density
#             #the total length of all streams and tributaries divided by basin area

#             #all streams in subwatershed
#             streams_clip = arcpy.Clip_analysis(streams, subwatershed, "streams")
#             print("streams clipped")

#             #add field for length
#             streams_addfield = arcpy.AddField_management(streams_clip, "LENGTH", "DOUBLE")

#             #calculate geometry 
#             streams_calculate = arcpy.CalculateGeometryAttributes_management(streams_addfield, [["LENGTH", "LENGTH_GEODESIC"]], 
#                                                                              "KILOMETERS")
#             print("length calculated")

#             #get the sum of all of the areas
#             stream_length_list = []  

#             rows = arcpy.SearchCursor(streams_calculate)  
#             for row in rows:  
#                 stream_length = row.getValue("LENGTH")  
#                 stream_length_list.append(stream_length)  

#             stream_length_sum = sum(stream_length_list)

#             print(stream_length_sum, " = length of all streams in subwatershed")

#             print(area, " = subwatershed area")

#             drainage_density = stream_length_sum / area

#             drainage_density_list.append(drainage_density)

#             print(drainage_density, "is the drainage density (streams/km)")

#             #find watershed length
#             #watershed length = distance from outlet to watershed boundary along the main channel
#             #we are assuming that the longest stream above is the main channel

#             watershed_length = max(stream_length_list)

#             watershed_length_list.append(watershed_length)

#             print(watershed_length, " = watershed length (longest stream in subwatershed)")


#             #calculate shape factor 
#             #watershed length squared divided by watershed area

#             shape_factor = (watershed_length**2) / area

#             shape_factor_list.append(shape_factor)

#             print(shape_factor, " is the shape factor.")



#             #calculate relief ratio
#             #relief divided by watershed length
#             #length is is kilometers, convert to meters

#             watershed_length_meters = watershed_length * 1000

#             relief_ratio = relief / watershed_length_meters

#             relief_ratio_list.append(relief_ratio)

#             print(relief_ratio, " = relief ratio")


#             #calculate ruggedness number
#             #product of relief and drainage density

#             #relief is in meters, convert first to km
#             relief_km = relief / 1000
#             print(relief_km, " is the relief in km")

#             ruggedness = relief_km * drainage_density

#             ruggedness_list.append(ruggedness)
#             print(ruggedness, " is the ruggedness number")


#             #calculate elongation ratio
#             #ratio of diameter of a circle having the same area as the basin to the max basin length


#             # diameter of circle with same area
# #             A = (pi)r^2
# #             r = sqrt(A/pi)
# #             d = r*2

#             radius = numpy.sqrt(area/numpy.pi)
#             print(radius, " miles is the radius of a circle with the same area.")

#             diameter = radius*2
#             print(diameter, " miles is the diameter of a circle with the same area.")

#             elongation_ratio = diameter / watershed_length

#             elongation_ratio_list.append(elongation_ratio)


#             #get number of buildings inside the aae zone

#             buildings_aae_select = arcpy.SelectLayerByLocation_management(building_footprints_clip, "INTERSECT", nfhl_sfha_aae )

#             buildings_aae = arcpy.CopyFeatures_management(buildings_aae_select, "buildings_aae.shp")

#             buildings_aae_count = arcpy.GetCount_management(buildings_aae)

#             buildings_aae_list.append(buildings_aae_count)

#             #get number of buildings inside the x zone

#             buildings_x_select = arcpy.SelectLayerByLocation_management(building_footprints_clip, "INTERSECT", nfhl_sfha_x )

#             buildings_x = arcpy.CopyFeatures_management(buildings_x_select, "buildings_x.shp")

#             buildings_x_count = arcpy.GetCount_management(buildings_x)

#             buildings_x_list.append(buildings_x_count)

#             get area of various land use codes
#             clip usa land use polygon to the subwatershed
            lu_subwatershed = arcpy.Clip_analysis(lu_usa, subwatershed, "lu_subwatershed.shp")

            lu_subwatershed_area = arcpy.AddGeometryAttributes_management(lu_subwatershed, "AREA_GEODESIC", '',
                                                              "SQUARE_KILOMETERS")


            #lu 21 = developed open space
            lu_21_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
                                                                                 "gridcode = 21")

            lu_21 = arcpy.CopyFeatures_management(lu_21_select, "lu_21.shp")

            #get the sum of all of the areas
            lu_21_polygons_list = []  

            rows = arcpy.SearchCursor(lu_21)  
            for row in rows:  
                lu_21_polygon = row.getValue("AREA_GEO")  
                lu_21_polygons_list.append(lu_21_polygon)  

            lu_21_area_sum = sum(lu_21_polygons_list)

            lu_21_list.append(lu_21_area_sum)
            print(subwatershed_number, "Land Use 21 (Developed, Open Space):", lu_21_area_sum)



#             #lu 22 = developed low intensity
#             lu_22_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 22")

#             lu_22 = arcpy.CopyFeatures_management(lu_22_select, "lu_22.shp")

#             #get the sum of all of the areas
#             lu_22_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_22)  
#             for row in rows:  
#                 lu_22_polygon = row.getValue("AREA_GEO")  
#                 lu_22_polygons_list.append(lu_22_polygon)  

#             lu_22_area_sum = sum(lu_22_polygons_list)

#             lu_22_list.append(lu_22_area_sum)


#             #lu 23 = developed medium intensity
#             lu_23_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 23")

#             lu_23 = arcpy.CopyFeatures_management(lu_23_select, "lu_23.shp")

#             #get the sum of all of the areas
#             lu_23_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_23)  
#             for row in rows:  
#                 lu_23_polygon = row.getValue("AREA_GEO")  
#                 lu_23_polygons_list.append(lu_23_polygon)  

#             lu_23_area_sum = sum(lu_23_polygons_list)

#             lu_23_list.append(lu_23_area_sum)



#             #lu 24 = developed high intensity
#             lu_24_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 24")

#             lu_24 = arcpy.CopyFeatures_management(lu_24_select, "lu_24.shp")

#             #get the sum of all of the areas
#             lu_24_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_24)  
#             for row in rows:  
#                 lu_24_polygon = row.getValue("AREA_GEO")  
#                 lu_24_polygons_list.append(lu_24_polygon)  

#             lu_24_area_sum = sum(lu_24_polygons_list)

#             lu_24_list.append(lu_24_area_sum)



#             #lu 41 = deciduous forest
#             lu_41_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 41")

#             lu_41 = arcpy.CopyFeatures_management(lu_41_select, "lu_41.shp")

#             #get the sum of all of the areas
#             lu_41_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_41)  
#             for row in rows:  
#                 lu_41_polygon = row.getValue("AREA_GEO")  
#                 lu_41_polygons_list.append(lu_41_polygon)  

#             lu_41_area_sum = sum(lu_41_polygons_list)

#             lu_41_list.append(lu_41_area_sum)


#             #lu 82 = cultivated crops
#             lu_82_select = arcpy.SelectLayerByAttribute_management(lu_subwatershed_area, "NEW_SELECTION",
#                                                                                  "gridcode = 82")

#             lu_82 = arcpy.CopyFeatures_management(lu_82_select, "lu_82.shp")

#             #get the sum of all of the areas
#             lu_82_polygons_list = []  

#             rows = arcpy.SearchCursor(lu_82)  
#             for row in rows:  
#                 lu_82_polygon = row.getValue("AREA_GEO")  
#                 lu_82_polygons_list.append(lu_82_polygon)  

#             lu_82_area_sum = sum(lu_82_polygons_list)

#             lu_82_list.append(lu_82_area_sum)

            
#             #get percent impervious indicator for subwatershed area
#             avg_impervious_pct = arcpy.sa.ZonalStatistics(subwatershed, "FID", impervious_usa, "MEAN" )

#             #get avg value  value
#             avg_impervious_result = arcpy.GetRasterProperties_management(avg_impervious_pct, "MAXIMUM")

#             #avg_impervious_pct_value = avg_impervious_result.getOutput(0)
#             print(impervious_value, " = avg impervious percent ")

#             impervious_percent_list.append(impervious_value)



#             #get distance from residential buildings to streams

#             building_footprints_residential_copy = arcpy.CopyFeatures_management(building_footprints_residential, "buildings_res.shp")


#             #project buildings and streams so they are in the same GCS
#             output_coord_system = arcpy.SpatialReference(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\Indiana_ML\working_dsn\NAD1983_ProjectionFile.prj")

#             streams_project = arcpy.Project_management(streams_clip, "streams_project.shp",
#                                                       output_coord_system)

#             buildings_project = arcpy.Project_management(building_footprints_residential_copy, "buildings_res_project.shp",
#                                                       output_coord_system)

#             #use near tool to get distance to steams

#             buildings_near = arcpy.Near_analysis(buildings_project, streams_project, "", "LOCATION", "", "GEODESIC")

#             #get all the distances in to the streams
#             dist_to_stream_list = []
#             rows = arcpy.SearchCursor(buildings_near)  
#             for row in rows:  
#                 dist_to_stream = row.getValue("NEAR_DIST")  
#                 dist_to_stream_list.append(dist_to_stream)  

#             dist_to_stream_avg = mean(dist_to_stream_list)

#             dist_to_stream_stdev = std(dist_to_stream_list)

#             print("Distance to stream avg", dist_to_stream_avg)
#             print("Distance to stream std", dist_to_stream_stdev)

#             dist_to_stream_avg_list.append(dist_to_stream_avg)
#             dist_to_stream_stdev_list.append(dist_to_stream_stdev)


#          ## LOOP    

#             #loop through all rainfall rasters in the same folder 


#             arcpy.env.workspace = directory_rainfall

#             rasters = arcpy.ListRasters("orb*")

#             for raster in rasters:

#                 raster_name = os.path.basename(raster).rstrip(os.path.splitext(raster)[1])
#                 print("Raster name: ", raster_name)

#                 #get average rainfall for duration using zonal statistics
#                 #elevRaster = arcpy.sa.Raster(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\Indiana_ML\working_dsn\dem_clip.tif")

#                 centroid_rainfall = arcpy.sa.ExtractValuesToPoints(centroid, raster, r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\shp\Centroid_Rainfall.shp", "NONE", "VALUE_ONLY")

#                 # Open a cursor on some fields in a table  
#                 rainfall_value = arcpy.da.SearchCursor(centroid_rainfall, ("RASTERVALU",)).next()[0]


#         #         avg_rainfall = arcpy.sa.ZonalStatistics(subwatershed, "FID", raster, "MEAN" )

#         #         #get avg value  value
#         #         avg_result = arcpy.GetRasterProperties_management(avg_rainfall, "MAXIMUM")

#                 #rainfall_value = avg_result.getOutput(0)
#                 print(rainfall_value, " = avg rainfall in inches *1000")

#                 if raster_name == "orb100yr06h":
#                     orb100yr06h_list.append(rainfall_value)

#                 elif raster_name == "orb100yr12h":
#                     orb100yr12h_list.append(rainfall_value)

#                 elif raster_name == "orb100yr24h":
#                     orb100yr24h_list.append(rainfall_value)

#                 elif raster_name == "orb25yr06h":
#                     orb25yr06h_list.append(rainfall_value)

#                 elif raster_name == "orb25yr12h":
#                     orb25yr12h_list.append(rainfall_value)

#                 elif raster_name == "orb25yr24h":
#                     orb25yr24h_list.append(rainfall_value)

#                 elif raster_name == "orb2yr06h":
#                     orb2yr06h_list.append(rainfall_value)

#                 elif raster_name == "orb2yr12h":
#                     orb2yr12h_list.append(rainfall_value)

#                 elif raster_name == "orb2yr24h":
#                     orb2yr24h_list.append(rainfall_value)

#                 elif raster_name == "orb50yr06h":
#                     orb50yr06h_list.append(rainfall_value)

#                 elif raster_name == "orb50yr12h":
#                     orb50yr12h_list.append(rainfall_value)

#                 elif raster_name == "orb50yr24h":
#                     orb50yr24h_list.append(rainfall_value)

#                 elif raster_name == "orb100yr06ha_am":
#                     orb100yr06ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb100yr12ha_am":
#                     orb100yr12ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb100yr24ha_am":
#                     orb100yr24ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb25yr06ha_am":
#                     orb25yr06ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb25yr12ha_am":
#                     orb25yr12ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb25yr24ha_am":
#                     orb25yr24ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb2yr06ha_am":
#                     orb2yr06ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb2yr12ha_am":
#                     orb2yr12ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb2yr24ha_am":
#                     orb2yr24ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb50yr06ha_am":
#                     orb50yr06ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb50yr12ha_am":
#                     orb50yr12ha_am_list.append(rainfall_value)

#                 elif raster_name == "orb50yr24ha_am":
#                     orb50yr24ha_am_list.append(rainfall_value)

#                 else:
#                     continue 



            #set workspace environment back to the newly created folder
            arcpy.env.workspace = output_workspace
            print(round(((time()-st)/60), 2) , 'minutes to process.')  


    
    
#########################################################################################


    
    
print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
# ------ Subwatershed: 051202021007 Number 1058 of 1590 ------
# 051202021007 Land Use 21 (Developed, Open Space): 3.5528915930393783
# 0.14 minutes to process.
# ------ Subwatershed: 051201010501 Number 1059 of 1590 ------
# 051201010501 Land Use 21 (Developed, Open Space): 1.3354397638096125
# 0.06 minutes to process.
# ------ Subwatershed: 051402010403 Number 1060 of 1590 ------
# 051402010403 Land Use 21 (Developed, Open Space): 3.8051588381183237
# 0.1 minutes to process.
# ------ Subwatershed: 051201090903 Number 1061 of 1590 ------
# 051201090903 Land Use 21 (Developed, Open Space): 0.5068471780588977
# 0.05 minutes to process.
# ------ Subwatershed: 071200010505 Number 1062 of 1590 ------
# 071200010505 Land Use 21 (Developed, Open Space): 2.335880789082988
# 0.09 minutes to process.
# ------ Subwatershed: 040500011007 Number 1063 of 1590 ------
# 040500011007 Land Use 21 (Developed, Open Space): 1.5272187178046046
# 0.09 minutes to process.
# ------ Subwatershed: 041000030404 Number 1064 of 1590 ------
# 041000030404 Land Use 21 (Developed, Open Space): 2.222553053246634
# 0.13 minutes to process.
# ------ Subwatershed: 050800030703 Number 1065 of 1590 ------
# 050800030703 Land Use 21 (Developed, Open Space): 3.1422598501792303
# 0.08 minutes to process.
# ------ Subwatershed: 051202011309 Number 1066 of 1590 ------
# 051202011309 Land Use 21 (Developed, Open Space): 14.921815804242046
# 0.28 minutes to process.
# ------ Subwatershed: 051201081604 Number 1067 of 1590 ------
# 051201081604 Land Use 21 (Developed, Open Space): 1.7253086690829829
# 0.09 minutes to process.
# ------ Subwatershed: 051201080510 Number 1068 of 1590 ------
# 051201080510 Land Use 21 (Developed, Open Space): 3.4014642560809114
# 0.12 minutes to process.
# ------ Subwatershed: 051201070104 Number 1069 of 1590 ------
# 051201070104 Land Use 21 (Developed, Open Space): 2.805355792407894
# 0.07 minutes to process.
# ------ Subwatershed: 051201061004 Number 1070 of 1590 ------
# 051201061004 Land Use 21 (Developed, Open Space): 1.182561287545204
# 0.07 minutes to process.
# ------ Subwatershed: 051201020108 Number 1071 of 1590 ------
# 051201020108 Land Use 21 (Developed, Open Space): 2.471910715978872
# 0.06 minutes to process.
# ------ Subwatershed: 051402020301 Number 1072 of 1590 ------
# 051402020301 Land Use 21 (Developed, Open Space): 2.2706244241836395
# 0.09 minutes to process.
# ------ Subwatershed: 051401040802 Number 1073 of 1590 ------
# 051401040802 Land Use 21 (Developed, Open Space): 1.769972915738312
# 0.07 minutes to process.
# ------ Subwatershed: 051202020804 Number 1074 of 1590 ------
# 051202020804 Land Use 21 (Developed, Open Space): 1.386322241564468
# 0.08 minutes to process.
# ------ Subwatershed: 051202070401 Number 1075 of 1590 ------
# 051202070401 Land Use 21 (Developed, Open Space): 2.7508822061589893
# 0.1 minutes to process.
# ------ Subwatershed: 050800030407 Number 1076 of 1590 ------
# 050800030407 Land Use 21 (Developed, Open Space): 2.4822004527539003
# 0.08 minutes to process.
# ------ Subwatershed: 051201081202 Number 1077 of 1590 ------
# 051201081202 Land Use 21 (Developed, Open Space): 1.9428074385597054
# 0.07 minutes to process.
# ------ Subwatershed: 051201011503 Number 1078 of 1590 ------
# 051201011503 Land Use 21 (Developed, Open Space): 2.570862918204519
# 0.08 minutes to process.
# ------ Subwatershed: 041000050204 Number 1079 of 1590 ------
# 041000050204 Land Use 21 (Developed, Open Space): 0.3192168004492119
# 0.06 minutes to process.
# ------ Subwatershed: 051202070203 Number 1080 of 1590 ------
# 051202070203 Land Use 21 (Developed, Open Space): 1.9439916294257977
# 0.08 minutes to process.
# ------ Subwatershed: 051202080606 Number 1081 of 1590 ------
# 051202080606 Land Use 21 (Developed, Open Space): 3.0800074654499316
# 0.09 minutes to process.
# ------ Subwatershed: 051202060308 Number 1082 of 1590 ------
# 051202060308 Land Use 21 (Developed, Open Space): 3.756096736684373
# 0.12 minutes to process.
# ------ Subwatershed: 051201080702 Number 1083 of 1590 ------
# 051201080702 Land Use 21 (Developed, Open Space): 1.9428944781258857
# 0.07 minutes to process.
# ------ Subwatershed: 051201011104 Number 1084 of 1590 ------
# 051201011104 Land Use 21 (Developed, Open Space): 7.8520662141890964
# 0.13 minutes to process.
# ------ Subwatershed: 071200010903 Number 1085 of 1590 ------
# 071200010903 Land Use 21 (Developed, Open Space): 2.026896176328039
# 0.1 minutes to process.
# ------ Subwatershed: 041900000200 Number 1086 of 1590 ------
# 041900000200 Land Use 21 (Developed, Open Space): 0.24217793611015717
# 0.55 minutes to process.
# ------ Subwatershed: 040500012003 Number 1087 of 1590 ------
# 040500012003 Land Use 21 (Developed, Open Space): 3.948052439966309
# 0.12 minutes to process.
# ------ Subwatershed: 051401010204 Number 1088 of 1590 ------
# 051401010204 Land Use 21 (Developed, Open Space): 3.5154934656255428
# 0.15 minutes to process.
# ------ Subwatershed: 040500011504 Number 1089 of 1590 ------
# 040500011504 Land Use 21 (Developed, Open Space): 5.014684716260599
# 0.17 minutes to process.
# ------ Subwatershed: 051402010101 Number 1090 of 1590 ------
# 051402010101 Land Use 21 (Developed, Open Space): 1.7281652460859065
# 0.09 minutes to process.
# ------ Subwatershed: 051402010301 Number 1091 of 1590 ------
# 051402010301 Land Use 21 (Developed, Open Space): 3.437213514580912
# 0.12 minutes to process.
# ------ Subwatershed: 051202081502 Number 1092 of 1590 ------
# 051202081502 Land Use 21 (Developed, Open Space): 1.459541106053553
# 0.1 minutes to process.
# ------ Subwatershed: 051202060502 Number 1093 of 1590 ------
# 051202060502 Land Use 21 (Developed, Open Space): 5.229953377503882
# 0.13 minutes to process.
# ------ Subwatershed: 051202010203 Number 1094 of 1590 ------
# 051202010203 Land Use 21 (Developed, Open Space): 2.8809665242472415
# 0.1 minutes to process.
# ------ Subwatershed: 051201100204 Number 1095 of 1590 ------
# 051201100204 Land Use 21 (Developed, Open Space): 2.616980851147506
# 0.09 minutes to process.
# ------ Subwatershed: 051201100101 Number 1096 of 1590 ------
# 051201100101 Land Use 21 (Developed, Open Space): 1.7609563164166382
# 0.07 minutes to process.
# ------ Subwatershed: 051201061102 Number 1097 of 1590 ------
# 051201061102 Land Use 21 (Developed, Open Space): 0.6748597516269351
# 0.08 minutes to process.
# ------ Subwatershed: 040500012102 Number 1098 of 1590 ------
# 040500012102 Land Use 21 (Developed, Open Space): 2.247073632268041
# 0.12 minutes to process.
# ------ Subwatershed: 051202060603 Number 1099 of 1590 ------
# 051202060603 Land Use 21 (Developed, Open Space): 1.575436384077666
# 0.09 minutes to process.
# ------ Subwatershed: 051202020305 Number 1100 of 1590 ------
# 051202020305 Land Use 21 (Developed, Open Space): 1.8653964861083676
# 0.1 minutes to process.
# ------ Subwatershed: 051202030807 Number 1101 of 1590 ------
# 051202030807 Land Use 21 (Developed, Open Space): 2.232623493920228
# 0.11 minutes to process.
# ------ Subwatershed: 051202070301 Number 1102 of 1590 ------
# 051202070301 Land Use 21 (Developed, Open Space): 2.901904069911652
# 0.12 minutes to process.
# ------ Subwatershed: 051202010604 Number 1103 of 1590 ------
# 051202010604 Land Use 21 (Developed, Open Space): 2.164368765110092
# 0.1 minutes to process.
# ------ Subwatershed: 051201060402 Number 1104 of 1590 ------
# 051201060402 Land Use 21 (Developed, Open Space): 3.1220661486421233
# 0.12 minutes to process.
# ------ Subwatershed: 051202090502 Number 1105 of 1590 ------
# 051202090502 Land Use 21 (Developed, Open Space): 2.2135016241400733
# 0.1 minutes to process.
# ------ Subwatershed: 051202011402 Number 1106 of 1590 ------
# 051202011402 Land Use 21 (Developed, Open Space): 7.074665623802586
# 0.19 minutes to process.
# ------ Subwatershed: 071200021303 Number 1107 of 1590 ------
# 071200021303 Land Use 21 (Developed, Open Space): 1.2929745657944203
# 0.11 minutes to process.
# ------ Subwatershed: 051201060703 Number 1108 of 1590 ------
# 051201060703 Land Use 21 (Developed, Open Space): 2.274123093919811
# 0.1 minutes to process.
# ------ Subwatershed: 050902030303 Number 1109 of 1590 ------
# 050902030303 Land Use 21 (Developed, Open Space): 3.1778824773397836
# 0.15 minutes to process.
# ------ Subwatershed: 051202080904 Number 1110 of 1590 ------
# 051202080904 Land Use 21 (Developed, Open Space): 2.3193336884510467
# 0.1 minutes to process.
# ------ Subwatershed: 051202080402 Number 1111 of 1590 ------
# 051202080402 Land Use 21 (Developed, Open Space): 2.3249297091970185
# 0.12 minutes to process.
# ------ Subwatershed: 051202050101 Number 1112 of 1590 ------
# 051202050101 Land Use 21 (Developed, Open Space): 2.450489221859673
# 0.1 minutes to process.
# ------ Subwatershed: 051201040702 Number 1113 of 1590 ------
# 051201040702 Land Use 21 (Developed, Open Space): 2.074371762025085
# 0.11 minutes to process.
# ------ Subwatershed: 051201080801 Number 1114 of 1590 ------
# 051201080801 Land Use 21 (Developed, Open Space): 2.039306347821536
# 0.11 minutes to process.
# ------ Subwatershed: 051201070304 Number 1115 of 1590 ------
# 051201070304 Land Use 21 (Developed, Open Space): 1.7877439702568698
# 0.1 minutes to process.
# ------ Subwatershed: 071200020503 Number 1116 of 1590 ------
# 071200020503 Land Use 21 (Developed, Open Space): 1.02321939451912
# 0.11 minutes to process.
# ------ Subwatershed: 051401040202 Number 1117 of 1590 ------
# 051401040202 Land Use 21 (Developed, Open Space): 2.999458241718919
# 0.13 minutes to process.
# ------ Subwatershed: 040500011205 Number 1118 of 1590 ------
# 040500011205 Land Use 21 (Developed, Open Space): 2.8796344938181875
# 0.16 minutes to process.
# ------ Subwatershed: 051401040702 Number 1119 of 1590 ------
# 051401040702 Land Use 21 (Developed, Open Space): 4.263770455202624
# 0.15 minutes to process.
# ------ Subwatershed: 051201040102 Number 1120 of 1590 ------
# 051201040102 Land Use 21 (Developed, Open Space): 2.1284762767694136
# 0.14 minutes to process.
# ------ Subwatershed: 050902030701 Number 1121 of 1590 ------
# 050902030701 Land Use 21 (Developed, Open Space): 3.6437491965934616
# 0.2 minutes to process.
# ------ Subwatershed: 040500012001 Number 1122 of 1590 ------
# 040500012001 Land Use 21 (Developed, Open Space): 1.6200902018901047
# 0.13 minutes to process.
# ------ Subwatershed: 051202090703 Number 1123 of 1590 ------
# 051202090703 Land Use 21 (Developed, Open Space): 2.350380193111547
# 0.21 minutes to process.
# ------ Subwatershed: 051202080902 Number 1124 of 1590 ------
# 051202080902 Land Use 21 (Developed, Open Space): 3.490156568572998
# 0.16 minutes to process.
# ------ Subwatershed: 051201080409 Number 1125 of 1590 ------
# 051201080409 Land Use 21 (Developed, Open Space): 1.879457118379225
# 0.13 minutes to process.
# ------ Subwatershed: 051201030508 Number 1126 of 1590 ------
# 051201030508 Land Use 21 (Developed, Open Space): 3.9400319101199908
# 0.13 minutes to process.
# ------ Subwatershed: 051201080402 Number 1127 of 1590 ------
# 051201080402 Land Use 21 (Developed, Open Space): 1.9498559890144052
# 0.13 minutes to process.
# ------ Subwatershed: 051401041002 Number 1128 of 1590 ------
# 051401041002 Land Use 21 (Developed, Open Space): 1.9344164239882111
# 0.14 minutes to process.
# ------ Subwatershed: 051202070803 Number 1129 of 1590 ------
# 051202070803 Land Use 21 (Developed, Open Space): 5.0572304376662185
# 0.2 minutes to process.
# ------ Subwatershed: 051202030701 Number 1130 of 1590 ------
# 051202030701 Land Use 21 (Developed, Open Space): 2.227059129778151
# 0.15 minutes to process.
# ------ Subwatershed: 051202010602 Number 1131 of 1590 ------
# 051202010602 Land Use 21 (Developed, Open Space): 2.105491258180893
# 0.12 minutes to process.
# ------ Subwatershed: 040400010302 Number 1132 of 1590 ------
# 040400010302 Land Use 21 (Developed, Open Space): 6.857529055281989
# 0.26 minutes to process.
# ------ Subwatershed: 071200010106 Number 1133 of 1590 ------
# 071200010106 Land Use 21 (Developed, Open Space): 1.5545669836416791
# 0.14 minutes to process.
# ------ Subwatershed: 040500010803 Number 1134 of 1590 ------
# 040500010803 Land Use 21 (Developed, Open Space): 4.283738620952758
# 0.2 minutes to process.
# ------ Subwatershed: 051202090302 Number 1135 of 1590 ------
# 051202090302 Land Use 21 (Developed, Open Space): 4.0567727112954
# 0.18 minutes to process.
# ------ Subwatershed: 051201070201 Number 1136 of 1590 ------
# 051201070201 Land Use 21 (Developed, Open Space): 1.9689338012299322
# 0.13 minutes to process.
# ------ Subwatershed: 040500011604 Number 1137 of 1590 ------
# 040500011604 Land Use 21 (Developed, Open Space): 2.1473972522847062
# 0.17 minutes to process.
# ------ Subwatershed: 051201130708 Number 1138 of 1590 ------
# 051201130708 Land Use 21 (Developed, Open Space): 1.8784483304240829
# 0.13 minutes to process.
# ------ Subwatershed: 051401010804 Number 1139 of 1590 ------
# 051401010804 Land Use 21 (Developed, Open Space): 3.8702746997832427
# 0.2 minutes to process.
# ------ Subwatershed: 050800030710 Number 1140 of 1590 ------
# 050800030710 Land Use 21 (Developed, Open Space): 1.7971653445471478
# 0.14 minutes to process.
# ------ Subwatershed: 051202020508 Number 1141 of 1590 ------
# 051202020508 Land Use 21 (Developed, Open Space): 1.8188036703748134
# 0.16 minutes to process.
# ------ Subwatershed: 051202020101 Number 1142 of 1590 ------
# 051202020101 Land Use 21 (Developed, Open Space): 4.81639719349552
# 0.2 minutes to process.
# ------ Subwatershed: 051201110601 Number 1143 of 1590 ------
# 051201110601 Land Use 21 (Developed, Open Space): 1.596272063572565
# 0.15 minutes to process.
# ------ Subwatershed: 051202010808 Number 1144 of 1590 ------
# 051202010808 Land Use 21 (Developed, Open Space): 5.9997455608034285
# 0.22 minutes to process.
# ------ Subwatershed: 051201100606 Number 1145 of 1590 ------
# 051201100606 Land Use 21 (Developed, Open Space): 4.303199632077392
# 0.2 minutes to process.
# ------ Subwatershed: 051202040102 Number 1146 of 1590 ------
# 051202040102 Land Use 21 (Developed, Open Space): 2.371959174700372
# 0.19 minutes to process.
# ------ Subwatershed: 051201060301 Number 1147 of 1590 ------
# 051201060301 Land Use 21 (Developed, Open Space): 1.9710862370632014
# 0.17 minutes to process.
# ------ Subwatershed: 051201130503 Number 1148 of 1590 ------
# 051201130503 Land Use 21 (Developed, Open Space): 2.775995025982309
# 0.17 minutes to process.
# ------ Subwatershed: 051401010305 Number 1149 of 1590 ------
# 051401010305 Land Use 21 (Developed, Open Space): 0.118165342577599
# 0.14 minutes to process.
# ------ Subwatershed: 050902030802 Number 1150 of 1590 ------
# 050902030802 Land Use 21 (Developed, Open Space): 3.643194052163757
# 0.22 minutes to process.
# ------ Subwatershed: 050902030501 Number 1151 of 1590 ------
# 050902030501 Land Use 21 (Developed, Open Space): 2.5980492041736594
# 0.19 minutes to process.
# ------ Subwatershed: 051202011501 Number 1152 of 1590 ------
# 051202011501 Land Use 21 (Developed, Open Space): 2.840148892393243
# 0.19 minutes to process.
# ------ Subwatershed: 051202040405 Number 1153 of 1590 ------
# 051202040405 Land Use 21 (Developed, Open Space): 5.925966086863153
# 0.24 minutes to process.
# ------ Subwatershed: 051201030404 Number 1154 of 1590 ------
# 051201030404 Land Use 21 (Developed, Open Space): 3.14739616621305
# 0.18 minutes to process.
# ------ Subwatershed: 051201010803 Number 1155 of 1590 ------
# 051201010803 Land Use 21 (Developed, Open Space): 1.5731935430562975
# 0.17 minutes to process.
# ------ Subwatershed: 071200030304 Number 1156 of 1590 ------
# 071200030304 Land Use 21 (Developed, Open Space): 6.131659569072751
# 0.27 minutes to process.
# ------ Subwatershed: 041000030402 Number 1157 of 1590 ------
# 041000030402 Land Use 21 (Developed, Open Space): 0.8864962288336119
# 0.19 minutes to process.
# ------ Subwatershed: 051202080101 Number 1158 of 1590 ------
# 051202080101 Land Use 21 (Developed, Open Space): 2.478320157533456
# 0.19 minutes to process.
# ------ Subwatershed: 051202060101 Number 1159 of 1590 ------
# 051202060101 Land Use 21 (Developed, Open Space): 1.703686240080211
# 0.18 minutes to process.
# ------ Subwatershed: 051202040108 Number 1160 of 1590 ------
# 051202040108 Land Use 21 (Developed, Open Space): 5.546818255628255
# 0.21 minutes to process.
# ------ Subwatershed: 051201060802 Number 1161 of 1590 ------
# 051201060802 Land Use 21 (Developed, Open Space): 1.9327221708337907
# 0.18 minutes to process.
# ------ Subwatershed: 051201011002 Number 1162 of 1590 ------
# 051201011002 Land Use 21 (Developed, Open Space): 9.368528295678137
# 0.25 minutes to process.
# ------ Subwatershed: 041000030802 Number 1163 of 1590 ------
# 041000030802 Land Use 21 (Developed, Open Space): 3.57096367503526
# 0.25 minutes to process.
# ------ Subwatershed: 041000071204 Number 1164 of 1590 ------
# 041000071204 Land Use 21 (Developed, Open Space): 2.44575342518265
# 0.2 minutes to process.
# ------ Subwatershed: 051401040805 Number 1165 of 1590 ------
# 051401040805 Land Use 21 (Developed, Open Space): 3.98218668322565
# 0.24 minutes to process.
# ------ Subwatershed: 051202090104 Number 1166 of 1590 ------
# 051202090104 Land Use 21 (Developed, Open Space): 1.5150448376491443
# 0.2 minutes to process.
# ------ Subwatershed: 051202070605 Number 1167 of 1590 ------
# 051202070605 Land Use 21 (Developed, Open Space): 4.36913447454421
# 0.24 minutes to process.
# ------ Subwatershed: 051201111104 Number 1168 of 1590 ------
# 051201111104 Land Use 21 (Developed, Open Space): 2.3934533884900664
# 0.24 minutes to process.
# ------ Subwatershed: 051202010404 Number 1169 of 1590 ------
# 051202010404 Land Use 21 (Developed, Open Space): 4.983757686926419
# 0.24 minutes to process.
# ------ Subwatershed: 051201070402 Number 1170 of 1590 ------
# 051201070402 Land Use 21 (Developed, Open Space): 3.277962210125345
# 0.23 minutes to process.
# ------ Subwatershed: 051201130305 Number 1171 of 1590 ------
# 051201130305 Land Use 21 (Developed, Open Space): 4.020943073028032
# 0.24 minutes to process.
# ------ Subwatershed: 051402011101 Number 1172 of 1590 ------
# 051402011101 Land Use 21 (Developed, Open Space): 4.833979583217333
# 0.3 minutes to process.
# ------ Subwatershed: 051201111101 Number 1173 of 1590 ------
# 051201111101 Land Use 21 (Developed, Open Space): 0.0635159749013626
# 0.2 minutes to process.
# ------ Subwatershed: 071200020705 Number 1174 of 1590 ------
# 071200020705 Land Use 21 (Developed, Open Space): 1.605419463151522
# 0.22 minutes to process.
# ------ Subwatershed: 051202060202 Number 1175 of 1590 ------
# 051202060202 Land Use 21 (Developed, Open Space): 1.9810279557718995
# 0.22 minutes to process.
# ------ Subwatershed: 051202010105 Number 1176 of 1590 ------
# 051202010105 Land Use 21 (Developed, Open Space): 2.3021679132554502
# 0.22 minutes to process.
# ------ Subwatershed: 051201020401 Number 1177 of 1590 ------
# 051201020401 Land Use 21 (Developed, Open Space): 4.002652673836431
# 0.24 minutes to process.
# ------ Subwatershed: 051201040505 Number 1178 of 1590 ------
# 051201040505 Land Use 21 (Developed, Open Space): 2.5603110512442853
# 0.23 minutes to process.
# ------ Subwatershed: 051201060103 Number 1179 of 1590 ------
# 051201060103 Land Use 21 (Developed, Open Space): 4.63888698295463
# 0.3 minutes to process.
# ------ Subwatershed: 041000030801 Number 1180 of 1590 ------
# 041000030801 Land Use 21 (Developed, Open Space): 3.0178855296226637
# 0.27 minutes to process.
# ------ Subwatershed: 051202050601 Number 1181 of 1590 ------
# 051202050601 Land Use 21 (Developed, Open Space): 2.1548081753121417
# 0.24 minutes to process.
# ------ Subwatershed: 041000040403 Number 1182 of 1590 ------
# 041000040403 Land Use 21 (Developed, Open Space): 2.5116128418257375
# 0.26 minutes to process.
# ------ Subwatershed: 051402011001 Number 1183 of 1590 ------
# 051402011001 Land Use 21 (Developed, Open Space): 2.524385023240716
# 0.3 minutes to process.
# ------ Subwatershed: 051401040303 Number 1184 of 1590 ------
# 051401040303 Land Use 21 (Developed, Open Space): 3.0028744138280947
# 0.26 minutes to process.
# ------ Subwatershed: 051201111703 Number 1185 of 1590 ------
# 051201111703 Land Use 21 (Developed, Open Space): 1.661804394741936
# 0.26 minutes to process.
# ------ Subwatershed: 051201111505 Number 1186 of 1590 ------
# 051201111505 Land Use 21 (Developed, Open Space): 2.481480892748646
# 0.27 minutes to process.
# ------ Subwatershed: 051202011006 Number 1187 of 1590 ------
# 051202011006 Land Use 21 (Developed, Open Space): 32.02654455446264
# 0.45 minutes to process.
# ------ Subwatershed: 051201090801 Number 1188 of 1590 ------
# 051201090801 Land Use 21 (Developed, Open Space): 1.977749201580155
# 0.25 minutes to process.
# ------ Subwatershed: 071200011311 Number 1189 of 1590 ------
# 071200011311 Land Use 21 (Developed, Open Space): 1.088003137990303
# 0.27 minutes to process.
# ------ Subwatershed: 051202060402 Number 1190 of 1590 ------
# 051202060402 Land Use 21 (Developed, Open Space): 1.8364878739242743
# 0.27 minutes to process.
# ------ Subwatershed: 051201030206 Number 1191 of 1590 ------
# 051201030206 Land Use 21 (Developed, Open Space): 2.875270993490914
# 0.26 minutes to process.
# ------ Subwatershed: 051201080201 Number 1192 of 1590 ------
# 051201080201 Land Use 21 (Developed, Open Space): 1.6367564777436077
# 0.28 minutes to process.
# ------ Subwatershed: 071200011101 Number 1193 of 1590 ------
# 071200011101 Land Use 21 (Developed, Open Space): 6.935185149650918
# 0.38 minutes to process.
# ------ Subwatershed: 071200010305 Number 1194 of 1590 ------
# 071200010305 Land Use 21 (Developed, Open Space): 2.2917640630132845
# 0.32 minutes to process.
# ------ Subwatershed: 041000050106 Number 1195 of 1590 ------
# 041000050106 Land Use 21 (Developed, Open Space): 1.8531680931538963
# 0.3 minutes to process.
# ------ Subwatershed: 051201111602 Number 1196 of 1590 ------
# 051201111602 Land Use 21 (Developed, Open Space): 2.3303890638807294
# 0.31 minutes to process.
# ------ Subwatershed: 051201110402 Number 1197 of 1590 ------
# 051201110402 Land Use 21 (Developed, Open Space): 2.656121625022966
# 0.31 minutes to process.
# ------ Subwatershed: 051201100502 Number 1198 of 1590 ------
# 051201100502 Land Use 21 (Developed, Open Space): 1.9789800248744334
# 0.29 minutes to process.
# ------ Subwatershed: 051401010702 Number 1199 of 1590 ------
# 051401010702 Land Use 21 (Developed, Open Space): 1.8226703774867143
# 0.3 minutes to process.
# ------ Subwatershed: 051202081201 Number 1200 of 1590 ------
# 051202081201 Land Use 21 (Developed, Open Space): 3.165686658263527
# 0.3 minutes to process.
# ------ Subwatershed: 051202080701 Number 1201 of 1590 ------
# 051202080701 Land Use 21 (Developed, Open Space): 2.638269561594207
# 0.31 minutes to process.
# ------ Subwatershed: 041000030706 Number 1202 of 1590 ------
# 041000030706 Land Use 21 (Developed, Open Space): 5.204353715326689
# 0.4 minutes to process.
# ------ Subwatershed: 040400010502 Number 1203 of 1590 ------
# 040400010502 Land Use 21 (Developed, Open Space): 4.4402239449247105
# 0.42 minutes to process.
# ------ Subwatershed: 041000030701 Number 1204 of 1590 ------
# 041000030701 Land Use 21 (Developed, Open Space): 2.053910049977823
# 0.36 minutes to process.
# ------ Subwatershed: 050800030802 Number 1205 of 1590 ------
# 050800030802 Land Use 21 (Developed, Open Space): 1.8277255134992778
# 0.31 minutes to process.
# ------ Subwatershed: 051202030503 Number 1206 of 1590 ------
# 051202030503 Land Use 21 (Developed, Open Space): 2.162264042171035
# 0.33 minutes to process.
# ------ Subwatershed: 071200020506 Number 1207 of 1590 ------
# 071200020506 Land Use 21 (Developed, Open Space): 1.5188461491484124
# 0.32 minutes to process.
# ------ Subwatershed: 051201011405 Number 1208 of 1590 ------
# 051201011405 Land Use 21 (Developed, Open Space): 6.010655420411483
# 0.4 minutes to process.
# ------ Subwatershed: 051401040502 Number 1209 of 1590 ------
# 051401040502 Land Use 21 (Developed, Open Space): 4.5313407449034155
# 0.39 minutes to process.
# ------ Subwatershed: 040500010805 Number 1210 of 1590 ------
# 040500010805 Land Use 21 (Developed, Open Space): 1.73769792340971
# 0.37 minutes to process.
# ------ Subwatershed: 051202021005 Number 1211 of 1590 ------
# 051202021005 Land Use 21 (Developed, Open Space): 5.5080533643829614
# 0.37 minutes to process.
# ------ Subwatershed: 051202070603 Number 1212 of 1590 ------
# 051202070603 Land Use 21 (Developed, Open Space): 2.3698550359902137
# 0.35 minutes to process.
# ------ Subwatershed: 051202020211 Number 1213 of 1590 ------
# 051202020211 Land Use 21 (Developed, Open Space): 1.8429163624893121
# 0.34 minutes to process.
# ------ Subwatershed: 051202040301 Number 1214 of 1590 ------
# 051202040301 Land Use 21 (Developed, Open Space): 1.7408061343493975
# 0.33 minutes to process.
# ------ Subwatershed: 051202040403 Number 1215 of 1590 ------
# 051202040403 Land Use 21 (Developed, Open Space): 2.960054651729728
# 0.43 minutes to process.
# ------ Subwatershed: 051201020201 Number 1216 of 1590 ------
# 051201020201 Land Use 21 (Developed, Open Space): 2.759565931385394
# 0.48 minutes to process.
# ------ Subwatershed: 051201080404 Number 1217 of 1590 ------
# 051201080404 Land Use 21 (Developed, Open Space): 1.450468818971572
# 0.45 minutes to process.
# ------ Subwatershed: 051201040407 Number 1218 of 1590 ------
# 051201040407 Land Use 21 (Developed, Open Space): 3.11132991321209
# 0.51 minutes to process.
# ------ Subwatershed: 051401040904 Number 1219 of 1590 ------
# 051401040904 Land Use 21 (Developed, Open Space): 2.4446568260284263
# 0.48 minutes to process.
# ------ Subwatershed: 051402020107 Number 1220 of 1590 ------
# 051402020107 Land Use 21 (Developed, Open Space): 2.329099228577494
# 0.51 minutes to process.
# ------ Subwatershed: 051202030510 Number 1221 of 1590 ------
# 051202030510 Land Use 21 (Developed, Open Space): 3.147250431545963
# 0.61 minutes to process.
# ------ Subwatershed: 051201080901 Number 1222 of 1590 ------
# 051201080901 Land Use 21 (Developed, Open Space): 2.1737209391526355
# 0.47 minutes to process.
# ------ Subwatershed: 071200020206 Number 1223 of 1590 ------
# 071200020206 Land Use 21 (Developed, Open Space): 0.9414789295118008
# 0.44 minutes to process.
# ------ Subwatershed: 051201040602 Number 1224 of 1590 ------
# 051201040602 Land Use 21 (Developed, Open Space): 2.3427238912120973
# 0.43 minutes to process.
# ------ Subwatershed: 071200010506 Number 1225 of 1590 ------
# 071200010506 Land Use 21 (Developed, Open Space): 1.8937043407856893
# 0.43 minutes to process.
# ------ Subwatershed: 050800030304 Number 1226 of 1590 ------
# 050800030304 Land Use 21 (Developed, Open Space): 2.306371299987253
# 0.53 minutes to process.
# ------ Subwatershed: 051202080804 Number 1227 of 1590 ------
# 051202080804 Land Use 21 (Developed, Open Space): 2.4937700136531786
# 0.52 minutes to process.
# ------ Subwatershed: 051201110504 Number 1228 of 1590 ------
# 051201110504 Land Use 21 (Developed, Open Space): 3.8120539250800314
# 0.48 minutes to process.
# ------ Subwatershed: 051202010309 Number 1229 of 1590 ------
# 051202010309 Land Use 21 (Developed, Open Space): 2.510944954460051
# 0.6 minutes to process.
# ------ Subwatershed: 051201050506 Number 1230 of 1590 ------
# 051201050506 Land Use 21 (Developed, Open Space): 2.1706335940913073
# 0.51 minutes to process.
# ------ Subwatershed: 051201060903 Number 1231 of 1590 ------
# 051201060903 Land Use 21 (Developed, Open Space): 2.082506053658685
# 0.43 minutes to process.
# ------ Subwatershed: 051201011305 Number 1232 of 1590 ------
# 051201011305 Land Use 21 (Developed, Open Space): 1.7625316128144555
# 0.41 minutes to process.
# ------ Subwatershed: 051201060509 Number 1233 of 1590 ------
# 051201060509 Land Use 21 (Developed, Open Space): 4.3037237478488475
# 0.46 minutes to process.
# ------ Subwatershed: 040500012206 Number 1234 of 1590 ------
# 040500012206 Land Use 21 (Developed, Open Space): 24.155083900222674
# 0.55 minutes to process.
# ------ Subwatershed: 051202080301 Number 1235 of 1590 ------
# 051202080301 Land Use 21 (Developed, Open Space): 1.3495753431564221
# 0.42 minutes to process.
# ------ Subwatershed: 051201111802 Number 1236 of 1590 ------
# 051201111802 Land Use 21 (Developed, Open Space): 2.548599142997446
# 0.42 minutes to process.
# ------ Subwatershed: 051202011302 Number 1237 of 1590 ------
# 051202011302 Land Use 21 (Developed, Open Space): 9.08757323250575
# 0.53 minutes to process.
# ------ Subwatershed: 051201061302 Number 1238 of 1590 ------
# 051201061302 Land Use 21 (Developed, Open Space): 1.2992211149688895
# 0.44 minutes to process.
# ------ Subwatershed: 051201130804 Number 1239 of 1590 ------
# 051201130804 Land Use 21 (Developed, Open Space): 1.3565592307785668
# 0.44 minutes to process.
# ------ Subwatershed: 050800020603 Number 1240 of 1590 ------
# 050800020603 Land Use 21 (Developed, Open Space): 0.131477048098325
# 0.41 minutes to process.
# ------ Subwatershed: 041000030301 Number 1241 of 1590 ------
# 041000030301 Land Use 21 (Developed, Open Space): 0.7643822458361802
# 0.44 minutes to process.
# ------ Subwatershed: 051202090804 Number 1242 of 1590 ------
# 051202090804 Land Use 21 (Developed, Open Space): 2.026290660908262
# 0.45 minutes to process.
# ------ Subwatershed: 051202081404 Number 1243 of 1590 ------
# 051202081404 Land Use 21 (Developed, Open Space): 2.4521320511552425
# 0.46 minutes to process.
# ------ Subwatershed: 051202020402 Number 1244 of 1590 ------
# 051202020402 Land Use 21 (Developed, Open Space): 1.7624808681081023
# 0.47 minutes to process.
# ------ Subwatershed: 051202070404 Number 1245 of 1590 ------
# 051202070404 Land Use 21 (Developed, Open Space): 4.551102455900454
# 0.51 minutes to process.
# ------ Subwatershed: 051202030101 Number 1246 of 1590 ------
# 051202030101 Land Use 21 (Developed, Open Space): 2.779502520833609
# 0.46 minutes to process.
# ------ Subwatershed: 041000040606 Number 1247 of 1590 ------
# 041000040606 Land Use 21 (Developed, Open Space): 8.842393868429847
# 0.6 minutes to process.
# ------ Subwatershed: 040500011703 Number 1248 of 1590 ------
# 040500011703 Land Use 21 (Developed, Open Space): 2.145020591286161
# 0.52 minutes to process.
# ------ Subwatershed: 051201030105 Number 1249 of 1590 ------
# 051201030105 Land Use 21 (Developed, Open Space): 3.6433190094291192
# 0.5 minutes to process.
# ------ Subwatershed: 051202020704 Number 1250 of 1590 ------
# 051202020704 Land Use 21 (Developed, Open Space): 2.1784885839349233
# 0.5 minutes to process.
# ------ Subwatershed: 051201100403 Number 1251 of 1590 ------
# 051201100403 Land Use 21 (Developed, Open Space): 2.75924249564572
# 0.5 minutes to process.
# ------ Subwatershed: 051201050302 Number 1252 of 1590 ------
# 051201050302 Land Use 21 (Developed, Open Space): 1.5381328166308428
# 0.5 minutes to process.
# ------ Subwatershed: 051201081605 Number 1253 of 1590 ------
# 051201081605 Land Use 21 (Developed, Open Space): 1.8601321782713822
# 0.52 minutes to process.
# ------ Subwatershed: 051201080601 Number 1254 of 1590 ------
# 051201080601 Land Use 21 (Developed, Open Space): 3.0750669142720093
# 0.52 minutes to process.
# ------ Subwatershed: 051201070105 Number 1255 of 1590 ------
# 051201070105 Land Use 21 (Developed, Open Space): 2.169325270685174
# 0.54 minutes to process.
# ------ Subwatershed: 051201050202 Number 1256 of 1590 ------
# 051201050202 Land Use 21 (Developed, Open Space): 2.1702342637835517
# 0.52 minutes to process.
# ------ Subwatershed: 051201061005 Number 1257 of 1590 ------
# 051201061005 Land Use 21 (Developed, Open Space): 2.5207678424816784
# 0.55 minutes to process.
# ------ Subwatershed: 051201011201 Number 1258 of 1590 ------
# 051201011201 Land Use 21 (Developed, Open Space): 2.3049790091400575
# 0.53 minutes to process.
# ------ Subwatershed: 071200010208 Number 1259 of 1590 ------
# 071200010208 Land Use 21 (Developed, Open Space): 4.400046936566761
# 0.68 minutes to process.
# ------ Subwatershed: 051202070704 Number 1260 of 1590 ------
# 051202070704 Land Use 21 (Developed, Open Space): 8.01756099427709
# 0.71 minutes to process.
# ------ Subwatershed: 051202011202 Number 1261 of 1590 ------
# 051202011202 Land Use 21 (Developed, Open Space): 11.289699492637906
# 0.69 minutes to process.
# ------ Subwatershed: 051201090905 Number 1262 of 1590 ------
# 051201090905 Land Use 21 (Developed, Open Space): 1.1897384278749574
# 0.56 minutes to process.
# ------ Subwatershed: 051202010502 Number 1263 of 1590 ------
# 051202010502 Land Use 21 (Developed, Open Space): 4.979419866703634
# 0.58 minutes to process.
# ------ Subwatershed: 051201061204 Number 1264 of 1590 ------
# 051201061204 Land Use 21 (Developed, Open Space): 1.0355467945828867
# 0.56 minutes to process.
# ------ Subwatershed: 071200011203 Number 1265 of 1590 ------
# 071200011203 Land Use 21 (Developed, Open Space): 0.8583531011785256
# 0.58 minutes to process.
# ------ Subwatershed: 051201130203 Number 1266 of 1590 ------
# 051201130203 Land Use 21 (Developed, Open Space): 2.211301532758865
# 0.56 minutes to process.
# ------ Subwatershed: 051401041107 Number 1267 of 1590 ------
# 051401041107 Land Use 21 (Developed, Open Space): 2.33581041919386
# 0.57 minutes to process.
# ------ Subwatershed: 051202070204 Number 1268 of 1590 ------
# 051202070204 Land Use 21 (Developed, Open Space): 4.560545616963025
# 0.62 minutes to process.
# ------ Subwatershed: 051201100301 Number 1269 of 1590 ------
# 051201100301 Land Use 21 (Developed, Open Space): 2.463898136341899
# 0.56 minutes to process.
# ------ Subwatershed: 051201100107 Number 1270 of 1590 ------
# 051201100107 Land Use 21 (Developed, Open Space): 2.910826311274012
# 0.6 minutes to process.
# ------ Subwatershed: 051201040401 Number 1271 of 1590 ------
# 051201040401 Land Use 21 (Developed, Open Space): 2.60373000303317
# 0.73 minutes to process.
# ------ Subwatershed: 071200010904 Number 1272 of 1590 ------
# 071200010904 Land Use 21 (Developed, Open Space): 2.147390210018692
# 0.69 minutes to process.
# ------ Subwatershed: 040500012103 Number 1273 of 1590 ------
# 040500012103 Land Use 21 (Developed, Open Space): 1.2113806357525505
# 0.69 minutes to process.
# ------ Subwatershed: 040500012004 Number 1274 of 1590 ------
# 040500012004 Land Use 21 (Developed, Open Space): 13.269134550286939
# 0.88 minutes to process.
# ------ Subwatershed: 050902030507 Number 1275 of 1590 ------
# 050902030507 Land Use 21 (Developed, Open Space): 3.2737505170277994
# 0.86 minutes to process.
# ------ Subwatershed: 051201081203 Number 1276 of 1590 ------
# 051201081203 Land Use 21 (Developed, Open Space): 2.24217692199556
# 0.77 minutes to process.
# ------ Subwatershed: 071200010408 Number 1277 of 1590 ------
# 071200010408 Land Use 21 (Developed, Open Space): 0.6937555737857751
# 0.8 minutes to process.
# ------ Subwatershed: 051402020302 Number 1278 of 1590 ------
# 051402020302 Land Use 21 (Developed, Open Space): 7.676894092469039
# 0.91 minutes to process.
# ------ Subwatershed: 051402010302 Number 1279 of 1590 ------
# 051402010302 Land Use 21 (Developed, Open Space): 3.129684186034887
# 0.84 minutes to process.
# ------ Subwatershed: 041000040407 Number 1280 of 1590 ------
# 041000040407 Land Use 21 (Developed, Open Space): 1.6440160108025523
# 0.74 minutes to process.
# ------ Subwatershed: 051201030102 Number 1281 of 1590 ------
# 051201030102 Land Use 21 (Developed, Open Space): 0.8328139982589354
# 0.78 minutes to process.
# ------ Subwatershed: 041000071002 Number 1282 of 1590 ------
# 041000071002 Land Use 21 (Developed, Open Space): 0.296352978427307
# 0.71 minutes to process.
# ------ Subwatershed: 051202080601 Number 1283 of 1590 ------
# 051202080601 Land Use 21 (Developed, Open Space): 3.6271291703987725
# 0.72 minutes to process.
# ------ Subwatershed: 051201081208 Number 1284 of 1590 ------
# 051201081208 Land Use 21 (Developed, Open Space): 3.639164037722332
# 0.76 minutes to process.
# ------ Subwatershed: 050800030713 Number 1285 of 1590 ------
# 050800030713 Land Use 21 (Developed, Open Space): 1.9792574463140555
# 0.75 minutes to process.
# ------ Subwatershed: 051402010204 Number 1286 of 1590 ------
# 051402010204 Land Use 21 (Developed, Open Space): 0.89984325237332
# 0.7 minutes to process.
# ------ Subwatershed: 050800030809 Number 1287 of 1590 ------
# 050800030809 Land Use 21 (Developed, Open Space): 0.33365151261222775
# 0.7 minutes to process.
# ------ Subwatershed: 051202020901 Number 1288 of 1590 ------
# 051202020901 Land Use 21 (Developed, Open Space): 3.1826887338081016
# 0.76 minutes to process.
# ------ Subwatershed: 051401010205 Number 1289 of 1590 ------
# 051401010205 Land Use 21 (Developed, Open Space): 4.518054179952751
# 0.79 minutes to process.
# ------ Subwatershed: 071200010405 Number 1290 of 1590 ------
# 071200010405 Land Use 21 (Developed, Open Space): 3.8824317168572784
# 0.81 minutes to process.
# ------ Subwatershed: 040500011505 Number 1291 of 1590 ------
# 040500011505 Land Use 21 (Developed, Open Space): 2.4706847563722225
# 0.76 minutes to process.
# ------ Subwatershed: 051402020305 Number 1292 of 1590 ------
# 051402020305 Land Use 21 (Developed, Open Space): 2.6310178918014486
# 0.77 minutes to process.
# ------ Subwatershed: 040400010201 Number 1293 of 1590 ------
# 040400010201 Land Use 21 (Developed, Open Space): 0.40283859076828116
# 0.73 minutes to process.
# ------ Subwatershed: 051402010102 Number 1294 of 1590 ------
# 051402010102 Land Use 21 (Developed, Open Space): 2.7794673954142595
# 0.76 minutes to process.
# ------ Subwatershed: 051202081503 Number 1295 of 1590 ------
# 051202081503 Land Use 21 (Developed, Open Space): 2.0824986361525344
# 0.81 minutes to process.
# ------ Subwatershed: 051202011403 Number 1296 of 1590 ------
# 051202011403 Land Use 21 (Developed, Open Space): 1.9702243075157808
# 0.76 minutes to process.
# ------ Subwatershed: 051202050403 Number 1297 of 1590 ------
# 051202050403 Land Use 21 (Developed, Open Space): 3.0525429644610105
# 0.78 minutes to process.
# ------ Subwatershed: 050800030604 Number 1298 of 1590 ------
# 050800030604 Land Use 21 (Developed, Open Space): 3.2140609294351963
# 0.79 minutes to process.
# ------ Subwatershed: 051202011001 Number 1299 of 1590 ------
# 051202011001 Land Use 21 (Developed, Open Space): 14.220203269071058
# 0.97 minutes to process.
# ------ Subwatershed: 071200021304 Number 1300 of 1590 ------
# 071200021304 Land Use 21 (Developed, Open Space): 1.5626207238506493
# 0.78 minutes to process.
# ------ Subwatershed: 041000040502 Number 1301 of 1590 ------
# 041000040502 Land Use 21 (Developed, Open Space): 1.7118139023916024
# 0.79 minutes to process.
# ------ Subwatershed: 050902030304 Number 1302 of 1590 ------
# 050902030304 Land Use 21 (Developed, Open Space): 6.662477554340736
# 0.9 minutes to process.
# ------ Subwatershed: 051202030808 Number 1303 of 1590 ------
# 051202030808 Land Use 21 (Developed, Open Space): 2.794532513658094
# 0.82 minutes to process.
# ------ Subwatershed: 051202010803 Number 1304 of 1590 ------
# 051202010803 Land Use 21 (Developed, Open Space): 3.346237184997683
# 0.8 minutes to process.
# ------ Subwatershed: 040500010804 Number 1305 of 1590 ------
# 040500010804 Land Use 21 (Developed, Open Space): 1.9395126475221436
# 0.81 minutes to process.
# ------ Subwatershed: 051201130802 Number 1306 of 1590 ------
# 051201130802 Land Use 21 (Developed, Open Space): 0.055358060611360005
# 0.78 minutes to process.
# ------ Subwatershed: 051201081102 Number 1307 of 1590 ------
# 051201081102 Land Use 21 (Developed, Open Space): 0.7353803692456065
# 0.8 minutes to process.
# ------ Subwatershed: 051201070305 Number 1308 of 1590 ------
# 051201070305 Land Use 21 (Developed, Open Space): 4.466888442192704
# 0.85 minutes to process.
# ------ Subwatershed: 071200020504 Number 1309 of 1590 ------
# 071200020504 Land Use 21 (Developed, Open Space): 0.8875583254084359
# 0.8 minutes to process.
# ------ Subwatershed: 040500011502 Number 1310 of 1590 ------
# 040500011502 Land Use 21 (Developed, Open Space): 2.159445965011698
# 0.87 minutes to process.
# ------ Subwatershed: 051401040203 Number 1311 of 1590 ------
# 051401040203 Land Use 21 (Developed, Open Space): 1.8378200098259891
# 0.86 minutes to process.
# ------ Subwatershed: 050800030708 Number 1312 of 1590 ------
# 050800030708 Land Use 21 (Developed, Open Space): 2.8500562878591342
# 0.86 minutes to process.
# ------ Subwatershed: 071200020702 Number 1313 of 1590 ------
# 071200020702 Land Use 21 (Developed, Open Space): 1.8416209173873224
# 0.9 minutes to process.
# ------ Subwatershed: 051201020404 Number 1314 of 1590 ------
# 051201020404 Land Use 21 (Developed, Open Space): 3.299319282739073
# 0.86 minutes to process.
# ------ Subwatershed: 051202090801 Number 1315 of 1590 ------
# 051202090801 Land Use 21 (Developed, Open Space): 3.001836074491823
# 0.97 minutes to process.
# ------ Subwatershed: 051202020308 Number 1316 of 1590 ------
# 051202020308 Land Use 21 (Developed, Open Space): 2.9050362535330616
# 0.98 minutes to process.
# ------ Subwatershed: 051202070103 Number 1317 of 1590 ------
# 051202070103 Land Use 21 (Developed, Open Space): 2.37348650894505
# 0.95 minutes to process.
# ------ Subwatershed: 051201080410 Number 1318 of 1590 ------
# 051201080410 Land Use 21 (Developed, Open Space): 2.7327250563365695
# 0.98 minutes to process.
# ------ Subwatershed: 051201080403 Number 1319 of 1590 ------
# 051201080403 Land Use 21 (Developed, Open Space): 0.7789773685636966
# 0.91 minutes to process.
# ------ Subwatershed: 051201030509 Number 1320 of 1590 ------
# 051201030509 Land Use 21 (Developed, Open Space): 2.904540229688441
# 0.91 minutes to process.
# ------ Subwatershed: 051201130709 Number 1321 of 1590 ------
# 051201130709 Land Use 21 (Developed, Open Space): 5.637821011831859
# 0.93 minutes to process.
# ------ Subwatershed: 051201130703 Number 1322 of 1590 ------
# 051201130703 Land Use 21 (Developed, Open Space): 4.673788552588802
# 0.92 minutes to process.
# ------ Subwatershed: 051401010604 Number 1323 of 1590 ------
# 051401010604 Land Use 21 (Developed, Open Space): 2.193185845729443
# 0.91 minutes to process.
# ------ Subwatershed: 051401040703 Number 1324 of 1590 ------
# 051401040703 Land Use 21 (Developed, Open Space): 6.554385495994188
# 1.01 minutes to process.
# ------ Subwatershed: 051202040807 Number 1325 of 1590 ------
# 051202040807 Land Use 21 (Developed, Open Space): 2.733897388382131
# 1.0 minutes to process.
# ------ Subwatershed: 051202030702 Number 1326 of 1590 ------
# 051202030702 Land Use 21 (Developed, Open Space): 2.8027777422706097
# 1.1 minutes to process.
# ------ Subwatershed: 071200010805 Number 1327 of 1590 ------
# 071200010805 Land Use 21 (Developed, Open Space): 0.6622556040463354
# 1.02 minutes to process.
# ------ Subwatershed: 051201040103 Number 1328 of 1590 ------
# 051201040103 Land Use 21 (Developed, Open Space): 2.083285713118341
# 0.98 minutes to process.
# ------ Subwatershed: 050902030702 Number 1329 of 1590 ------
# 050902030702 Land Use 21 (Developed, Open Space): 3.433955905902639
# 1.03 minutes to process.
# ------ Subwatershed: 051201070202 Number 1330 of 1590 ------
# 051201070202 Land Use 21 (Developed, Open Space): 1.9334264032832134
# 0.94 minutes to process.
# ------ Subwatershed: 051201040705 Number 1331 of 1590 ------
# 051201040705 Land Use 21 (Developed, Open Space): 8.729258494506352
# 1.02 minutes to process.
# ------ Subwatershed: 071200010205 Number 1332 of 1590 ------
# 071200010205 Land Use 21 (Developed, Open Space): 3.859668252339769
# 1.04 minutes to process.
# ------ Subwatershed: 051401010805 Number 1333 of 1590 ------
# 051401010805 Land Use 21 (Developed, Open Space): 10.212866359336969
# 1.17 minutes to process.
# ------ Subwatershed: 040400010509 Number 1334 of 1590 ------
# 040400010509 Land Use 21 (Developed, Open Space): 5.409027201520068
# 1.21 minutes to process.
# ------ Subwatershed: 051202070901 Number 1335 of 1590 ------
# 051202070901 Land Use 21 (Developed, Open Space): 4.331070154094326
# 1.0 minutes to process.
# ------ Subwatershed: 051202040103 Number 1336 of 1590 ------
# 051202040103 Land Use 21 (Developed, Open Space): 6.09592589425531
# 1.04 minutes to process.
# ------ Subwatershed: 051201060403 Number 1337 of 1590 ------
# 051201060403 Land Use 21 (Developed, Open Space): 3.9068561415842815
# 1.02 minutes to process.
# ------ Subwatershed: 071200011309 Number 1338 of 1590 ------
# 071200011309 Land Use 21 (Developed, Open Space): 0.769034185446739
# 1.02 minutes to process.
# ------ Subwatershed: 051201020101 Number 1339 of 1590 ------
# 051201020101 Land Use 21 (Developed, Open Space): 3.1502062327818767
# 1.0 minutes to process.
# ------ Subwatershed: 051401040901 Number 1340 of 1590 ------
# 051401040901 Land Use 21 (Developed, Open Space): 3.0072574278936917
# 1.03 minutes to process.
# ------ Subwatershed: 051202040501 Number 1341 of 1590 ------
# 051202040501 Land Use 21 (Developed, Open Space): 12.79895556514812
# 1.14 minutes to process.
# ------ Subwatershed: 051201081502 Number 1342 of 1590 ------
# 051201081502 Land Use 21 (Developed, Open Space): 1.8524028751808357
# 1.08 minutes to process.
# ------ Subwatershed: 051202011101 Number 1343 of 1590 ------
# 051202011101 Land Use 21 (Developed, Open Space): 1.8814196316255347
# 1.02 minutes to process.
# ------ Subwatershed: 051201030501 Number 1344 of 1590 ------
# 051201030501 Land Use 21 (Developed, Open Space): 2.2563581962799018
# 1.04 minutes to process.
# ------ Subwatershed: 071200011302 Number 1345 of 1590 ------
# 071200011302 Land Use 21 (Developed, Open Space): 1.0013002431323033
# 1.06 minutes to process.
# ------ Subwatershed: 051202070606 Number 1346 of 1590 ------
# 051202070606 Land Use 21 (Developed, Open Space): 2.87968321383837
# 1.09 minutes to process.
# ------ Subwatershed: 050800030804 Number 1347 of 1590 ------
# 050800030804 Land Use 21 (Developed, Open Space): 2.9522837268559172
# 1.1 minutes to process.
# ------ Subwatershed: 051201010604 Number 1348 of 1590 ------
# 051201010604 Land Use 21 (Developed, Open Space): 2.729195104119099
# 1.08 minutes to process.
# ------ Subwatershed: 051202081301 Number 1349 of 1590 ------
# 051202081301 Land Use 21 (Developed, Open Space): 1.7660984514322116
# 1.07 minutes to process.
# ------ Subwatershed: 051202020601 Number 1350 of 1590 ------
# 051202020601 Land Use 21 (Developed, Open Space): 4.207549445250748
# 1.19 minutes to process.
# ------ Subwatershed: 051201111508 Number 1351 of 1590 ------
# 051201111508 Land Use 21 (Developed, Open Space): 3.176934575805431
# 1.12 minutes to process.
# ------ Subwatershed: 051201111202 Number 1352 of 1590 ------
# 051201111202 Land Use 21 (Developed, Open Space): 3.791239529066443
# 1.11 minutes to process.
# ------ Subwatershed: 051202030802 Number 1353 of 1590 ------
# 051202030802 Land Use 21 (Developed, Open Space): 2.248637021845084
# 1.11 minutes to process.
# ------ Subwatershed: 051201110603 Number 1354 of 1590 ------
# 051201110603 Land Use 21 (Developed, Open Space): 10.288259491320083
# 1.24 minutes to process.
# ------ Subwatershed: 051202010809 Number 1355 of 1590 ------
# 051202010809 Land Use 21 (Developed, Open Space): 13.323712042827742
# 1.4 minutes to process.
# ------ Subwatershed: 051201061308 Number 1356 of 1590 ------
# 051201061308 Land Use 21 (Developed, Open Space): 2.022078822260691
# 1.15 minutes to process.
# ------ Subwatershed: 051402010904 Number 1357 of 1590 ------
# 051402010904 Land Use 21 (Developed, Open Space): 2.2207646402350685
# 1.15 minutes to process.
# ------ Subwatershed: 051202090105 Number 1358 of 1590 ------
# 051202090105 Land Use 21 (Developed, Open Space): 2.8201696091898647
# 1.16 minutes to process.
# ------ Subwatershed: 051201060503 Number 1359 of 1590 ------
# 051201060503 Land Use 21 (Developed, Open Space): 2.8259994758717424
# 1.18 minutes to process.
# ------ Subwatershed: 051201010804 Number 1360 of 1590 ------
# 051201010804 Land Use 21 (Developed, Open Space): 2.930889127015326
# 1.18 minutes to process.
# ------ Subwatershed: 040400010402 Number 1361 of 1590 ------
# 040400010402 Land Use 21 (Developed, Open Space): 1.6370581403448354
# 1.25 minutes to process.
# ------ Subwatershed: 051201111103 Number 1362 of 1590 ------
# 051201111103 Land Use 21 (Developed, Open Space): 0.9698312343897869
# 1.17 minutes to process.
# ------ Subwatershed: 050902030504 Number 1363 of 1590 ------
# 050902030504 Land Use 21 (Developed, Open Space): 2.5397317892811198
# 1.23 minutes to process.
# ------ Subwatershed: 051202011601 Number 1364 of 1590 ------
# 051202011601 Land Use 21 (Developed, Open Space): 4.820572564953737
# 1.17 minutes to process.
# ------ Subwatershed: 051202060102 Number 1365 of 1590 ------
# 051202060102 Land Use 21 (Developed, Open Space): 2.080055355410601
# 1.15 minutes to process.
# ------ Subwatershed: 051201070406 Number 1366 of 1590 ------
# 051201070406 Land Use 21 (Developed, Open Space): 1.5236219896145176
# 1.19 minutes to process.
# ------ Subwatershed: 051201040508 Number 1367 of 1590 ------
# 051201040508 Land Use 21 (Developed, Open Space): 1.3293740777956178
# 1.17 minutes to process.
# ------ Subwatershed: 051201060302 Number 1368 of 1590 ------
# 051201060302 Land Use 21 (Developed, Open Space): 4.428616200769022
# 1.39 minutes to process.
# ------ Subwatershed: 041000071205 Number 1369 of 1590 ------
# 041000071205 Land Use 21 (Developed, Open Space): 2.5394402058804744
# 1.21 minutes to process.
# ------ Subwatershed: 051202060203 Number 1370 of 1590 ------
# 051202060203 Land Use 21 (Developed, Open Space): 4.126998211623815
# 1.26 minutes to process.
# ------ Subwatershed: 051202020205 Number 1371 of 1590 ------
# 051202020205 Land Use 21 (Developed, Open Space): 3.143430607479114
# 1.22 minutes to process.
# ------ Subwatershed: 051202060104 Number 1372 of 1590 ------
# 051202060104 Land Use 21 (Developed, Open Space): 1.38332977946382
# 1.2 minutes to process.
# ------ Subwatershed: 051202040704 Number 1373 of 1590 ------
# 051202040704 Land Use 21 (Developed, Open Space): 3.2209373366976317
# 1.29 minutes to process.
# ------ Subwatershed: 050800030108 Number 1374 of 1590 ------
# 050800030108 Land Use 21 (Developed, Open Space): 4.484026659189551
# 1.26 minutes to process.
# ------ Subwatershed: 071200020103 Number 1375 of 1590 ------
# 071200020103 Land Use 21 (Developed, Open Space): 1.582755805423011
# 1.3 minutes to process.
# ------ Subwatershed: 051401040402 Number 1376 of 1590 ------
# 051401040402 Land Use 21 (Developed, Open Space): 7.869624934339423
# 1.34 minutes to process.
# ------ Subwatershed: 050800030203 Number 1377 of 1590 ------
# 050800030203 Land Use 21 (Developed, Open Space): 1.8148545567779726
# 1.23 minutes to process.
# ------ Subwatershed: 041000040302 Number 1378 of 1590 ------
# 041000040302 Land Use 21 (Developed, Open Space): 0.02570466340186
# 1.23 minutes to process.
# ------ Subwatershed: 051202081508 Number 1379 of 1590 ------
# 051202081508 Land Use 21 (Developed, Open Space): 3.5279140540520113
# 1.28 minutes to process.
# ------ Subwatershed: 071200020402 Number 1380 of 1590 ------
# 071200020402 Land Use 21 (Developed, Open Space): 0.9523446106828347
# 1.27 minutes to process.
# ------ Subwatershed: 040400010505 Number 1381 of 1590 ------
# 040400010505 Land Use 21 (Developed, Open Space): 5.894796591806417
# 1.39 minutes to process.
# ------ Subwatershed: 051402011002 Number 1382 of 1590 ------
# 051402011002 Land Use 21 (Developed, Open Space): 2.3151699236656165
# 1.29 minutes to process.
# ------ Subwatershed: 041000030803 Number 1383 of 1590 ------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-345cfdd16949> in <module>
#      15             #select subwatershed from shapefile with all of them
#      16             subwatershed_selection = arcpy.SelectLayerByAttribute_management(all_subwatersheds, "NEW_SELECTION",
# ---> 17                                                                              "HUC12 = " + "'"+subwatershed_number+"'")
#      18
#      19             #select centroid from shapefile with all of them
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in SelectLayerByAttribute(in_layer_or_view, selection_type, where_clause, invert_where_clause)
#    8519     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    8520     try:
# -> 8521         retval = convertArcObjectToPythonObject(gp.SelectLayerByAttribute_management(*gp_fixargs((in_layer_or_view, selection_type, where_clause, invert_where_clause), True)))
#    8522         return retval
#    8523     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     509         val = getattr(self._gp, attr)
#     510         if callable(val):
# --> 511             return lambda *args: val(*gp_fixargs(args, True))
#     512         else:
#     513             return convertArcObjectToPythonObject(val)
#
# KeyboardInterrupt:

# %%
len(lu_21_list)
# Out:
# 325

# %%
st = time()
outputs = {'subwatershed': subwatershed_list[0:325],
#           'area': area_list[0:167],
#           'perimeter': perimeter_list[0:167],
#           'circulatory_ratio': circulatory_ratio_list[0:167],
#           'relief': relief_list[0:167],
#           'avg_slope': avg_slope_list[0:167],
#            'watershed_length': watershed_length_list[0:167],
#            'elongation_ratio': elongation_ratio_list[0:167],
#            'drainage_density': drainage_density_list[0:167],
#            'shape_factor': shape_factor_list[0:167],
#            'relief_ratio': relief_ratio_list[0:167],
#            'ruggedness': ruggedness_list[0:167]}
#            'aae_area': aae_list[0:167],
#            'buildings_aae_count': buildings_aae_list[0:167],
#            'x_area': x_list[0:167],
#            'buildings_x_count': buildings_x_list[0:167],
#            'water_bodies_area': water_bodies_list[0:167],
#            'dams_count': dams_list[0:167],
#            'bridges_count': bridges_list[0:167],
#            'streets_km': streets_list[0:167],
#            'railroads_km': railroads_list[0:167],
#            'population': population_list[0:167],
#            'population_density': population_density_list[0:167],
#            'avg_median_income': avg_median_income_list[0:167],
#            'housing_density': housing_density_list[0:167],
#            'population_change': population_change_list[0:167],
#            'dependent_population_pct': dependent_population_list[0:167],
#            'dist_to_stream_avg (m)': dist_to_stream_avg_list[0:167],
#            'dist_to_stream_stdev (m)': dist_to_stream_stdev_list[0:167],
           'lu_21_area' : lu_21_list[0:325]
#            'lu_22_area' : lu_22_list[0:167],
#            'lu_23_area' : lu_23_list[0:167],
#            'lu_24_area': lu_24_list[0:167],
#            'lu_41_area': lu_41_list[0:167],
#            'lu_82_area': lu_82_list[0:167],
#            'avg_impervious_percent': impervious_percent_list[0:167],
#            'orb100yr06h': orb100yr06h_list[0:167],
#            'orb100yr12h': orb100yr12h_list[0:167],
#            'orb100yr24h': orb100yr24h_list[0:167],
#            'orb25yr06h': orb25yr06h_list[0:167],
#            'orb25yr12h': orb25yr12h_list[0:167],
#            'orb25yr24h':orb25yr24h_list[0:167],
#            'orb2yr06h': orb2yr06h_list[0:167],
#            'orb2yr12h': orb2yr12h_list[0:167],
#            'orb2yr24h': orb2yr24h_list[0:167],
#            'orb50yr06h': orb50yr06h_list[0:167],
#            'orb50yr12h': orb50yr12h_list[0:167],
#            'orb50yr24h':orb50yr24h_list[0:167],
#            'orb100yr06ha_am': orb100yr06ha_am_list[0:167],
#            'orb100yr12ha_am': orb100yr12ha_am_list[0:167],
#            'orb100yr24ha_am': orb100yr24ha_am_list[0:167],
#            'orb25yr06ha_am': orb25yr06ha_am_list[0:167],
#            'orb25yr12ha_am': orb25yr12ha_am_list[0:167],
#            'orb25yr24ha_am': orb25yr24ha_am_list[0:167],
#            'orb2yr06ha_am': orb2yr06ha_am_list[0:167],
#            'orb2yr12ha_am': orb2yr12ha_am_list[0:167],
#            'orb2yr24ha_am': orb2yr24ha_am_list[0:167],
#            'orb50yr06ha_am': orb50yr06ha_am_list[0:167],
#            'orb50yr12ha_am': orb50yr12ha_am_list[0:167],
#            'orb50yr24ha_am': orb50yr24ha_am_list[0:167]
          }

# 
# 
# 
#  
#         
# 
            
outputs_df = pd.DataFrame(outputs, columns = ['subwatershed',
#                                              'area',
#                                              'perimeter',
#                                              'circulatory_ratio',
#                                              'relief',
#                                              'avg_slope',
#                                               'watershed_length',
#                                               'elongation_ratio',
#                                               'drainage_density',
#                                               'shape_factor',
#                                               'relief_ratio',
#                                               'ruggedness'
#                                               'aae_area',
#                                               'buildings_aae_count',
#                                               'x_area',
#                                               'buildings_x_count',
#                                               'water_bodies_area',
#                                               'dams_count',
#                                               'bridges_count',
#                                               'streets_km',
#                                               'railroads_km',
#                                               'population',
#                                               'population_density',
#                                               'avg_median_income',
#                                               'housing_density',
#                                               'population_change',
#                                               'dependent_population_pct',
#                                               'dist_to_stream_avg (m)',
#                                               'dist_to_stream_stdev (m)',
                                              'lu_21_area'
#                                               'lu_22_area',
#                                               'lu_23_area',
#                                               'lu_24_area',
#                                               'lu_41_area',
#                                               'lu_82_area',
#                                               'avg_impervious_percent',
#                                              'orb100yr06h',
#                                               'orb100yr12h',
#                                               'orb100yr24h',
#                                               'orb25yr06h',
#                                               'orb25yr12h',
#                                               'orb25yr24h',
#                                               'orb2yr06h',
#                                               'orb2yr12h',
#                                               'orb2yr24h',
#                                               'orb50yr06h',
#                                               'orb50yr12h',
#                                               'orb50yr24h',
#                                               'orb100yr06ha_am',
#                                               'orb100yr12ha_am',
#                                               'orb100yr24ha_am',
#                                               'orb25yr06ha_am',
#                                               'orb25yr12ha_am',
#                                               'orb25yr24ha_am',
#                                               'orb2yr06ha_am',
#                                               'orb2yr12ha_am',
#                                               'orb2yr24ha_am',
#                                               'orb50yr06ha_am',
#                                               'orb50yr12ha_am',
#                                               'orb50yr24ha_am'
                                             ])    
    

#     
#  
# 
# 
# 
#




print(outputs_df)

outputs_df.to_excel(r"C:\Users\jmatney\Documents\GitHub\IndianaRisk\data\output\lu_21_5.xlsx")
print(round(((time()-st)/60), 2) , 'minutes to process.')
# Out:
#      subwatershed  lu_21_area
# 0    051202021007    3.552892
# 1    051201010501    1.335440
# 2    051402010403    3.805159
# 3    051201090903    0.506847
# 4    071200010505    2.335881
# ..            ...         ...
# 320  041000040302    0.025705
# 321  051202081508    3.527914
# 322  071200020402    0.952345
# 323  040400010505    5.894797
# 324  051402011002    2.315170
#
# [325 rows x 2 columns]
# 0.02 minutes to process.

# %%
length_dict = {key: len(value) for key, value in outputs.items()}
length_dict
# Out:
# {'subwatershed': 325, 'lu_21_area': 325}
